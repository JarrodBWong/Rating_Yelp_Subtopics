# %%
from bs4 import BeautifulSoup
import sys
import time
import logging
import argparse
import requests
import codecs
import urllib
import os
import requests
import json
import nltk
from nltk.corpus import stopwords
import gensim
from gensim.corpora import BleiCorpus
from gensim import corpora
from gensim.models import LdaModel

# %%
# YELP DATASET: train on business reviews for businesses within the "Coffee & Tea" category

coffee_places = set()

with open('yelp_academic_dataset_business.json') as businesses:
    for item in businesses:
        biz = json.loads(item)
        if biz['categories'] is not None:
            if "Coffee & Tea" in biz['categories']:
                coffee_places.add(biz['business_id'])
        
reviewData = {}

with open('yelp_academic_dataset_review.json') as reviews:
    for item in reviews:
        rev = json.loads(item)
        if rev['business_id'] in coffee_places:
            reviewData[rev['review_id']] = {'text':rev['text'], 'stars':rev['stars']}

# %%
#list(reviewData.items())[:100]
# Out:
# 179409

# %%
# Split review into sentences, remove stopwords, extract parts-of-speech tags
# (opt. if lots of reviews) store each review into MongoDB db called 'Reviews'

stopWords = set(stopwords.words('english'))

for revId in reviewData:
    reviewWords = []
    sentences = nltk.sent_tokenize(reviewData[revId]['text'].lower())
    
    for sentence in sentences:
        tokens = nltk.word_tokenize(sentence)
        text = [w for w in tokens if w not in stopWords]
        tagged_text = nltk.pos_tag(text)
        
        for word, tag in tagged_text:
            reviewWords.append({'word': word, 'pos': tag})
    
    reviewData[revId]['review_words'] = reviewWords

list(reviewData.items())[:100]
# Out:
# [('1UJoZE55HxmEPSIVdFThUg',
#   {'review_words': [{'pos': 'NNS', 'word': 'les'},
#     {'pos': 'NNS', 'word': 'choses'},
#     {'pos': 'VBP', 'word': 'se'},
#     {'pos': 'JJ', 'word': 'sont'},
#     {'pos': 'NN', 'word': 'beaucoup'},
#     {'pos': 'NN', 'word': 'améliorées'},
#     {'pos': 'NN', 'word': 'au'},
#     {'pos': 'NN', 'word': 'café'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': "j'y"},
#     {'pos': 'VBP', 'word': 'ai'},
#     {'pos': 'NN', 'word': 'mangé'},
#     {'pos': 'JJ', 'word': 'une'},
#     {'pos': 'NN', 'word': 'assiette'},
#     {'pos': 'NN', 'word': "d'oeufs"},
#     {'pos': 'NNS', 'word': 'bénédictines'},
#     {'pos': 'VBP', 'word': 'très'},
#     {'pos': 'JJ', 'word': 'originale'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'et'},
#     {'pos': 'NN', 'word': 'mon'},
#     {'pos': 'NN', 'word': 'accompagnatrice'},
#     {'pos': 'NNS', 'word': 'des'},
#     {'pos': 'NNS', 'word': 'crêpes'},
#     {'pos': 'JJ', 'word': 'red'},
#     {'pos': 'NN', 'word': 'velvet'},
#     {'pos': 'NNS', 'word': 'moelleuses'},
#     {'pos': 'VBP', 'word': 'à'},
#     {'pos': 'NN', 'word': 'souhait'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJS', 'word': "c'est"},
#     {'pos': 'NN', 'word': 'propre'},
#     {'pos': 'NN', 'word': 'et'},
#     {'pos': 'JJ', 'word': 'le'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'JJS', 'word': 'est'},
#     {'pos': 'NN', 'word': 'excellent'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'à'},
#     {'pos': 'NN', 'word': 'réessayer'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 5,
#    'text': "Les choses se sont beaucoup améliorées au café. J'y ai mangé une assiette d'oeufs bénédictines très originale, et mon accompagnatrice des crêpes Red velvet moelleuses à souhait. C'est propre et le service y est excellent. À réessayer!"}),
#  ('nlb5lnWo2q4vNrGhFv6kug',
#   {'review_words': [{'pos': 'JJ', 'word': 'pinch'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'JJ', 'word': 'reliable'},
#     {'pos': 'NN', 'word': 'option'},
#     {'pos': 'VBG', 'word': 'getting'},
#     {'pos': 'VBN', 'word': 'caffeinated'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NN', 'word': 'quality'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'NNS', 'word': 'treats'},
#     {'pos': 'JJ', 'word': 'occasional'},
#     {'pos': 'JJ', 'word': 'gluten-free'},
#     {'pos': 'NNS', 'word': 'options'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'atmosphere'},
#     {'pos': 'RB', 'word': 'quite'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'main'},
#     {'pos': 'NN', 'word': 'complaint'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'RB', 'word': 'usually'},
#     {'pos': 'RB', 'word': 'quite'},
#     {'pos': 'JJ', 'word': 'noisy'},
#     {'pos': 'MD', 'word': 'would'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'consider'},
#     {'pos': 'VBG', 'word': 'relaxing'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'VBP', 'word': 'go'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 4,
#    'text': "In a pinch this place is a reliable option for getting caffeinated. Good quality coffee, nice treats with the occasional gluten-free options. The atmosphere is quite nice, but my main complaint is it's usually quite noisy and I wouldn't consider it a very relaxing place to go for coffee."}),
#  ('6FXeXgIF3qL3fmvbBqBtPw',
#   {'review_words': [{'pos': 'JJS', 'word': 'best'},
#     {'pos': 'NN', 'word': 'vanilla'},
#     {'pos': 'NN', 'word': 'chai'},
#     {'pos': 'RB', 'word': 'ever'},
#     {'pos': '.', 'word': '.'},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '3'},
#     {'pos': 'JJS', 'word': 'largest'},
#     {'pos': 'NN', 'word': 'size'},
#     {'pos': 'NN', 'word': 'offer'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBG', 'word': 'getting'},
#     {'pos': 'NN', 'word': 'car'},
#     {'pos': 'VBG', 'word': 'walking'},
#     {'pos': 'IN', 'word': 'inside'},
#     {'pos': 'RB', 'word': 'instead'},
#     {'pos': 'VBG', 'word': 'sitting'},
#     {'pos': 'NNS', 'word': 'starbucks'},
#     {'pos': 'VBP', 'word': 'drive'},
#     {'pos': 'NN', 'word': 'thru'},
#     {'pos': 'VBG', 'word': 'paying'},
#     {'pos': 'RB', 'word': 'almost'},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '5'},
#     {'pos': 'NN', 'word': 'brainer'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'super'},
#     {'pos': 'JJ', 'word': 'friendly'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'beautiful'},
#     {'pos': 'NN', 'word': 'furniture'},
#     {'pos': 'NN', 'word': 'deco'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NN', 'word': 'menu'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'JJ', 'word': 'clean'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'maybe'},
#     {'pos': 'JJS', 'word': 'best'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'NN', 'word': 'try'},
#     {'pos': 'NN', 'word': 'study'},
#     {'pos': 'IN', 'word': 'since'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'kinda'},
#     {'pos': 'NN', 'word': 'noisy'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'separate'},
#     {'pos': 'NN', 'word': 'hallway'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'quiet'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'VBP', 'word': 'think'},
#     {'pos': 'NN', 'word': 'amelie'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'noda'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'JJ', 'word': 'quick'},
#     {'pos': 'VBZ', 'word': 'comes'},
#     {'pos': 'VBG', 'word': 'bringing'},
#     {'pos': 'VB', 'word': 'drink'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'even'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'packed'},
#     {'pos': 'NN', 'word': 'inside'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'line'},
#     {'pos': 'NN', 'word': 'door'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'ditch'},
#     {'pos': 'NNS', 'word': 'starbucks'},
#     {'pos': 'VBP', 'word': 'panera'},
#     {'pos': 'JJ', 'word': 'give'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'VBP', 'word': 'go'},
#     {'pos': 'JJ', 'word': 'next'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': 'VBP', 'word': "'re"},
#     {'pos': 'NN', 'word': 'ballantyne'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 5,
#    'text': "Best vanilla chai ever. At under $3 for the largest size they offer, getting out of my car and walking inside instead of sitting in a Starbucks drive thru and paying almost $5 is a no brainer. Super friendly staff, beautiful furniture and deco, great menu and it's always clean. Maybe not the best place to try to study since it's kinda noisy, but there is a separate hallway that's quiet (think Amelie's in noda). They are always very quick when it comes to bringing out my drink, even when it's packed inside and there's a line to the door. Ditch Starbucks or Panera and give this place a go next time you're in Ballantyne!"}),
#  ('IFFqCH50jUbXkUzOjoxz7g',
#   {'review_words': [{'pos': 'VBN', 'word': 'used'},
#     {'pos': 'NN', 'word': 'drive'},
#     {'pos': 'JJ', 'word': 'past'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'DT', 'word': 'every'},
#     {'pos': 'NN', 'word': 'day'},
#     {'pos': 'NN', 'word': 'asu'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'even'},
#     {'pos': 'VBP', 'word': 'know'},
#     {'pos': 'NN', 'word': 'anything'},
#     {'pos': 'JJ', 'word': 'read'},
#     {'pos': 'NN', 'word': 'online'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'oh'},
#     {'pos': 'NN', 'word': 'man'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'sure'},
#     {'pos': 'NN', 'word': 'glad'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'hard'},
#     {'pos': 'VBG', 'word': 'finding'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'healthy'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'vegetarian/vegan'},
#     {'pos': 'JJ', 'word': 'friendly'},
#     {'pos': 'VBD', 'word': 'fast'},
#     {'pos': 'NN', 'word': 'food'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'IN', 'word': 'around'},
#     {'pos': 'JJ', 'word': 'awesome'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'mention'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'VBG', 'word': 'entertaining'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'guy'},
#     {'pos': 'VBG', 'word': 'working'},
#     {'pos': 'NN', 'word': 'drive'},
#     {'pos': 'NN', 'word': 'flip'},
#     {'pos': 'NN', 'word': 'excitement'},
#     {'pos': 'NN', 'word': 'gingerbread'},
#     {'pos': 'NN', 'word': 'house'},
#     {'pos': 'VBD', 'word': 'kit'},
#     {'pos': 'JJR', 'word': 'passenger'},
#     {'pos': 'NN', 'word': 'seat'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'also'},
#     {'pos': 'VBD', 'word': 'kept'},
#     {'pos': 'VBG', 'word': 'referring'},
#     {'pos': 'NNP', 'word': "'homegirl"},
#     {'pos': 'POS', 'word': "'"},
#     {'pos': 'NN', 'word': 'haha'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'able'},
#     {'pos': 'NN', 'word': 'bring'},
#     {'pos': 'VB', 'word': 'try'},
#     {'pos': 'NN', 'word': 'anything'},
#     {'pos': 'JJ', 'word': 'veggie'},
#     {'pos': 'NNS', 'word': 'burgers'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'IN', 'word': 'since'},
#     {'pos': 'NN', 'word': 'love'},
#     {'pos': 'NN', 'word': 'veggie'},
#     {'pos': 'NNS', 'word': 'burgers'},
#     {'pos': 'RB', 'word': 'much'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'RB', 'word': 'usually'},
#     {'pos': 'VBP', 'word': 'go'},
#     {'pos': 'JJ', 'word': 'early'},
#     {'pos': 'NN', 'word': 'bird'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'quinoa'},
#     {'pos': 'JJ', 'word': 'black'},
#     {'pos': 'NN', 'word': 'bean'},
#     {'pos': 'NN', 'word': 'patty'},
#     {'pos': 'VBZ', 'word': 'seems'},
#     {'pos': 'JJ', 'word': 'tad'},
#     {'pos': 'NN', 'word': 'bland'},
#     {'pos': 'RB', 'word': 'actually'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NNS', 'word': 'toppings'},
#     {'pos': 'VBP', 'word': 'make'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'fried'},
#     {'pos': 'NN', 'word': 'egg'},
#     {'pos': 'NN', 'word': 'chipotle'},
#     {'pos': 'VBP', 'word': 'aioli'},
#     {'pos': 'JJ', 'word': 'fabulous'},
#     {'pos': 'NN', 'word': 'burger'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'buns'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': 'RB', 'word': 'well'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CC', 'word': 'plus'},
#     {'pos': 'JJ', 'word': 'huge'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'fill'},
#     {'pos': 'RB', 'word': 'fast'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'JJ', 'word': "d'lish"},
#     {'pos': 'RB', 'word': 'relatively'},
#     {'pos': 'JJ', 'word': 'inexpensive'},
#     {'pos': 'NN', 'word': 'quality'},
#     {'pos': 'NNS', 'word': 'ingredients'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'think'},
#     {'pos': 'NN', 'word': 'concept'},
#     {'pos': 'NN', 'word': 'restaurant'},
#     {'pos': 'NN', 'word': 'awesome'},
#     {'pos': 'MD', 'word': 'would'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'VB', 'word': 'see'},
#     {'pos': 'NNS', 'word': 'places'},
#     {'pos': 'JJ', 'word': 'similar'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 4,
#    'text': "I used to drive past this place every day on my was to ASU, but did not even know anything about it until I read about it online. Oh man, I am sure glad I did.\n\nIt is hard finding a good, healthy, vegetarian/vegan friendly fast food place, so having a place like this around is just awesome. Not to mention, the service is great, the staff is always entertaining. I had one guy working the drive through flip out with excitement because I had a gingerbread house kit in my passenger seat. He also kept referring to me  as 'homegirl' haha. \n\nI have not been able to bring myself to try anything other than the veggie burgers, since I just love veggie burgers so much! I usually go for the Early Bird. The quinoa black bean patty itself seems a tad bland to me actually, but the toppings so make up for it. The fried egg and chipotle aioli are fabulous on that burger. The buns are delicious as well. Plus they are huge, fill you up fast!\n\nD'lish is relatively inexpensive for the quality for the ingredients. I think the concept of this restaurant is awesome and I would love to see more places similar to this!"}),
#  ('i0JGjRoYKCm2Ywsc6JojZw',
#   {'review_words': [{'pos': 'VB', 'word': 'say'},
#     {'pos': 'RB', 'word': 'enough'},
#     {'pos': 'JJ', 'word': 'much'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'NN', 'word': 'le'},
#     {'pos': 'NN', 'word': 'sélect..'},
#     {'pos': 'RB', 'word': 'probably'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'atmospheric'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBN', 'word': 'refined'},
#     {'pos': 'JJ', 'word': 'friendly'},
#     {'pos': 'JJ', 'word': 'french'},
#     {'pos': 'NNS', 'word': 'restaurants'},
#     {'pos': 'NN', 'word': 'toronto'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'excellent'},
#     {'pos': 'JJ', 'word': 'french'},
#     {'pos': 'NNS', 'word': 'tables'},
#     {'pos': 'IN', 'word': 'toronto'},
#     {'pos': 'JJ', 'word': 'go'},
#     {'pos': 'NN', 'word': 'destination'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'JJ', 'word': 'authentic'},
#     {'pos': 'JJ', 'word': 'french'},
#     {'pos': 'NN', 'word': 'brasserie'},
#     {'pos': 'NN', 'word': 'fare'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'sometimes'},
#     {'pos': 'NN', 'word': 'twist'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'classics'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'boeuf'},
#     {'pos': 'NN', 'word': 'bourguignon'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'tartare'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'cassoulet'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'choucroute'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'FW', 'word': 'etc'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'originally'},
#     {'pos': 'JJ', 'word': 'queen'},
#     {'pos': 'NN', 'word': 'street'},
#     {'pos': 'JJS', 'word': 'west'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'VB', 'word': 'remember'},
#     {'pos': 'JJ', 'word': 'bread'},
#     {'pos': 'NNS', 'word': 'baskets'},
#     {'pos': 'VBG', 'word': 'hanging'},
#     {'pos': 'NNS', 'word': 'tables'},
#     {'pos': '.', 'word': '?'},
#     {'pos': ')', 'word': ')'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBD', 'word': 'moved'},
#     {'pos': 'NNS', 'word': 'years'},
#     {'pos': 'RB', 'word': 'ago'},
#     {'pos': 'JJR', 'word': 'bigger'},
#     {'pos': 'RB', 'word': 'much'},
#     {'pos': 'JJR', 'word': 'better'},
#     {'pos': 'NN', 'word': 'location'},
#     {'pos': 'IN', 'word': 'wellington'},
#     {'pos': 'NN', 'word': 'street.the'},
#     {'pos': 'NN', 'word': 'interior'},
#     {'pos': 'RB', 'word': 'nicely'},
#     {'pos': 'VBN', 'word': 'decorated'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'brasserie'},
#     {'pos': 'NN', 'word': 'parisienne'},
#     {'pos': 'RB', 'word': 'atmosphere'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBD', 'word': 'went'},
#     {'pos': 'JJ', 'word': 'early'},
#     {'pos': 'NN', 'word': 'dinner'},
#     {'pos': 'RB', 'word': 'pretty'},
#     {'pos': 'JJ', 'word': 'ballerina'},
#     {'pos': 'NN', 'word': 'monday'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'june'},
#     {'pos': 'CD', 'word': '2nd'},
#     {'pos': 'CD', 'word': '2014.'},
#     {'pos': 'NN', 'word': 'weather'},
#     {'pos': 'RB', 'word': 'lovely'},
#     {'pos': 'VBD', 'word': 'opted'},
#     {'pos': 'NN', 'word': 'sit'},
#     {'pos': 'RB', 'word': 'lovely'},
#     {'pos': 'JJ', 'word': 'front'},
#     {'pos': 'NN', 'word': 'patio'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'RB', 'word': 'friendly'},
#     {'pos': 'JJ', 'word': 'efficient'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'waiter'},
#     {'pos': 'RB', 'word': 'even'},
#     {'pos': 'VBD', 'word': 'spoke'},
#     {'pos': 'JJ', 'word': 'french'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'something'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'thing'},
#     {'pos': 'NN', 'word': 'speaking'},
#     {'pos': 'NN', 'word': 'language'},
#     {'pos': 'NN', 'word': 'cuisine'},
#     {'pos': 'NN', 'word': 'savouring'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'MD', 'word': 'must'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'IN', 'word': 'unless'},
#     {'pos': 'NN', 'word': 'course'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBP', 'word': 'know'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'VBG', 'word': 'looking'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'arabic'},
#     {'pos': 'JJ', 'word': 'vietnamese'},
#     {'pos': '.', 'word': '!'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBG', 'word': 'waiting'},
#     {'pos': 'NN', 'word': 'dinner'},
#     {'pos': 'NN', 'word': 'companion'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBD', 'word': 'savoured'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': 'NN', 'word': 'pastis'},
#     {'pos': 'NN', 'word': 'ricard'},
#     {'pos': 'NN', 'word': 'brand'},
#     {'pos': '(', 'word': '('},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '6.50'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'classical'},
#     {'pos': 'NN', 'word': 'presentation'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'long'},
#     {'pos': 'NN', 'word': 'glass'},
#     {'pos': 'NN', 'word': 'ice'},
#     {'pos': 'NN', 'word': 'pastis'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'water'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'JJ', 'word': 'carafe'},
#     {'pos': 'NN', 'word': 'ricard'},
#     {'pos': 'NN', 'word': 'logo'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'selection'},
#     {'pos': 'NNS', 'word': 'wines'},
#     {'pos': 'NN', 'word': 'glass'},
#     {'pos': 'JJ', 'word': 'limited'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'quite'},
#     {'pos': 'JJ', 'word': 'varied'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': '5'},
#     {'pos': 'JJ', 'word': 'oz'},
#     {'pos': 'NNS', 'word': 'glasses'},
#     {'pos': ':', 'word': ':'},
#     {'pos': 'CD', 'word': '2'},
#     {'pos': 'NNS', 'word': 'whites'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NNS', 'word': 'chablis'},
#     {'pos': 'VBP', 'word': 'domaine'},
#     {'pos': 'NN', 'word': 'laroche'},
#     {'pos': 'FW', 'word': "'12"},
#     {'pos': '(', 'word': '('},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '12.25'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'NN', 'word': 'muscadet'},
#     {'pos': 'VBG', 'word': 'coing'},
#     {'pos': 'FW', 'word': 'de'},
#     {'pos': 'FW', 'word': 'sèvre'},
#     {'pos': 'FW', 'word': "'10"},
#     {'pos': '(', 'word': '('},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '10.75'},
#     {'pos': ')', 'word': ')'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'red'},
#     {'pos': 'NN', 'word': 'cabernet'},
#     {'pos': 'NN', 'word': 'villa'},
#     {'pos': 'NNS', 'word': 'des'},
#     {'pos': 'VBZ', 'word': 'anges'},
#     {'pos': 'JJ', 'word': 'languedoc'},
#     {'pos': 'NNP', 'word': "'11"},
#     {'pos': '(', 'word': '('},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '10.25'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'pastis'},
#     {'pos': 'RB', 'word': 'already'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'glass'},
#     {'pos': 'NN', 'word': 'wine'},
#     {'pos': 'JJ', 'word': 'enough'},
#     {'pos': 'NN', 'word': 'guest'},
#     {'pos': 'NN', 'word': 'muscadet'},
#     {'pos': 'NN', 'word': 'apéritif'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'started'},
#     {'pos': 'JJ', 'word': 'meal'},
#     {'pos': 'JJ', 'word': 'excellent'},
#     {'pos': 'NN', 'word': 'dozen'},
#     {'pos': 'NN', 'word': 'malpèque'},
#     {'pos': 'NNS', 'word': 'oysters'},
#     {'pos': '(', 'word': '('},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '29.00'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'specifically'},
#     {'pos': 'JJ', 'word': 'seafood'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'le'},
#     {'pos': 'NN', 'word': 'sélect'},
#     {'pos': 'VBZ', 'word': 'chooses'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NNS', 'word': 'bivalves'},
#     {'pos': ',', 'word': ','},
#     {'pos': ':', 'word': ':'},
#     {'pos': 'NNS', 'word': 'oysters'},
#     {'pos': 'VBP', 'word': 'seafood'},
#     {'pos': 'NNS', 'word': 'platters'},
#     {'pos': 'JJ', 'word': 'forte'},
#     {'pos': 'NNS', 'word': 'brasseries'},
#     {'pos': 'NN', 'word': 'hexagone'},
#     {'pos': '.', 'word': '.'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'pretty'},
#     {'pos': 'RB', 'word': 'ballerina'},
#     {'pos': 'VBN', 'word': 'ordered'},
#     {'pos': 'JJ', 'word': 'roasted'},
#     {'pos': 'NN', 'word': 'salmon'},
#     {'pos': 'VBD', 'word': 'cold'},
#     {'pos': 'JJ', 'word': 'quinoa'},
#     {'pos': 'NN', 'word': 'aubergine'},
#     {'pos': 'NN', 'word': 'salad'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': '(', 'word': '('},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '16.95'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'ordered'},
#     {'pos': 'NN', 'word': 'bison'},
#     {'pos': 'NN', 'word': 'tartare'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'bison'},
#     {'pos': 'JJ', 'word': 'perfect'},
#     {'pos': 'NN', 'word': 'meat'},
#     {'pos': 'NN', 'word': 'dish'},
#     {'pos': ':', 'word': ':'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'VB', 'word': 'fatty'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NN', 'word': 'lean'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'fresh'},
#     {'pos': 'NN', 'word': 'meaty'},
#     {'pos': 'NN', 'word': 'taste'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'tartare'},
#     {'pos': '(', 'word': '('},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '17.95'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'JJ', 'word': 'well-seasoned'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'enough'},
#     {'pos': 'NN', 'word': 'spice'},
#     {'pos': 'VBD', 'word': 'chopped'},
#     {'pos': 'NNS', 'word': 'pistachios'},
#     {'pos': 'JJ', 'word': 'top'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': 'NN', 'word': 'touch'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'tasted'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'dish'},
#     {'pos': 'VBD', 'word': 'concluded'},
#     {'pos': 'JJ', 'word': 'le'},
#     {'pos': 'JJ', 'word': 'sélect'},
#     {'pos': 'NN', 'word': 'apt'},
#     {'pos': 'VBG', 'word': 'surfing'},
#     {'pos': 'NN', 'word': 'turfing'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'finale'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBN', 'word': 'shared'},
#     {'pos': 'NN', 'word': 'parfait'},
#     {'pos': 'NN', 'word': 'praliné'},
#     {'pos': '(', 'word': '('},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '10.95'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'praline'},
#     {'pos': 'JJ', 'word': 'popular'},
#     {'pos': 'JJ', 'word': 'french'},
#     {'pos': 'NN', 'word': 'dessert'},
#     {'pos': 'NN', 'word': 'ingredient'},
#     {'pos': 'VBD', 'word': 'made'},
#     {'pos': 'JJ', 'word': 'candied'},
#     {'pos': 'NNS', 'word': 'almonds'},
#     {'pos': 'RBR', 'word': 'hazelnuts'},
#     {'pos': 'RB', 'word': 'finely'},
#     {'pos': 'JJ', 'word': 'ground'},
#     {'pos': 'VBP', 'word': 'make'},
#     {'pos': 'NN', 'word': 'sort'},
#     {'pos': 'NN', 'word': 'crunchy'},
#     {'pos': 'NN', 'word': 'powder'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'dessert'},
#     {'pos': 'VBZ', 'word': 'incorporates'},
#     {'pos': 'JJ', 'word': 'ice'},
#     {'pos': 'NN', 'word': 'cream'},
#     {'pos': 'NN', 'word': 'dish'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': 'NN', 'word': 'light'},
#     {'pos': 'NN', 'word': 'palate'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'yet'},
#     {'pos': 'VBZ', 'word': 'throws'},
#     {'pos': 'RB', 'word': 'quite'},
#     {'pos': 'JJ', 'word': 'flavour'},
#     {'pos': 'NN', 'word': 'punch'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'simultaneously'},
#     {'pos': 'JJ', 'word': 'sweet'},
#     {'pos': 'NN', 'word': 'salty'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'often'},
#     {'pos': 'JJ', 'word': 'skip'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'downtown'},
#     {'pos': 'NNS', 'word': 'restaurants'},
#     {'pos': 'VBP', 'word': 'head'},
#     {'pos': 'RB', 'word': 'elsewhere'},
#     {'pos': 'JJ', 'word': 'dinner'},
#     {'pos': 'NN', 'word': 'caffeine'},
#     {'pos': 'NN', 'word': 'fix'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'le'},
#     {'pos': 'VBP', 'word': 'sélect'},
#     {'pos': 'RB', 'word': 'quite'},
#     {'pos': 'JJ', 'word': 'skilled'},
#     {'pos': 'NN', 'word': 'espresso'},
#     {'pos': 'NN', 'word': 'machine'},
#     {'pos': ':', 'word': ':'},
#     {'pos': 'NN', 'word': 'cappucino'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'VBZ', 'word': 'makes'},
#     {'pos': 'CD', 'word': '2'},
#     {'pos': 'NN', 'word': 'cappucini'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'CD', 'word': '4.50'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'VBD', 'word': 'enjoyed'},
#     {'pos': 'RB', 'word': 'much'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'word'},
#     {'pos': 'VBZ', 'word': 'le'},
#     {'pos': 'VBP', 'word': 'sélect'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'wine'},
#     {'pos': 'NN', 'word': 'list'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'JJS', 'word': 'best'},
#     {'pos': 'NN', 'word': 'city'},
#     {'pos': 'VBP', 'word': 'find'},
#     {'pos': 'NN', 'word': 'lot'},
#     {'pos': 'JJ', 'word': 'different'},
#     {'pos': 'NNS', 'word': 'bottles'},
#     {'pos': 'DT', 'word': 'every'},
#     {'pos': 'NN', 'word': 'taste'},
#     {'pos': 'DT', 'word': 'every'},
#     {'pos': 'NN', 'word': 'price'},
#     {'pos': 'NN', 'word': 'range'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'check'},
#     {'pos': 'JJ', 'word': 'bin'},
#     {'pos': 'NN', 'word': 'end'},
#     {'pos': 'NN', 'word': 'section'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'MD', 'word': 'may'},
#     {'pos': 'VB', 'word': 'find'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': 'NNS', 'word': 'bargains'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'conclusion'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'le'},
#     {'pos': 'NN', 'word': 'sélect'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NNS', 'word': 'years'},
#     {'pos': 'VBZ', 'word': 'remains'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'strongest'},
#     {'pos': 'NN', 'word': 'dining'},
#     {'pos': 'NNS', 'word': 'options'},
#     {'pos': 'VBP', 'word': 'downtown'},
#     {'pos': 'JJ', 'word': 'west'},
#     {'pos': 'NN', 'word': 'area'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'fan'},
#     {'pos': 'JJ', 'word': 'french'},
#     {'pos': 'NN', 'word': 'cuisine'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'NNS', 'word': 'restaurants'},
#     {'pos': 'JJ', 'word': 'similar'},
#     {'pos': 'NNS', 'word': 'les'},
#     {'pos': 'NNS', 'word': 'halles'},
#     {'pos': 'RB', 'word': 'nyc'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'NN', 'word': 'establishment'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': "I cannot say enough how much I love Le Sélect.. This is probably one the most atmospheric, refined and friendly French restaurants in Toronto. There are a few other excellent French tables in Toronto but this is my go to destination for good authentic French brasserie fare, sometimes with a twist. All the classics are here. Boeuf Bourguignon, Tartare, Cassoulet, Choucroute, etc.  Originally on Queen Street west (remember the bread baskets hanging over the tables?), they moved some years ago to this bigger and much better location on Wellington street.The interior is very nicely decorated, with this Brasserie Parisienne atmosphere.\nI went there for an early dinner with the Pretty Ballerina on Monday, June the 2nd 2014. The weather was lovely and we opted to sit on the lovely front patio.\nService was very friendly and efficient, and our waiter even spoke French with me, which is something I like. I have this thing about speaking the language of the cuisine I am savouring, it is a must. Unless of course, I do not know it (here is looking at you, Arabic and Vietnamese!).\nAs I was waiting for my dinner companion, I savoured a  delicious pastis of the Ricard Brand($6.50). Classical presentation, long glass with ice and pastis, with water in a nice carafe with the Ricard logo on it. The selection of wines by the glass is limited but at the same time, quite varied. We all had  5 oz glasses: 2 whites, Chablis Domaine Laroche '12 ($12.25) and Muscadet Coing de Sèvre '10 ($10.75) for her, while I had a red Cabernet Villa des Anges Languedoc '11 ($10.25). I had the pastis already so one glass of wine was enough and my guest had the muscadet as her apéritif.\nWe started our meal with an excellent dozen of Malpèque oysters ($29.00). While not specifically a seafood place, Le Sélect chooses very good bivalves, as they should: oysters and seafood platters being a forte of brasseries all over the Hexagone.\nThen, the Pretty Ballerina ordered the Roasted Salmon with  cold Quinoa and Aubergine salad, which was delicious ($16.95).\nI ordered the Bison Tartare. Bison is a perfect meat for this dish: not really fatty, with a good lean, fresh meaty taste. This tartare($17.95) is well-seasoned, with just enough spice and the chopped pistachios on top are a delicious touch . We tasted each other's dish and concluded that Le Sélect is very apt both at surfing and turfing.\nFor the finale, we shared the parfait praliné ($10.95). Praline is a popular French dessert ingredient  made from candied almonds and hazelnuts that are finely ground to make a sort of crunchy powder. This dessert incorporates it in an ice cream dish which is delicious and light on the palate, yet throws quite a flavour punch, simultaneously sweet and salty.\nOften I skip coffee at downtown restaurants and head elsewhere for an after dinner caffeine fix, but Le Sélect is quite skilled with the espresso machine: we both had a cappucino(which makes for 2 cappucini, 4.50 each) and enjoyed it very much.\nOne word about Le Sélect's wine list. It is one of the best in the city and you will find a lot of different bottles for every taste at every price range. If you check the bin end section, you may find delicious bargains.\nIn conclusion, Le Sélect, after all these years remains one of the strongest dining options in the downtown west area. If you are a fan of French Cuisine and if you like restaurants similar to Les Halles in NYC, you will love this establishment."}),
#  ('pvJqpkwekGcqwkgl2uYmeA',
#   {'review_words': [{'pos': 'VBN', 'word': 'used'},
#     {'pos': 'VB', 'word': 'go'},
#     {'pos': 'JJ', 'word': 'place'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'business'},
#     {'pos': 'NNS', 'word': 'meetings'},
#     {'pos': 'JJ', 'word': 'broken'},
#     {'pos': 'NN', 'word': 'furniture'},
#     {'pos': 'NN', 'word': 'walk'},
#     {'pos': 'NN', 'word': 'creepy'},
#     {'pos': 'NN', 'word': 'guy'},
#     {'pos': 'VBG', 'word': 'smoking'},
#     {'pos': 'NN', 'word': 'section'},
#     {'pos': 'NN', 'word': 'enter'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'feel'},
#     {'pos': 'JJ', 'word': 'bad'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'VBD', 'word': 'seemed'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'RB', 'word': 'even'},
#     {'pos': 'IN', 'word': 'though'},
#     {'pos': 'RB', 'word': 'obviously'},
#     {'pos': 'NN', 'word': 'work'},
#     {'pos': 'NN', 'word': 'someone'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'care'},
#     {'pos': 'NN', 'word': 'business'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 1,
#    'text': "Used to be my go to place for coffee business meetings but the broken down furniture and having to walk through the creepy guy smoking section as I enter did it for me.  Feel bad for the staff because they always seemed really nice even though they obviously work for someone who doesn't care about the business."}),
#  ('cAZPv394bZ-Ig2jFEbEeIA',
#   {'review_words': [{'pos': 'JJ', 'word': 'true'},
#     {'pos': 'JJ', 'word': 'asian'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'PRP', 'word': 'us'},
#     {'pos': 'VBP', 'word': 'tea'},
#     {'pos': 'VBG', 'word': 'coursing'},
#     {'pos': 'NN', 'word': 'thru'},
#     {'pos': 'NN', 'word': 'blood'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'hate'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'much'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'NN', 'word': 'drink..'},
#     {'pos': 'JJ', 'word': 'altho'},
#     {'pos': 'NN', 'word': 'situation'},
#     {'pos': 'VBP', 'word': "'ve"},
#     {'pos': 'RB', 'word': 'probably'},
#     {'pos': 'VBD', 'word': 'got'},
#     {'pos': 'JJ', 'word': 'mix'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'VBG', 'word': 'coursing'},
#     {'pos': 'JJ', 'word': 'thru'},
#     {'pos': 'NNS', 'word': 'veins'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'basically'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'EX', 'word': 'tea'},
#     {'pos': 'NN', 'word': 'nothing'},
#     {'pos': 'JJ', 'word': 'new'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'nothing'},
#     {'pos': 'NN', 'word': 'exciting'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'everyday'},
#     {'pos': 'VBP', 'word': 'stuff..'},
#     {'pos': 'VBN', 'word': 'come'},
#     {'pos': 'NN', 'word': 'david'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'RB', 'word': 'well'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'NNS', 'word': 'locations'},
#     {'pos': 'RB', 'word': 'probably'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'VB', 'word': 'come'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'VBP', 'word': 'whole'},
#     {'pos': 'NN', 'word': 'wall'},
#     {'pos': 'VBN', 'word': 'filled'},
#     {'pos': 'JJ', 'word': 'tea'},
#     {'pos': 'JJ', 'word': 'displayed'},
#     {'pos': 'NN', 'word': 'floor'},
#     {'pos': 'NN', 'word': 'ceiling'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'categorized'},
#     {'pos': 'NN', 'word': 'type'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'ingredient'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'caffeine'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'herbal'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'NN', 'word': 'super'},
#     {'pos': 'RB', 'word': 'friendly'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBZ', 'word': 'comes'},
#     {'pos': 'RB', 'word': 'pick'},
#     {'pos': 'JJ', 'word': 'right'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'VB', 'word': 'go'},
#     {'pos': 'NN', 'word': 'hardcore'},
#     {'pos': 'NN', 'word': 'bland'},
#     {'pos': 'NN', 'word': 'caffeine'},
#     {'pos': 'VBD', 'word': 'loaded'},
#     {'pos': 'JJ', 'word': 'black'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'strawberry/pomegranate/raspberry/melon'},
#     {'pos': 'NN', 'word': 'mix'},
#     {'pos': 'NN', 'word': 'fruit'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'name'},
#     {'pos': 'VBD', 'word': 'got'},
#     {'pos': 'NNS', 'word': 'it..'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'get'},
#     {'pos': 'CD', 'word': '100g'},
#     {'pos': 'NNS', 'word': 'get'},
#     {'pos': 'JJ', 'word': 'free'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': 'NN', 'word': 'tin'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBZ', 'word': 'makes'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NNS', 'word': 'gifts'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'NN', 'word': 'load'},
#     {'pos': 'NNS', 'word': 'antioxidants'},
#     {'pos': 'VBP', 'word': 'feel'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'VBP', 'word': "'re"},
#     {'pos': 'JJ', 'word': 'ready'},
#     {'pos': 'NN', 'word': 'anything'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'RB', 'word': 'even'},
#     {'pos': 'NN', 'word': 'life'},
#     {'pos': 'NNS', 'word': 'throws'},
#     {'pos': 'NNS', 'word': 'lemons'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'squeeze'},
#     {'pos': 'CC', 'word': '&'},
#     {'pos': '#', 'word': '#'},
#     {'pos': 'NN', 'word': '%'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': '.', 'word': '!'},
#     {'pos': ':', 'word': ':'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'NN', 'word': 'awesomeness'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 5,
#    'text': "Being a true asian, most of us have tea coursing thru our blood. Don't hate, that's just how much tea we like to drink.. altho in my situation i've probably got a mix of tea and coffee coursing thru my veins. Basically, tea is nothing new, nothing exciting, everyday stuff.. until you come to David's Tea!\n\nWell this place (other locations are probably just as nice but I come to this one) has the whole wall filled with tea displayed from floor to ceiling. All categorized by type, ingredient, caffeine, or herbal. The staff here are super friendly, so when it comes to pick a right tea for you, this is the place to be! You can go hardcore bland caffeine loaded black tea, to strawberry/pomegranate/raspberry/melon mix fruit tea, name it they got it.. and more.\n\nGet 100G you will get a free tea tin, makes great gifts too!\n\nLoad up on those antioxidants and you will feel like you're ready for anything! This is where even life throws you lemons, you just squeeze that S&#% in your tea! :) awesomeness!"}),
#  ('rUEtn3qDWwegCDpXQ8exnQ',
#   {'review_words': [{'pos': 'NN', 'word': 'holy'},
#     {'pos': 'NNS', 'word': 'smokes'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'holy'},
#     {'pos': 'NN', 'word': 'oak'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'shop'},
#     {'pos': 'JJ', 'word': 'cum'},
#     {'pos': 'NN', 'word': 'bar'},
#     {'pos': 'NNS', 'word': 'transitions'},
#     {'pos': 'NN', 'word': 'course'},
#     {'pos': 'NN', 'word': 'day'},
#     {'pos': 'JJ', 'word': 'cozy'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'NN', 'word': 'study'},
#     {'pos': 'JJ', 'word': 'awesome'},
#     {'pos': 'NN', 'word': 'spot'},
#     {'pos': 'NNS', 'word': 'cocktails'},
#     {'pos': 'VBG', 'word': 'evening'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'JJ', 'word': 'awesome'},
#     {'pos': 'JJ', 'word': 'trendy'},
#     {'pos': 'NNS', 'word': 'spots'},
#     {'pos': 'VBG', 'word': 'transforming'},
#     {'pos': 'JJ', 'word': 'bloordale'},
#     {'pos': 'JJ', 'word': 'next'},
#     {'pos': 'NN', 'word': 'hip'},
#     {'pos': 'NN', 'word': 'spot'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'shop'},
#     {'pos': 'RB', 'word': 'definitely'},
#     {'pos': 'JJ', 'word': 'casual'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'VB', 'word': 'think'},
#     {'pos': 'IN', 'word': 'normcore'},
#     {'pos': 'NN', 'word': 'fashion'},
#     {'pos': 'NN', 'word': 'restaurant'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'still'},
#     {'pos': 'MD', 'word': 'would'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'call'},
#     {'pos': 'JJ', 'word': 'dive'},
#     {'pos': 'NN', 'word': 'bar'},
#     {'pos': 'IN', 'word': 'though'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'dimly'},
#     {'pos': 'JJ', 'word': 'lit'},
#     {'pos': 'NN', 'word': 'bar'},
#     {'pos': 'VBG', 'word': 'evening'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'JJ', 'word': 'intimate'},
#     {'pos': 'NN', 'word': 'vibe'},
#     {'pos': 'JJ', 'word': 'appropriate'},
#     {'pos': 'RB', 'word': 'enough'},
#     {'pos': 'NN', 'word': 'amount'},
#     {'pos': 'NN', 'word': 'background'},
#     {'pos': 'RB', 'word': 'noise'},
#     {'pos': 'VB', 'word': 'make'},
#     {'pos': 'NN', 'word': 'feel'},
#     {'pos': 'RB', 'word': 'quite'},
#     {'pos': 'JJ', 'word': 'pleasant'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'homey'},
#     {'pos': 'JJ', 'word': 'trendy'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'cocktail'},
#     {'pos': 'NN', 'word': 'list'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'RB', 'word': 'pretty'},
#     {'pos': 'JJ', 'word': 'interesting'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'enjoyed'},
#     {'pos': 'CD', 'word': 'two'},
#     {'pos': 'NNS', 'word': 'cocktails'},
#     {'pos': 'JJ', 'word': 'last'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': ':', 'word': ':'},
#     {'pos': 'CD', 'word': '1'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'NN', 'word': 'cynar'},
#     {'pos': 'NN', 'word': 'sour'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'know'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VB', 'word': 'cynar'},
#     {'pos': 'NN', 'word': 'liquor'},
#     {'pos': 'VBN', 'word': 'made'},
#     {'pos': 'NNS', 'word': 'artichokes'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'VBG', 'word': 'bracing'},
#     {'pos': 'NN', 'word': 'taste'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'actually'},
#     {'pos': 'RB', 'word': 'shockingly'},
#     {'pos': 'JJ', 'word': 'pleasant'},
#     {'pos': 'NN', 'word': 'sour'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'also'},
#     {'pos': 'VBZ', 'word': 'cocktails'},
#     {'pos': 'NN', 'word': 'cynar'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBZ', 'word': 'takes'},
#     {'pos': 'NN', 'word': 'talent'},
#     {'pos': 'NN', 'word': 'employ'},
#     {'pos': 'NN', 'word': 'potent'},
#     {'pos': 'JJ', 'word': 'potable'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': '2'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'JJ', 'word': 'last'},
#     {'pos': 'NN', 'word': 'word'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'ordered'},
#     {'pos': 'VB', 'word': 'drink'},
#     {'pos': 'JJ', 'word': 'off-menu'},
#     {'pos': 'NN', 'word': 'spying'},
#     {'pos': 'NNS', 'word': 'bottles'},
#     {'pos': 'JJ', 'word': 'green'},
#     {'pos': 'NN', 'word': 'chartreuse'},
#     {'pos': 'NN', 'word': 'maraschino'},
#     {'pos': 'NN', 'word': 'liquor'},
#     {'pos': 'NN', 'word': 'shelf'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'libations'},
#     {'pos': 'RB', 'word': 'often'},
#     {'pos': 'VBP', 'word': 'absent'},
#     {'pos': 'JJ', 'word': 'many'},
#     {'pos': 'RB', 'word': 'pretty'},
#     {'pos': 'JJ', 'word': 'solid'},
#     {'pos': 'NNS', 'word': 'bars'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'super-friendly'},
#     {'pos': 'NN', 'word': 'bartender'},
#     {'pos': 'VBD', 'word': 'thrilled'},
#     {'pos': 'JJ', 'word': 'give'},
#     {'pos': 'JJ', 'word': 'new'},
#     {'pos': 'NN', 'word': 'cocktail'},
#     {'pos': 'NN', 'word': 'try'},
#     {'pos': 'RB', 'word': 'gladly'},
#     {'pos': 'VBD', 'word': 'followed'},
#     {'pos': 'NNS', 'word': 'directions'},
#     {'pos': 'JJ', 'word': 'general'},
#     {'pos': 'NN', 'word': 'success'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBD', 'word': 'ended'},
#     {'pos': 'CD', 'word': '3speed'},
#     {'pos': 'JJ', 'word': 'slammed'},
#     {'pos': 'DT', 'word': 'every'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': 'VBN', 'word': 'tried'},
#     {'pos': 'VBP', 'word': 'go'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'holy'},
#     {'pos': 'MD', 'word': 'oak'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'JJ', 'word': 'little'},
#     {'pos': 'JJ', 'word': 'serendipitous'},
#     {'pos': 'NN', 'word': 'discovery'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'perfect'},
#     {'pos': 'NN', 'word': 'cocktail'},
#     {'pos': 'VBG', 'word': 'outing'},
#     {'pos': 'NN', 'word': 'emerson'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'fyi'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBZ', 'word': 'laptops'},
#     {'pos': 'CD', 'word': '9'},
#     {'pos': 'NN', 'word': 'pm'},
#     {'pos': ':', 'word': '...'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'official'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'shop'},
#     {'pos': 'NN', 'word': 'bar'},
#     {'pos': 'NN', 'word': 'transition'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 4,
#    'text': "Holy Smokes, Holy Oak!\n\nThis coffee shop cum bar transitions during the course of the day from a cozy place to study to an awesome spot for cocktails in the evening.   One of the awesome trendy spots that is transforming Bloordale to the next hip spot.\n\nThe shop is definitely casual (think normcore fashion in a restaurant).  I still wouldn't call it a dive bar though.  The dimly lit bar in the evening has a really intimate vibe to it with a just appropriate enough amount of background noise to make it feel quite pleasant.  It's homey and trendy at the same time.\n\nThe COCKTAIL list here is really pretty interesting.  I enjoyed two cocktails last time:\n1) A cynar sour.  For those of you who don't know, cynar is a liquor made from artichokes.  It's a bracing taste, but actually shockingly pleasant as a sour. They also had a few other cocktails with cynar in them.  It takes some talent to employ this potent potable.\n\n2) The Last Word.  I ordered this drink off-menu after spying bottles of both green chartreuse and maraschino liquor on the shelf.  These libations are often absent from many pretty solid bars. The super-friendly bartender was thrilled to give a new cocktail a try and gladly followed my directions for a general success. \n\nI only ended up here because 3Speed has been slammed every time I tried to go there.  Holy Oak is a great little serendipitous discovery for me.  Perfect for a cocktail before or after your outing to The Emerson.\n\nFYI, no laptops after 9 PM...that's the official time for the coffee shop to bar transition."}),
#  ('yiZ8LlOBpv5M6hIQHR9bcg',
#   {'review_words': [{'pos': 'NN', 'word': 'ok'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBP', 'word': 'know'},
#     {'pos': 'RB', 'word': 'recently'},
#     {'pos': 'VBN', 'word': 'reviewed'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'VBZ', 'word': 'keeps'},
#     {'pos': 'VBG', 'word': 'getting'},
#     {'pos': 'RBR', 'word': 'better'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'today'},
# ...
#     {'pos': 'MD', 'word': 'would'},
#     {'pos': 'VB', 'word': 'looked'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'JJ', 'word': 'special'},
#     {'pos': 'JJ', 'word': 'significant'},
#     {'pos': 'NN', 'word': 'hookah'},
#     {'pos': 'NN', 'word': 'lounge'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'tried'},
#     {'pos': '``', 'word': '``'},
#     {'pos': 'JJ', 'word': 'berried'},
#     {'pos': 'NN', 'word': 'treasure'},
#     {'pos': "''", 'word': "''"},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'surprisingly'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NN', 'word': 'combination'},
#     {'pos': 'NN', 'word': 'hookah'},
#     {'pos': 'VBG', 'word': 'smoking'},
#     {'pos': 'NN', 'word': 'night'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'literally'},
#     {'pos': 'VBD', 'word': 'came'},
#     {'pos': 'NNS', 'word': 'times'},
#     {'pos': 'JJ', 'word': '*just*'},
#     {'pos': 'VBP', 'word': 'sake'},
#     {'pos': 'VBG', 'word': 'trying'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'also'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NN', 'word': 'range'},
#     {'pos': 'NN', 'word': 'hookah'},
#     {'pos': 'RB', 'word': 'mainly'},
#     {'pos': 'NNS', 'word': 'flavors'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'notably'},
#     {'pos': 'NN', 'word': 'fruit'},
#     {'pos': 'NN', 'word': 'loop'},
#     {'pos': 'NN', 'word': 'flavor'},
#     {'pos': 'VBD', 'word': 'renowned'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'azuza'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'NN', 'word': 'neighborhood'},
#     {'pos': 'JJ', 'word': 'local'},
#     {'pos': 'NN', 'word': 'hookah'},
#     {'pos': 'NN', 'word': 'hangout'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NNS', 'word': 'nights'},
#     {'pos': 'VBP', 'word': "'ve"},
#     {'pos': 'VBD', 'word': 'went'},
#     {'pos': 'NNS', 'word': 'weekdays'},
#     {'pos': 'RB', 'word': 'pretty'},
#     {'pos': 'JJ', 'word': 'steady'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'overly'},
#     {'pos': 'VBN', 'word': 'crowded'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'dj'},
#     {'pos': 'NNS', 'word': 'plays'},
#     {'pos': 'RB', 'word': 'pretty'},
#     {'pos': 'JJ', 'word': 'diverse'},
#     {'pos': 'VBN', 'word': 'set'},
#     {'pos': 'VBZ', 'word': 'comes'},
#     {'pos': 'NN', 'word': 'music'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'RB', 'word': 'especially'},
#     {'pos': 'VBG', 'word': 'featuring'},
#     {'pos': 'JJ', 'word': 'old'},
#     {'pos': 'NN', 'word': 'school'},
#     {'pos': 'VBZ', 'word': 'hits'},
#     {'pos': 'CD', 'word': '90s'},
#     {'pos': 'JJ', 'word': 'early'},
#     {'pos': 'CD', 'word': '200s'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'check'},
#     {'pos': 'JJ', 'word': 'fine'},
#     {'pos': 'NNS', 'word': 'teas'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'VBZ', 'word': 'makes'},
#     {'pos': 'NN', 'word': 'hookah'},
#     {'pos': 'NN', 'word': 'experience'},
#     {'pos': 'NN', 'word': 'worthwhile'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 4,
#    'text': 'Their tea and chai menu is definitely something to experiment and glance over, for this is probably one of the best selling points of Azuza and if it wasn\'t for the tea, I don\'t think I would have looked at this place as any special significant hookah lounge. I tried the "Berried Treasure" tea, and it was a surprisingly good combination with the hookah we were smoking that night. I have literally came here times before *just* for the sake of trying out their tea. There is also a great range of hookah in mainly flavors, most notably the fruit loop flavor that is renowned here. \n\nAzuza is more like a neighborhood local hookah hangout, as the nights I\'ve went on the weekdays were pretty steady, but not overly crowded. There is a DJ who plays a pretty diverse set when it comes to music (especially featuring old school hits from the 90s and early 200s). Check it out for the fine teas, it really makes the hookah experience here worthwhile!'}),
#  ('yPHttdMLzY33s3mBC6HXMQ',
#   {'review_words': [{'pos': 'NN', 'word': 'place'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'JJ', 'word': 'chill'},
#     {'pos': 'JJS', 'word': 'best'},
#     {'pos': 'NN', 'word': 'spot'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'bring'},
#     {'pos': 'NNS', 'word': 'friends'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'family'},
#     {'pos': 'NN', 'word': 'body'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'dj'},
#     {'pos': 'VBG', 'word': 'hitting'},
#     {'pos': 'JJS', 'word': 'best'},
#     {'pos': 'NNS', 'word': 'beats'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'VB', 'word': 'fun'}],
#    'stars': 5,
#    'text': 'This place is really chill best spot to be at. bring the friends, family any body. DJ hitting the best beats really fun'}),
#  ('BBPnanVSq0dpnCyEMWunwA',
#   {'review_words': [{'pos': 'NN', 'word': 'dinner'},
#     {'pos': 'JJ', 'word': 'special'},
#     {'pos': 'VBD', 'word': 'consisted'},
#     {'pos': 'JJ', 'word': 'smoked'},
#     {'pos': 'NN', 'word': 'salmon'},
#     {'pos': 'NN', 'word': 'potato'},
#     {'pos': 'NN', 'word': 'salad'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'choice'},
#     {'pos': 'NN', 'word': 'soup'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'dinner'},
#     {'pos': 'NN', 'word': 'roll'},
#     {'pos': ',', 'word': ','},
#     {'pos': '``', 'word': '``'},
#     {'pos': 'VBD', 'word': 'grilled'},
#     {'pos': 'NN', 'word': 'tender'},
#     {'pos': 'NN', 'word': 'beef'},
#     {'pos': "''", 'word': "''"},
#     {'pos': 'NN', 'word': 'mushroom'},
#     {'pos': 'NN', 'word': 'wine'},
#     {'pos': 'NN', 'word': 'sauce'},
#     {'pos': 'CC', 'word': 'either'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': ':', 'word': '-'},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '17.99'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'food'},
#     {'pos': 'NN', 'word': 'decent'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'JJ', 'word': 'terrible'},
#     {'pos': 'JJ', 'word': 'overall'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NN', 'word': 'value'},
#     {'pos': 'NN', 'word': 'money'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 3,
#    'text': 'Had the dinner special which consisted of a smoked salmon potato salad, choice of soup, dinner roll, and a "grilled tender beef" with a mushroom wine sauce and either a coffee or tea - all for $17.99.  Food was decent, coffee was terrible but overall good value for the money.'}),
#  ('zBD6Al8oLppzYjFqN7qVvg',
#   {'review_words': [{'pos': 'VB', 'word': 'love'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'shop'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NN', 'word': 'energy'},
#     {'pos': 'NN', 'word': 'chi'},
#     {'pos': 'NN', 'word': 'latte'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'soo'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'JJ', 'word': 'much'},
#     {'pos': 'JJR', 'word': 'better'},
#     {'pos': 'NN', 'word': 'star'},
#     {'pos': ':', 'word': '...'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NNS', 'word': 'people'},
#     {'pos': 'VBP', 'word': 'work'},
#     {'pos': 'NN', 'word': 'kind'},
#     {'pos': 'NN', 'word': 'sweet'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'thing'},
#     {'pos': 'VB', 'word': 'recommend'},
#     {'pos': 'VB', 'word': 'take'},
#     {'pos': 'JJ', 'word': 'commercial'},
#     {'pos': 'NN', 'word': 'tech'},
#     {'pos': 'NN', 'word': 'company'},
#     {'pos': 'NN', 'word': 'tv'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBP', 'word': 'think'},
#     {'pos': 'NN', 'word': 'person'},
#     {'pos': 'VBN', 'word': 'purchased'},
#     {'pos': 'JJ', 'word': 'advertisement'},
#     {'pos': 'NN', 'word': 'tv'},
#     {'pos': 'NN', 'word': 'shop'},
#     {'pos': 'VBG', 'word': 'flashing'},
#     {'pos': 'JJ', 'word': 'devil'},
#     {'pos': 'NNS', 'word': 'symbols'},
#     {'pos': 'RB', 'word': 'covertly'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'typical'},
#     {'pos': '``', 'word': '``'},
#     {'pos': 'NN', 'word': 'illuminati'},
#     {'pos': "''", 'word': "''"},
#     {'pos': 'JJ', 'word': 'tactic'},
#     {'pos': 'NN', 'word': 'hex'},
#     {'pos': 'NN', 'word': 'goodness'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'elevate'},
#     {'pos': 'VBN', 'word': 'connected'},
#     {'pos': 'VBP', 'word': 'hope'},
#     {'pos': 'NN', 'word': 'church'},
#     {'pos': 'NN', 'word': 'lot'},
#     {'pos': 'JJ', 'word': 'humanitarian'},
#     {'pos': 'NN', 'word': 'work'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'give'},
#     {'pos': 'VBG', 'word': 'helping'},
#     {'pos': 'VB', 'word': 'provide'},
#     {'pos': 'NN', 'word': 'water'},
#     {'pos': 'NNS', 'word': 'wells'},
#     {'pos': 'CD', 'word': '3rd'},
#     {'pos': 'NN', 'word': 'world'},
#     {'pos': 'NNS', 'word': 'countries'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NNS', 'word': 'people'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'devil'},
#     {'pos': 'NN', 'word': 'satan'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NNS', 'word': 'people'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'VBP', 'word': 'try'},
#     {'pos': 'JJ', 'word': 'hex'},
#     {'pos': 'NN', 'word': 'goodness'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'look'},
#     {'pos': 'JJ', 'word': 'tech'},
#     {'pos': 'JJ', 'word': 'commercial'},
#     {'pos': 'NN', 'word': 'see'},
#     {'pos': 'NN', 'word': 'symbolism'},
#     {'pos': 'VB', 'word': 'bophet'},
#     {'pos': 'JJ', 'word': 'satanic'},
#     {'pos': 'NNS', 'word': 'god'},
#     {'pos': 'VBP', 'word': 'look'},
#     {'pos': 'JJ', 'word': 'illuminati'},
#     {'pos': 'NNS', 'word': 'symbols'},
#     {'pos': 'NN', 'word': 'satanism'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'devil'},
#     {'pos': 'NNS', 'word': 'worshipers'},
#     {'pos': 'NN', 'word': 'country'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'VB', 'word': 'see'},
#     {'pos': 'NN', 'word': 'mark'},
#     {'pos': 'IN', 'word': 'pasio'},
#     {'pos': 'NN', 'word': 'youtube'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'JJ', 'word': 'hex'},
#     {'pos': 'NNS', 'word': 'workers'},
#     {'pos': 'NNS', 'word': 'g-d'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NNS', 'word': 'people'},
#     {'pos': 'VBP', 'word': 'elevate'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': 'I love this coffee shop, such great energy and the Chi Latte\'s are soo delicious!! Much better then the Star ...coffee  The people that work there are kind and sweet. The only thing I recommend is to take down that commercial for that tech company on your TV, I think the person that purchased that advertisement on your TV in your shop is flashing devil symbols covertly. A typical "Illuminati" tactic to hex goodness. Elevate is connected with the Hope Church and they do a lot of humanitarian work. They give to helping provide water wells for 3rd world countries. They are good people. The devil and satan\'s people always try to hex goodness. Look up that tech commercial you have and see the symbolism of Bophet the satanic god and look up Illuminati symbols for Satanism. The devil worshipers own this country (see Mark Pasio on youtube) and they love to hex the workers of G-d like the good people at Elevate.'}),
#  ('SgUS_3IbUvS4KW7TaFzPVg',
#   {'review_words': [{'pos': 'JJS', 'word': 'best'},
#     {'pos': 'NN', 'word': 'latte'},
#     {'pos': 'NN', 'word': 'edinburgh'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBN', 'word': 'guaranteed'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': 'Best latte in Edinburgh, guaranteed.'}),
#  ('PbR6lv8rFpx7_g2-DIYvkQ',
#   {'review_words': [{'pos': 'NN', 'word': 'wish'},
#     {'pos': 'MD', 'word': 'could'},
#     {'pos': 'NN', 'word': 'rate'},
#     {'pos': 'JJR', 'word': 'higher'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VBD', 'word': 'impressed'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'honeydew'},
#     {'pos': 'NN', 'word': 'milk'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': 'VBD', 'word': 'lacked'},
#     {'pos': '``', 'word': '``'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': "''", 'word': "''"},
#     {'pos': 'NN', 'word': 'factor'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'basically'},
#     {'pos': 'VBN', 'word': 'tasted'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'NN', 'word': 'honeydew'},
#     {'pos': 'NN', 'word': 'powder'},
#     {'pos': 'NN', 'word': 'milk'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'macaron'},
#     {'pos': 'NN', 'word': 'ice'},
#     {'pos': 'NN', 'word': 'cream'},
#     {'pos': 'NN', 'word': 'sandwich'},
#     {'pos': 'VBZ', 'word': 'fun'},
#     {'pos': 'JJ', 'word': 'hard'},
#     {'pos': 'NN', 'word': 'eat'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'ice'},
#     {'pos': 'NN', 'word': 'cream'},
#     {'pos': 'JJ', 'word': 'soft'},
#     {'pos': 'VBZ', 'word': 'makes'},
#     {'pos': 'NN', 'word': 'macaron'},
#     {'pos': 'NNS', 'word': 'soggy'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'RB', 'word': 'however'},
#     {'pos': 'CD', 'word': '4'},
#     {'pos': 'NNS', 'word': 'stars'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'NNS', 'word': 'times'},
#     {'pos': 'JJ', 'word': 'visited'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'JJ', 'word': 'helpful'},
#     {'pos': 'RB', 'word': 'friendly'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 3,
#    'text': 'I wish I could rate them higher but I wasn\'t that impressed.\n\nTheir Honeydew Milk Tea lacked the "Tea" factor.  It basically tasted like Honeydew powder and milk.\n\nThe Macaron Ice Cream Sandwich is fun but hard to eat.  The ice cream is soft and it makes the macaron soggy.\n\nThe service however is 4 stars!!  Both times I visited the staff was helpful and friendly.'}),
#  ('tOQWHrhU0ln-w9Z6vVyO7Q',
#   {'review_words': [{'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NN', 'word': 'ice'},
#     {'pos': 'NN', 'word': 'cream'},
#     {'pos': 'NN', 'word': 'shop'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'excellent'},
#     {'pos': 'JJ', 'word': 'basic'},
#     {'pos': 'NNS', 'word': 'flavors'},
#     {'pos': 'NNS', 'word': 'mix-ins'},
#     {'pos': 'VBP', 'word': 'want'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'MD', 'word': "'d"},
#     {'pos': 'VB', 'word': 'give'},
#     {'pos': 'JJ', 'word': 'top'},
#     {'pos': 'NN', 'word': 'rating'},
#     {'pos': 'RB', 'word': 'regardless'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'owner'},
#     {'pos': 'NN', 'word': 'spartan'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'bonus'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 5,
#    'text': "This is a great ice cream shop. Excellent basic flavors and mix-ins if you want them. We'd give it a top rating regardless, but the owner is a Spartan, which is a bonus!"}),
#  ('TwYbKtxOe0NM0hPxB4B_eg',
#   {'review_words': [{'pos': 'JJ', 'word': 'fav'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'CD', 'word': '2'},
#     {'pos': 'NNS', 'word': 'reasons'},
#     {'pos': 'CD', 'word': '1'},
#     {'pos': 'NN', 'word': 'butter'},
#     {'pos': 'NN', 'word': 'brew'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'CD', 'word': '2'},
#     {'pos': 'NN', 'word': 'luke'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'JJS', 'word': 'nicest'},
#     {'pos': 'NN', 'word': 'baristas'},
#     {'pos': 'VBD', 'word': 'encountered'}],
#    'stars': 4,
#    'text': 'My fav place for 2 reasons \n\n1 Butter Brew!\n2 Luke!  one of the nicest baristas I have encountered'})]

# %%
def lemmatize(reviewDict):
    # loop through the reviews
    # get nouns and group them by lemma
    reviewCorpus = {}
    lemmatizer = nltk.WordNetLemmatizer()

    for review_count, review_content in reviewDict.items():
        nouns = []
        words = [w for w in review_content['review_words'] if w['pos'] in ['NN','NNS']]
        
        for w in words:
            nouns.append(lemmatizer.lemmatize(w['word']))
            
        reviewCorpus[review_count] = {'review_stars' : review_content['stars'], \
                                      'review_text' : review_content['text'], \
                                      'review_nouns' : nouns} 
    
    return reviewCorpus

# %%
# feed reviews to LDA model using k topics
def train(reviewDict, k):
    
    '''
    create id2word
    cannot filter extremes when the set is too small (only 1 page of yelp)
    '''
    id2word = corpora.Dictionary(reviewDict[review]["review_nouns"] for review in reviewDict)
#     id2word.filter_extremes(keep_n=10000)
#     id2word.compactify()

    corpora_dict = corpora.Dictionary(reviewDict[review]["review_nouns"] for review in reviewDict)
    corpora_dict.save('lda/dictionary.dict')
    
    corpus = [corpora_dict.doc2bow(reviewDict[review]["review_nouns"]) for review in reviewDict]
    corpora.BleiCorpus.serialize('lda/corpus.lda-c', corpus)
    corpus = corpora.BleiCorpus('lda/corpus.lda-c')
    
    if k == 50:
        # save lda model for 50 topics
        lda = gensim.models.LdaModel(corpus, num_topics=50, id2word=id2word)
        lda.save('lda/lda_50_topics.lda')
    
    elif k == 25:
        # save lda model for 25 topics
        lda = gensim.models.LdaModel(corpus, num_topics=25, id2word=id2word)
        lda.save('lda/lda_25_topics.lda')
    
    return lda

# %%
import requests
import json

def main():
    global REVIEW_DICT 
    REVIEW_DICT = reviewData 
        
    '''
    Check if the folder for the lda model exists
    If it doesnt create the folder 
    '''
    if not os.path.exists('lda'):
        os.makedirs('lda')
    
    train(lemmatize(REVIEW_DICT), 25)

    
if __name__ == '__main__':
    main()

# %%
# Get all 50 topics using K=50
WEIGHT_TOPIC = []

dictionary_path = "lda/dictionary.dict"
corpus_path = "lda/corpus.lda-c"
lda_model_path = "lda/lda_50_topics.lda"

dictionary = corpora.Dictionary.load(dictionary_path)
corpus = corpora.BleiCorpus(corpus_path)
lda = LdaModel.load(lda_model_path)

# See topics
TOPIC_DICT = dict(lda.show_topics(num_topics=50))

for topicN, topicWeights in TOPIC_DICT.items():
    print('Topic ' + str(topicN) + ' : \n' + str(topicWeights) + '\n')
# Out:
# Topic 0 :
# 0.058*"table" + 0.042*"space" + 0.029*"place" + 0.023*"chair" + 0.022*"seat" + 0.020*"lot" + 0.020*"coffee" + 0.019*"sit" + 0.018*"people" + 0.018*"seating"
#
# Topic 1 :
# 0.078*"water" + 0.040*"card" + 0.038*"half" + 0.036*"pork" + 0.024*"dollar" + 0.024*"charge" + 0.022*"cash" + 0.022*"cost" + 0.020*"ball" + 0.018*"credit"
#
# Topic 2 :
# 0.101*"game" + 0.055*"board" + 0.042*"boyfriend" + 0.032*"size" + 0.030*"room" + 0.026*"purchase" + 0.021*"girlfriend" + 0.019*"disappointment" + 0.017*"hey" + 0.016*"energy"
#
# Topic 3 :
# 0.242*"location" + 0.067*"drive" + 0.047*"thru" + 0.040*"time" + 0.035*"car" + 0.031*"service" + 0.024*"staff" + 0.015*"way" + 0.014*"line" + 0.012*"order"
#
# Topic 4 :
# 0.056*"butter" + 0.053*"pie" + 0.053*"pizza" + 0.047*"flavour" + 0.024*"cat" + 0.024*"peanut" + 0.022*"pasta" + 0.015*"crust" + 0.014*"oil" + 0.013*"balance"
#
# Topic 5 :
# 0.067*"check" + 0.047*"excellent" + 0.046*"wow" + 0.033*"neighborhood" + 0.027*"cold" + 0.021*"food" + 0.020*"jam" + 0.018*"range" + 0.016*"bottle" + 0.014*"place"
#
# Topic 6 :
# 0.175*"flavor" + 0.109*"gelato" + 0.044*"nutella" + 0.029*"pistachio" + 0.028*"sample" + 0.016*"grocery" + 0.015*"http" + 0.014*"buttery" + 0.014*"scoop" + 0.013*"texture"
#
# Topic 7 :
# 0.098*"line" + 0.061*"people" + 0.031*"time" + 0.029*"order" + 0.023*"wait" + 0.022*"person" + 0.021*"door" + 0.021*"way" + 0.020*"morning" + 0.017*"day"
#
# Topic 8 :
# 0.068*"roll" + 0.044*"bathroom" + 0.032*"yeah" + 0.029*"school" + 0.023*"spring" + 0.022*"chef" + 0.022*"keep" + 0.022*"peach" + 0.018*"haha" + 0.017*"shrimp"
#
# Topic 9 :
# 0.040*"food" + 0.032*"chicken" + 0.027*"sauce" + 0.022*"meat" + 0.021*"dish" + 0.021*"burger" + 0.021*"fry" + 0.020*"meal" + 0.017*"portion" + 0.017*"place"
#
# Topic 10 :
# 0.047*"toronto" + 0.035*"design" + 0.034*"cool" + 0.023*"cafe" + 0.023*"perfection" + 0.021*"heart" + 0.021*"guest" + 0.017*"fountain" + 0.015*"welcoming" + 0.015*"gem"
#
# Topic 11 :
# 0.196*"bagel" + 0.056*"cheese" + 0.047*"brownie" + 0.041*"convenient" + 0.037*"caramel" + 0.032*"cream" + 0.031*"rock" + 0.020*"gut" + 0.019*"p" + 0.018*"cappuccino"
#
# Topic 12 :
# 0.066*"nice" + 0.055*"staff" + 0.039*"strip" + 0.034*"afternoon" + 0.028*"mall" + 0.027*"helpful" + 0.024*"talk" + 0.022*"suggestion" + 0.019*"pleasant" + 0.018*"leaf"
#
# Topic 13 :
# 0.025*"expectation" + 0.021*"unique" + 0.020*"figure" + 0.018*"hell" + 0.017*"hype" + 0.017*"fix" + 0.017*"groupon" + 0.017*"hip" + 0.017*"appreciate" + 0.016*"kick"
#
# Topic 14 :
# 0.121*"pastry" + 0.063*"croissant" + 0.046*"cooky" + 0.046*"muffin" + 0.046*"bakery" + 0.031*"cookie" + 0.028*"almond" + 0.022*"tart" + 0.020*"item" + 0.017*"good"
#
# Topic 15 :
# 0.063*"beer" + 0.042*"wine" + 0.034*"summer" + 0.023*"state" + 0.021*"view" + 0.020*"selection" + 0.020*"list" + 0.019*"madison" + 0.019*"california" + 0.016*"hole"
#
# Topic 16 :
# 0.049*"die" + 0.040*"der" + 0.033*"da" + 0.024*"man" + 0.023*"war" + 0.020*"mit" + 0.020*"ist" + 0.015*"zu" + 0.014*"sehr" + 0.014*"ein"
#
# Topic 17 :
# 0.206*"starbucks" + 0.049*"coffee" + 0.033*"location" + 0.028*"drink" + 0.025*"staff" + 0.020*"lot" + 0.018*"time" + 0.017*"baristas" + 0.017*"area" + 0.017*"parking"
#
# Topic 18 :
# 0.169*"cake" + 0.057*"cupcake" + 0.026*"macaroon" + 0.021*"velvet" + 0.016*"moist" + 0.015*"baby" + 0.014*"birthday" + 0.014*"salt" + 0.013*"sweet" + 0.013*"dessert"
#
# Topic 19 :
# 0.161*"place" + 0.047*"coffee" + 0.033*"staff" + 0.032*"music" + 0.026*"vibe" + 0.024*"friend" + 0.023*"spot" + 0.022*"book" + 0.020*"fun" + 0.019*"hang"
#
# Topic 20 :
# 0.126*"order" + 0.124*"drink" + 0.082*"time" + 0.064*"minute" + 0.020*"girl" + 0.018*"service" + 0.015*"wait" + 0.014*"counter" + 0.012*"people" + 0.012*"get"
#
# Topic 21 :
# 0.266*"latte" + 0.065*"chai" + 0.046*"milk" + 0.043*"vanilla" + 0.037*"%" + 0.020*"caramel" + 0.019*"syrup" + 0.016*"foam" + 0.013*"taste" + 0.013*"glad"
#
# Topic 22 :
# 0.099*"business" + 0.041*"atmosphere" + 0.031*"care" + 0.029*"owner" + 0.026*"phoenix" + 0.025*"support" + 0.024*"product" + 0.023*"montreal" + 0.023*"place" + 0.023*"chain"
#
# Topic 23 :
# 0.059*"snack" + 0.046*"spice" + 0.039*"weather" + 0.038*"none" + 0.037*"winter" + 0.026*"outdoor" + 0.023*"hubby" + 0.022*"soda" + 0.020*"lavender" + 0.018*"layout"
#
# Topic 24 :
# 0.074*"food" + 0.034*"service" + 0.033*"restaurant" + 0.032*"place" + 0.028*"time" + 0.026*"menu" + 0.024*"friend" + 0.021*"group" + 0.020*"server" + 0.019*"price"
#
# Topic 25 :
# 0.190*"crepe" + 0.078*"honey" + 0.058*"strawberry" + 0.043*"banana" + 0.027*"berry" + 0.024*"savory" + 0.022*"toast" + 0.016*"fruit" + 0.015*"mountain" + 0.015*"snow"
#
# Topic 26 :
# 0.075*"vegan" + 0.050*"desert" + 0.045*"son" + 0.032*"par" + 0.029*"pot" + 0.022*".." + 0.021*"comfort" + 0.020*"gluten" + 0.020*"au" + 0.018*"coast"
#
# Topic 27 :
# 0.276*"chocolate" + 0.058*"dessert" + 0.033*"chip" + 0.014*"cheesecake" + 0.014*"bun" + 0.013*"raspberry" + 0.013*"banana" + 0.012*"creme" + 0.012*"sweet" + 0.010*"truffle"
#
# Topic 28 :
# 0.257*"star" + 0.039*"reason" + 0.036*"rating" + 0.031*"review" + 0.019*"mint" + 0.018*"sesame" + 0.016*"closing" + 0.016*"brown" + 0.014*"hair" + 0.013*"management"
#
# Topic 29 :
# 0.140*"food" + 0.103*"breakfast" + 0.078*"place" + 0.045*"service" + 0.028*"time" + 0.021*"menu" + 0.018*"staff" + 0.017*"lunch" + 0.015*"brunch" + 0.015*"spot"
#
# Topic 30 :
# 0.042*"macchiato" + 0.034*"cause" + 0.025*"post" + 0.024*"tasting" + 0.022*"blend" + 0.021*"fruity" + 0.021*"matcha" + 0.021*"patient" + 0.020*"eye" + 0.018*"venue"
#
# Topic 31 :
# 0.141*"love" + 0.077*"kid" + 0.040*"yum" + 0.032*"place" + 0.029*"family" + 0.019*"fresh" + 0.015*"city" + 0.014*"special" + 0.013*"jar" + 0.012*"cocoa"
#
# Topic 32 :
# 0.078*"hour" + 0.059*"weekend" + 0.039*"place" + 0.034*"time" + 0.024*"student" + 0.017*"food" + 0.017*"complaint" + 0.017*"evening" + 0.016*"system" + 0.014*"people"
#
# Topic 33 :
# 0.233*"tea" + 0.073*"milk" + 0.052*"place" + 0.049*"boba" + 0.046*"drink" + 0.018*"time" + 0.014*"taste" + 0.013*"flavor" + 0.010*"mango" + 0.010*"ice"
#
# Topic 34 :
# 0.141*"sandwich" + 0.057*"salad" + 0.052*"lunch" + 0.036*"bread" + 0.030*"soup" + 0.020*"food" + 0.019*"cheese" + 0.017*"place" + 0.017*"panini" + 0.016*"wrap"
#
# Topic 35 :
# 0.126*"cream" + 0.109*"donut" + 0.103*"ice" + 0.025*"place" + 0.023*"waffle" + 0.022*"flavor" + 0.013*"shop" + 0.012*"dunkin" + 0.012*"sugar" + 0.012*"time"
#
# Topic 36 :
# 0.054*"coconut" + 0.047*"tapioca" + 0.039*"slush" + 0.034*"miss" + 0.029*"cleveland" + 0.028*"disappoint" + 0.024*"grass" + 0.024*"craving" + 0.022*"refreshing" + 0.021*"bf"
#
# Topic 37 :
# 0.258*"coffee" + 0.053*"shop" + 0.040*"place" + 0.022*"cup" + 0.016*"espresso" + 0.016*"bean" + 0.013*"time" + 0.013*"staff" + 0.010*"drink" + 0.010*"house"
#
# Topic 38 :
# 0.192*"bar" + 0.073*"night" + 0.037*"station" + 0.026*"mood" + 0.024*"cocktail" + 0.019*"pm" + 0.016*"edinburgh" + 0.015*"dream" + 0.014*"inviting" + 0.013*"background"
#
# Topic 39 :
# 0.115*"place" + 0.038*"amazing" + 0.029*"friend" + 0.029*"cute" + 0.028*"fruit" + 0.023*"food" + 0.021*"recommend" + 0.019*"yummy" + 0.018*"staff" + 0.018*"quiche"
#
# Topic 40 :
# 0.147*"store" + 0.049*"doughnut" + 0.036*"pick" + 0.025*"center" + 0.024*"shopping" + 0.023*"rude" + 0.023*"hazelnut" + 0.020*"bag" + 0.020*"box" + 0.017*"valley"
#
# Topic 41 :
# 0.051*"le" + 0.046*"café" + 0.020*"je" + 0.018*"pa" + 0.017*"de" + 0.017*"la" + 0.016*"et" + 0.016*"que" + 0.015*"pour" + 0.013*"bon"
#
# Topic 42 :
# 0.110*"egg" + 0.076*"bacon" + 0.053*"toast" + 0.052*"potato" + 0.041*"breakfast" + 0.030*"sausage" + 0.022*"biscuit" + 0.020*"diner" + 0.018*"brunch" + 0.018*"salmon"
#
# Topic 43 :
# 0.068*"juice" + 0.065*"apple" + 0.041*"cinnamon" + 0.041*"orange" + 0.040*"smoothy" + 0.039*"smoothie" + 0.019*"beat" + 0.017*"cheap" + 0.016*"movie" + 0.016*"downtown"
#
# Topic 44 :
# 0.106*"customer" + 0.086*"service" + 0.035*"employee" + 0.031*"time" + 0.023*"guy" + 0.020*"manager" + 0.018*"experience" + 0.018*"day" + 0.018*"owner" + 0.015*"lady"
#
# Topic 45 :
# 0.042*"macarons" + 0.035*"ambience" + 0.030*"charlotte" + 0.026*"mediocre" + 0.023*"interior" + 0.018*"garden" + 0.015*"pricing" + 0.015*"add" + 0.014*"mark" + 0.014*"speed"
#
# Topic 46 :
# 0.093*"scone" + 0.065*"dog" + 0.033*"quaint" + 0.032*"airport" + 0.027*"con" + 0.018*"serf" + 0.017*"pro" + 0.017*"avoid" + 0.016*"mini" + 0.016*"detail"
#
# Topic 47 :
# 0.043*"im" + 0.031*"e" + 0.027*"eine" + 0.022*"einen" + 0.022*"campus" + 0.020*"potter" + 0.019*"aber" + 0.018*"gibt" + 0.017*"lecker" + 0.014*"harry"
#
# Topic 48 :
# 0.161*"vega" + 0.064*"la" + 0.051*"hotel" + 0.034*"class" + 0.031*"steak" + 0.029*"omelette" + 0.028*"quick" + 0.023*"gift" + 0.022*"trip" + 0.020*"season"
#
# Topic 49 :
# 0.024*"yesterday" + 0.018*"effort" + 0.018*"drop" + 0.017*"future" + 0.015*"establishment" + 0.015*"lack" + 0.014*"time" + 0.014*"office" + 0.013*"hope" + 0.012*"stick"

# %%
# Get all 25 topics using K=25

WEIGHT_TOPIC = []

dictionary_path = "lda/dictionary.dict"
corpus_path = "lda/corpus.lda-c"
lda_model_path = "lda/lda_25_topics.lda"

dictionary = corpora.Dictionary.load(dictionary_path)
corpus = corpora.BleiCorpus(corpus_path)
lda = LdaModel.load(lda_model_path)

# See topics
TOPIC_DICT = dict(lda.show_topics(num_topics=25))

for topicN, topicWeights in TOPIC_DICT.items():
    print('Topic ' + str(topicN) + ' : \n' + str(topicWeights) + '\n')
# Out:
# Topic 0 :
# 0.089*"place" + 0.052*"staff" + 0.031*"love" + 0.026*"pie" + 0.025*"selection" + 0.021*"music" + 0.019*"night" + 0.018*"owner" + 0.015*"day" + 0.013*"fun"
#
# Topic 1 :
# 0.147*"latte" + 0.048*"game" + 0.045*"chai" + 0.027*"croissant" + 0.025*"vanilla" + 0.025*"board" + 0.023*"almond" + 0.021*"place" + 0.020*"mocha" + 0.017*"milk"
#
# Topic 2 :
# 0.045*"time" + 0.042*"place" + 0.042*"food" + 0.034*"order" + 0.031*"service" + 0.021*"crepe" + 0.020*"minute" + 0.018*"people" + 0.014*"star" + 0.013*"wait"
#
# Topic 3 :
# 0.030*"guy" + 0.028*"smile" + 0.026*"dog" + 0.020*"lady" + 0.018*"thank" + 0.016*"airport" + 0.015*"girl" + 0.013*"yesterday" + 0.013*"counter" + 0.013*"hummus"
#
# Topic 4 :
# 0.155*"donut" + 0.030*"doughnut" + 0.020*"dozen" + 0.018*"apple" + 0.016*"dunkin" + 0.015*"shop" + 0.013*"place" + 0.012*"creme" + 0.011*"mint" + 0.010*"sugar"
#
# Topic 5 :
# 0.021*"wir" + 0.013*"vacation" + 0.012*"immer" + 0.011*"earl" + 0.011*"kale" + 0.011*"parfait" + 0.011*"frappe" + 0.010*"vor" + 0.010*"tag" + 0.009*"paradise"
#
# Topic 6 :
# 0.055*"food" + 0.025*"place" + 0.020*"restaurant" + 0.020*"service" + 0.016*"meal" + 0.015*"time" + 0.015*"menu" + 0.012*"chicken" + 0.011*"dish" + 0.010*"price"
#
# Topic 7 :
# 0.061*"place" + 0.034*"coffee" + 0.020*"table" + 0.018*"area" + 0.016*"work" + 0.014*"lot" + 0.014*"staff" + 0.014*"spot" + 0.014*"people" + 0.013*"space"
#
# Topic 8 :
# 0.086*"bagel" + 0.064*"pastry" + 0.039*"bakery" + 0.023*"bread" + 0.021*"tart" + 0.020*"cheese" + 0.017*"bun" + 0.016*"baguette" + 0.011*"crust" + 0.011*"quiche"
#
# Topic 9 :
# 0.085*"sandwich" + 0.080*"breakfast" + 0.036*"food" + 0.035*"lunch" + 0.028*"place" + 0.027*"egg" + 0.026*"salad" + 0.017*"bread" + 0.016*"bacon" + 0.016*"menu"
#
# Topic 10 :
# 0.134*"cream" + 0.108*"ice" + 0.034*"waffle" + 0.032*"place" + 0.019*"strawberry" + 0.017*"flavor" + 0.015*"dessert" + 0.013*"topping" + 0.012*"macaroon" + 0.012*"banana"
#
# Topic 11 :
# 0.123*"cake" + 0.046*"dessert" + 0.045*"cupcake" + 0.023*"brownie" + 0.019*"sweet" + 0.017*"cheesecake" + 0.016*"yum" + 0.014*"birthday" + 0.014*"bakery" + 0.012*"layer"
#
# Topic 12 :
# 0.048*"beer" + 0.038*"wine" + 0.020*"daughter" + 0.019*"turkey" + 0.015*"corn" + 0.015*"boy" + 0.013*"cash" + 0.013*"hubby" + 0.013*"bottle" + 0.012*"club"
#
# Topic 13 :
# 0.101*"flavor" + 0.046*"gelato" + 0.028*"butter" + 0.023*"taste" + 0.015*"caramel" + 0.014*"flavour" + 0.014*"peanut" + 0.013*"pistachio" + 0.012*"desert" + 0.011*"coconut"
#
# Topic 14 :
# 0.028*"die" + 0.024*"der" + 0.020*"da" + 0.018*"le" + 0.014*"ist" + 0.013*"war" + 0.013*"man" + 0.012*"café" + 0.011*"mit" + 0.011*"e"
#
# Topic 15 :
# 0.295*"chocolate" + 0.018*"bar" + 0.011*"raspberry" + 0.010*"caesar" + 0.010*"fountain" + 0.010*"dark" + 0.009*"truffle" + 0.008*"banana" + 0.008*"piece" + 0.008*"max"
#
# Topic 16 :
# 0.204*"coffee" + 0.039*"shop" + 0.036*"place" + 0.019*"cup" + 0.013*"bean" + 0.013*"espresso" + 0.012*"time" + 0.011*"drink" + 0.010*"staff" + 0.008*"cappuccino"
#
# Topic 17 :
# 0.055*"juice" + 0.031*"roll" + 0.025*"orange" + 0.023*"son" + 0.022*"cinnamon" + 0.013*"buffet" + 0.010*"form" + 0.009*"oreo" + 0.009*"app" + 0.008*"batch"
#
# Topic 18 :
# 0.183*"tea" + 0.012*"selection" + 0.012*"store" + 0.011*"cup" + 0.011*"place" + 0.011*"pot" + 0.011*"afternoon" + 0.010*"time" + 0.008*"price" + 0.007*"something"
#
# Topic 19 :
# 0.076*"cooky" + 0.064*"cookie" + 0.060*"muffin" + 0.056*"chip" + 0.040*"scone" + 0.029*"macarons" + 0.020*"blueberry" + 0.017*"chocolate" + 0.016*"salt" + 0.015*"cheddar"
#
# Topic 20 :
# 0.053*"starbucks" + 0.051*"location" + 0.040*"time" + 0.039*"service" + 0.037*"customer" + 0.032*"drink" + 0.030*"order" + 0.020*"line" + 0.020*"employee" + 0.019*"staff"
#
# Topic 21 :
# 0.108*"tea" + 0.090*"milk" + 0.083*"drink" + 0.057*"boba" + 0.049*"place" + 0.016*"sugar" + 0.016*"taste" + 0.015*"time" + 0.012*"flavor" + 0.012*"smoothie"
#
# Topic 22 :
# 0.042*"kid" + 0.016*"place" + 0.012*"class" + 0.012*"year" + 0.011*"hip" + 0.010*"yogurt" + 0.009*"station" + 0.009*"student" + 0.009*"brother" + 0.008*"college"
#
# Topic 23 :
# 0.017*"cafe" + 0.014*"wall" + 0.012*"room" + 0.011*"door" + 0.010*"market" + 0.010*"cat" + 0.009*"floor" + 0.008*"street" + 0.008*"night" + 0.008*"bar"
#
# Topic 24 :
# 0.059*"la" + 0.051*"vega" + 0.029*"lol" + 0.016*"dutch" + 0.014*"health" + 0.014*"bf" + 0.012*"tim" + 0.011*"yonge" + 0.011*"skill" + 0.010*"access"
