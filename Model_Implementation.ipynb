# %%
from bs4 import BeautifulSoup
import sys
import time
import logging
import argparse
import requests
import codecs
import urllib
import os
import requests
import json
import nltk
from nltk.corpus import stopwords
import gensim
from gensim.corpora import BleiCorpus
from gensim import corpora
from gensim.models import LdaModel
from scipy import stats
import corenlp

# %%
# K_TOPICS = 25

# if K_TOPICS == 50:
# # Topic labels for K=50 topics
# # interpreted from category weights for each topic from LDA model
#     TOPIC_LABELS = {
#     0 : 'Seating',
#     1 : 'Price/Payment',
#     2 : 'Atmosphere (people/energy)',
#     3 : 'location/convenience/service (cars, line)',
#     4 : 'savory food',
#     5 : 'Unknown #1',
#     6 : 'desserts/sweets',
#     7 : 'wait/line/order',
#     8 : 'Unknown #2',
#     9 : 'food / meat',
#     10 : 'design',
#     11 : 'convenient / easy to grab food',
#     12 : 'helpfulness/friendliness of staff',
#     13 : 'trendiness / uniqueness',
#     14 : 'bakery items / pastries',
#     15 : 'alcoholic beverages',
#     16 : 'Unknown #3',
#     17 : 'compared to Starbucks',
#     18 : 'cake / dessert',
#     19 : 'atmosphere / fun',
#     20 : 'order / waittime / service',
#     21 : 'specialty drinks (e.g. latte)',
#     22 : 'business / chain',
#     23 : 'seasonal drinks (WINTER?)',
#     24 : 'food service / servers',
#     25 : 'crepes',
#     26 : 'vegan / gluten-free? (slight)',
#     27 : 'chocolate desserts',
#     28 : 'star rating rationale?',
#     29 : 'breakfast/brunch',
#     30 : 'blended drinks (e.g. macchiato, matcha, fruit)',
#     31 : 'good for families/kids',
#     32 : 'hours / opening',
#     33 : 'tea beverages (e.g. boba)',
#     34 : 'lunch foods (sandwich, salad, soup)',
#     35 : 'ice cream, donut, waffle (sweet things)',
#     36 : 'refreshing things (coconut, tapioca, slushie)',
#     37 : 'General coffee shop (cup, bean, place)',
#     38 : 'nighttime / cocktails and bars',
#     39 : 'Would recommend the place ',
#     40 : 'Store / shopping',
#     41 : 'French cafe?',
#     42 : 'breakfast foods (eggs/bacon/toast,etc)',
#     43 : 'juice and smoothies',
#     44 : 'customer service',
#     45 : 'ambience / interior',
#     46 : 'Unknown #4',
#     47 : 'Unknown #5',
#     48 : 'Hotel cafe',
#     49 : 'Unknown #6',
#     }

# elif
# K_TOPICS == 25: 

# Topic labels for K=25 topics
# interpreted from category weights for each topic from LDA model
TOPIC_LABELS = {
0 : 'Atmosphere (place, staff, love, selection, music, fun)',
1 : 'Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
2 : 'Wait Time / Service (time, place, food, order, service, wait)',
3 : 'Staff (guy, smile, lady, girl, thank you, counter)',
4 : 'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
5 : 'Visited on Vacation (vacation, kale, parfait, frappe, paradise)',
6 : 'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
7 : 'Physical Space (place, table, area, spot, staff, parking lot, space)',
8 : 'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
9 : 'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
10 : 'Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)',
11 : 'Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
12 : 'Alcoholic Beverages (beer, wine, bottle, club)',
13 : 'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
14 : 'Unknown (die, der, da, le, ist, man)',
15 : 'Chocolates (bar, raspberry, fountain, dark, truffle)',
16 : 'Coffee – General (coffee, shop, place, cup, bean, espresso)',
17 : 'Juice (juice, roll, orange, cinnamon)',
18 : 'Tea (tea, selection, store, cup)',
19 : 'Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)',
20 : 'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
21 : 'Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)',
22 : 'Young People (kid, place, class, year, hip, student, college)',
23 : 'Room (cafe, wall, room, door, floor)',
24 : 'Misc.'
}

# %%
# # Test on an example – applying LDA model to unseen review

# def predTopics(review_text):
#     separated_text = review_text.lower().split()
    
#     # apply LDA model
#     dictionary_path = "lda/dictionary.dict"
#     corpus_path = "lda/corpus.lda-c"
    
# #     if K_TOPICS == 50:
# #         lda_model_path = "lda/lda_50_topics.lda"
# #     elif K_TOPICS == 25:
#     lda_model_path = "lda/lda_25_topics.lda"

#     dictionary = corpora.Dictionary.load(dictionary_path)
#     corpus = corpora.BleiCorpus(corpus_path)
#     lda = LdaModel.load(lda_model_path)
    
#     review_bow = dictionary.doc2bow(separated_text)
    
#     return lda[review_bow]


# # Test on an example unseen review
# unseenReview = '''I absolutely love the vibe at Render Coffee. I went there to catch up on some work for the weekend, and managed to find some nice outdoor seating. It was nearing the middle of fall, and they brilliantly have a heater outside for chillier days. 

# I opted for a hot chocolate, which was relatively pricey but was delicious. The staff were also very understanding when a fly decided to take a dip in my drink. They ended up giving me a new cup of hit chocolate, free of charge!

# I wished that I tried some of their sandwiches, I was spying what others were ordering and the sandwiches looked so good. Will definitely be back to try some. Overall, love Render, just wish it was a tad more affordable!'''

# for (topic, weight) in predTopics(unseenReview):
#     print('Review has ' + str(weight*100) + '% weight ' + 'for topic: \n' + TOPIC_LABELS[topic] + '\n')
# Out:
# Review has 21.7238966477% weight for topic:
# Atmosphere (place, staff, love, selection, music, fun)
#
# Review has 7.82228119299% weight for topic:
# Wait Time / Service (time, place, food, order, service, wait)
#
# Review has 6.52270468795% weight for topic:
# Staff (guy, smile, lady, girl, thank you, counter)
#
# Review has 2.98964361085% weight for topic:
# Food / Meals / Restaurant (food, place, restaurant, service, meal)
#
# Review has 6.08804856195% weight for topic:
# Physical Space (place, table, area, spot, staff, parking lot, space)
#
# Review has 2.46743951702% weight for topic:
# Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)
#
# Review has 2.37473897417% weight for topic:
# Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)
#
# Review has 4.28694296946% weight for topic:
# Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)
#
# Review has 9.65643902052% weight for topic:
# Alcoholic Beverages (beer, wine, bottle, club)
#
# Review has 7.09860176671% weight for topic:
# Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)
#
# Review has 2.95363605134% weight for topic:
# Unknown (die, der, da, le, ist, man)
#
# Review has 3.3952280266% weight for topic:
# Coffee – General (coffee, shop, place, cup, bean, espresso)
#
# Review has 2.80794014091% weight for topic:
# Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)
#
# Review has 5.61388337549% weight for topic:
# Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)
#
# Review has 2.47516812459% weight for topic:
# Young People (kid, place, class, year, hip, student, college)
#
# Review has 5.04343409207% weight for topic:
# Room (cafe, wall, room, door, floor)
#
# Review has 6.10854466821% weight for topic:
# Misc.

# %%
# import corenlp
# import numpy as np

# def sentimentScore(text):
#     # Before running corenlp, must start up NLP server using:
#     # java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000

#     sentences = list(filter(None, text.replace('\n','').split('.')))
#     sentimentVals = []
#     for sentence in sentences:
#         try:
#             sentimentVals.append(corenlp.sentiment_analysis_on_sentence(sentence))
#         except:
#             continue
        
#     return np.mean(sentimentVals)

# %%
# def get_reviews(theurl):
#     '''Get 20 reviews from first page of restaurant'''
#     reviewInfo = {}
    
#     stop = set(stopwords.words('english'))
    
#     main_page = requests.get(theurl)
#     if main_page.status_code == 200:
#         soup = BeautifulSoup(main_page.content, "html.parser")
#     else:
#         print('Non-200 status code. Get request for url failed.')
    
#     review_div = soup.findAll('div',{'itemprop':'review'})

#     reviewCount = 1
    
#     for i in review_div: # iterating through review_div 
#         # get review star rating
#         reviewStar = float(i.find('meta',{'itemprop':'ratingValue'}).get('content', None))

#         # get review body text
#         reviewBody = i.find('p',{'itemprop':'description'})
#         for txt in reviewBody:
#             if type(txt) != '<p>' and not str(txt).startswith('<p>'):
#                 reviewText = txt
        
#         topics = predTopics(reviewText)
#         sentiment = sentimentScore(reviewText)
        
#         reviewInfo[reviewCount] = {'review_stars' : reviewStar, \
#                                    'review_text': reviewText, \
#                                    'review_topics' : topics, \
#                                    'sentiment_score' : sentiment} 
#         reviewCount += 1
        
#     return reviewInfo

# %%
def predTopics(review_text):
    separated_text = review_text.lower().split()
    
    # apply LDA model
    dictionary_path = "lda/dictionary.dict"
    corpus_path = "lda/corpus.lda-c"

    lda_model_path = "lda/lda_25_topics.lda"

    dictionary = corpora.Dictionary.load(dictionary_path)
    corpus = corpora.BleiCorpus(corpus_path)
    lda = LdaModel.load(lda_model_path)
    
    review_bow = dictionary.doc2bow(separated_text)
    
    return lda[review_bow]

def sentimentScore(text):
    # Before running corenlp, must start up NLP server using:
    # java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000

    sentences = list(filter(None, text.replace('\n','').split('.')))
    sentimentVals = []
    for sentence in sentences:
        try:
            sentimentVals.append(corenlp.sentiment_analysis_on_sentence(sentence))
        except:
            continue
        
    return np.mean(sentimentVals)

def get_reviews(theurl):
    '''Get 20 reviews from first page of restaurant'''
    reviewInfo = {}
    
    stop = set(stopwords.words('english'))
    
    main_page = requests.get(theurl)
    if main_page.status_code == 200:
        soup = BeautifulSoup(main_page.content, "html.parser")
    else:
        print('Non-200 status code. Get request for url failed.')
    
    review_div = soup.findAll('div',{'itemprop':'review'})

    reviewCount = 1
    
    for i in review_div: # iterating through review_div 
        # get review star rating
        reviewStar = float(i.find('meta',{'itemprop':'ratingValue'}).get('content', None))

        # get review body text
        reviewBody = i.find('p',{'itemprop':'description'})
        for txt in reviewBody:
            if type(txt) != '<p>' and not str(txt).startswith('<p>'):
                reviewText = txt
        
        topics = predTopics(reviewText)
        sentiment = sentimentScore(reviewText)
        
        reviewInfo[reviewCount] = {'review_stars' : reviewStar, \
                                   'review_text': reviewText, \
                                   'review_topics' : topics, \
                                   'sentiment_score' : sentiment} 
        reviewCount += 1
        
    return reviewInfo

def getReviewData(resUrl):
    '''Return dictionary of reviews (with their extracted topics and sentiment scores)
       and the least frequent topics across all reviews for this restaurant
    '''
    resReviews = get_reviews(resUrl)
    
    resData = {}
    
    for count, items in resReviews.items():
        resData[count] = {'review_stars' : items['review_stars'],
                          'review_text' : items['review_text'],
                          'review_topics' : sorted([(t,TOPIC_LABELS[t],w) for (t,w) in items['review_topics']], key=lambda x: x[2], reverse=True),
                          'sentiment_score' : items['sentiment_score']}
        
    return resData

def getLeastFrequent(reviewData):
    topicWeightList = []
    for count, item in reviewData.items():
        this = [(i[0], i[2]) for i in item['review_topics']]
        topicWeightList.append(this)
        
    total = 0
    topicDistribution = [0 for i in range(0,25)]
    for review in topicWeightList:
        for item in review:
            index = item[0]
            topicDistribution[index] += item[1]
            total += item[1]
    topicDistribution
    topicDistDict = {}
    for i in range(len(topicDistribution)):
        topicDistDict[TOPIC_LABELS[i]] =  topicDistribution[i]/total

    leastFrequent = []
    for topic in topicDistDict.keys():
        if topicDistDict[topic] < .02:
            leastFrequent.append(topic)
            
    return leastFrequent

def topicsByWeight(data):
    '''Return list of ranked topics from highest to lowest aggregate weight on restaurant's reviews.'''
    topic_weights = {}
    
    for count, items in data.items():
        for topic in items['review_topics']:
            if topic[1] not in topic_weights:
                topic_weights[topic[1]] = topic[2]            
            else:
                topic_weights[topic[1]] += topic[2]
    
    ranked_topics = sorted(list(topic_weights.items()), key=lambda x: x[1], reverse=True)
    
    return ranked_topics

def getStats(data):
    '''Return ranked topics (by weight) and dictionary of stars/sentiment score for each topic'''
    topic_weights = {}
    stars_sentiments = {topic_name: {'sentiments':[], 'stars':[]} for n, topic_name in TOPIC_LABELS.items()}
    
    for count, items in data.items():
        for topic in items['review_topics']:
            stars_sentiments[topic[1]]['sentiments'].append(items['sentiment_score'])
            stars_sentiments[topic[1]]['stars'].append(items['review_stars'])
    
    # calculate average sentiment scores and star ratings for each topic
    for k in stars_sentiments:
        stars_sentiments[k]['sentiments'] = np.mean(stars_sentiments[k]['sentiments'])
        stars_sentiments[k]['stars'] = np.mean(stars_sentiments[k]['stars'])
        
    stars_sentiments = {topicItems[0]:topicItems[1] for topicItems in list(stars_sentiments.items()) \
                        if not np.isnan(topicItems[1]['sentiments']) and not topicItems[0] in getLeastFrequent(data)}
    
    return stars_sentiments
    
def rankBySentiment(ss_stats):
    topicSentimentsRanked = sorted([(i[0],i[1]['sentiments']) for i in list(ss_stats.items())], key=lambda x:x[1], reverse=True)
    return topicSentimentsRanked

def rankByStars(ss_stats):
    topicStarsRanked = sorted([(i[0],i[1]['stars']) for i in list(ss_stats.items())], key=lambda x:x[1], reverse=True)
    return topicStarsRanked

def regSentStars(ss_stats):
    '''Do linear regression of sentiment score on star rating.
       Return slope, intercept, r_squared, p_value, std_err of regression
    '''

    topicSentiments = [i['sentiments'] for i in list(ss_stats.values())]
    topicStars = [i['stars'] for i in list(ss_stats.values())]
    slope, intercept, r_value, p_value, std_err = stats.linregress(topicSentiments, topicStars)
    
#     print('slope : ', slope)
#     print('intercept : ', intercept)
#     print('r_squared : ', r_value**2)
#     print('p_value : ', p_value)
#     print('std_err : ', std_err)
    
    return slope, intercept, r_value**2, p_value, std_err

def sentimentGroup(n):
    '''Takes sentiment score and classifies into sentiment group'''
    if round(n, 0) == 0:
        return 'very negative ({})'.format(str(round(n,2)))
    if round(n, 0) == 1:
        return 'negative ({})'.format(str(round(n,2)))
    elif round(n, 0) == 2:
        if n < 1.75:
            return 'slightly negative ({})'.format(str(round(n,2)))
        elif n > 2.25:
            return 'slightly positive ({})'.format(str(round(n,2)))
        else:
            return 'neutral ({})'.format(str(round(n,2)))
    elif round(n, 0) == 3:
        return 'positive ({})'.format(str(round(n,2)))
    elif round(n, 0) == 4:
        return 'very positive ({})'.format(str(round(n,2)))
 
def recommend(data, sentimentRank, starRank):
    '''Prints a recommendation based on the cafe's topic sentiments and stars '''
    
#     print('People feel good about these aspects of this cafe...')
#     posFeelings = [print('* ' + topic[0].split('(')[0] + ' ({})'.format(str(topic[1]))) for topic in sentimentRank[0:3]]
#     print()
#     print("However, they don't feel so good about these aspects of this cafe...")
#     negFeelings = [print('* ' + topic[0].split('(')[0] + ' ({})'.format(str(topic[1]))) for topic in sentimentRank[-3:]]
#     print()
#     print("Ratings for reviews about these topics are high...")
#     posStars = [print('* ' + topic[0].split('(')[0] + ' ({})'.format(str(topic[1]))) for topic in starRank[0:3]]
#     print()
#     print("Reviews for reviews about these topics are low...")
#     negStars = [print('* ' + topic[0].split('(')[0] + ' ({})'.format(str(topic[1]))) for topic in starRank[-3:]]
#     print()
    
    composite = sorted([(name, (stats['sentiments'], stats['stars'])) for name, stats in getStats(data).items()], key=lambda x:x[1], reverse=True)
    
    print('RECOMMENDATION: \n')
    print('Keep up the good work with...')
    posRecc = [print('---> ' + topic[0].split('(')[0] + '(avg. sentiment: {} / avg. stars: {})'.format(sentimentGroup(topic[1][0]), round(topic[1][1], 2))) for topic in composite[0:3]]
    print()
    print('May need to make improvements where performing lowest...')
    negRecc = [print('---> ' + topic[0].split('(')[0] + '(avg. sentiment: {} / avg. stars: {})'.format(sentimentGroup(topic[1][0]), round(topic[1][1], 2))) for topic in composite[-3:]]

def predictStars(data, unseenReview):
    '''Predict star rating for a based on a review's sentiment'''
    sentiment_score = sentimentScore(unseenReview)
    print('sentiment_score : ' + str(sentiment_score))
    predStars = regSentStars(getStats(data))[1] + regSentStars(getStats(data))[0]*sentiment_score
    return predStars

# %%
cafe_data = getReviewData('https://www.yelp.com/biz/thorntons-boston')

# %%
myreview = '''We've passed this place quite a bit over the last few years and, on weekends, almost always see a long line. After wanting to try it since moving to Boston, we finally got the chance this past week. Unfortunately, I think one of my hunches about the place may have been right: the long lines are based more on Thornton's location (close proximity to hotels and the Prudential Center) than on the food itself. 

The food here was not bad, but I wouldn't call it good either. I tried the Morning Delight, which was a strange mixture of both savory (olives, mozzarella, tomatoes, and basil), and sweet ("french toast" that I wouldn't really describe as such -- it was more of a large croissant). I knew from the menu it was a weird combination, but I wanted to try something unique that I thought Thornton's would potentially be able to surprise me on. Unfortunately, they didn't know more than me -- it was just weird. 

What it lacked in taste, the food made up for in volume and cost: there was a lot of it and it was cheap. The service was also not bad. That said, the food here wasn't good enough to get me to come back, even if there wasn't a line.'''

# cafeSent = rankBySentiment(getStats(cafe_data))
# cafeStars = rankByStars(getStats(cafe_data))
# recommend(cafe_data, cafeSent, cafeStars)
# getStats(cafe_data)
# Out:
# RECOMMENDATION:
#
# Keep up the good work with...
# ---> Small Dessserts (avg. sentiment: neutral (2.06) / avg. stars: 4.0)
# ---> Atmosphere (avg. sentiment: neutral (2.05) / avg. stars: 4.0)
# ---> Wait Time / Service (avg. sentiment: neutral (2.03) / avg. stars: 3.75)
#
# May need to make improvements where performing lowest...
# ---> Juice (avg. sentiment: neutral (1.77) / avg. stars: 3.6)
# ---> Food / Meals / Restaurant (avg. sentiment: neutral (1.75) / avg. stars: 3.64)
# ---> Customer Service (avg. sentiment: slightly negative (1.7) / avg. stars: 3.33)

# %%
# Test on multiple reviews for a particular coffee place
pavementUrl = 'https://www.yelp.com/biz/pavement-coffeehouse-boston'
pavementReviews = get_reviews(pavementUrl)

# %%
pavementData = {}

for count, items in pavementReviews.items():
    pavementData[count] = {'review_stars' : items['review_stars'],
                           'review_text' : items['review_text'],
                           'review_topics' : sorted([(t,TOPIC_LABELS[t],w) for (t,w) in items['review_topics']], key=lambda x: x[2], reverse=True),
                           'sentiment_score' : items['sentiment_score']}
    
pavementData
# Out:
# {1: {'review_stars': 4.0,
#   'review_text': 'Pavement has a calm, jazzy vibe to it. It feels light and relaxed where you can enjoy a nice conversation with someone without feeling cramped by students with papers and laptops. The decor is really nice and simplistic. I adored the boho colorful tabletops, and I almost wanted to ask where they were from. \n\nI ordered a Spanish latte and received a deliciously light and foamy latte. The barista was pretty accurate pressing down the espresso, and you could tell he was pretty skilled in latte art as he left me a lovely flower in my latte. \n\nI wish they had more choices for specialty lattes. They only had the basics of vanilla, Spanish, chai, etc.',
#   'review_topics': [(0,
#     'Atmosphere (place, staff, love, selection, music, fun)',
#     0.16269280761366453),
#    (22,
#     'Young People (kid, place, class, year, hip, student, college)',
#     0.090965474072581085),
#    (1,
#     'Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#     0.085834709834324951),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.082516603478827624),
#    (2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.074844084989157483),
#    (18, 'Tea (tea, selection, store, cup)', 0.066676040829383887),
#    (11,
#     'Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
#     0.058836875909712864),
#    (7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.056498879768059396),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.052859098245278825),
#    (10,
#     'Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)',
#     0.052680306419673556),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.049822279574438237),
#    (4,
#     'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#     0.029873631224563928),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.027852098593894301),
#    (14, 'Unknown (die, der, da, le, ist, man)', 0.027691072684310765),
#    (6,
#     'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#     0.025755898442659218),
#    (24, 'Misc.', 0.024248696613732357),
#    (12,
#     'Alcoholic Beverages (beer, wine, bottle, club)',
#     0.023951441705179637)],
#   'sentiment_score': 2.25},
#  2: {'review_stars': 4.0,
#   'review_text': "Fresh bagels, polite staff, cool vibe, good coffee \n\nStopped in here before exploring the city for the day and ordered a few coffees and bagels. The lox bagel had a good amount of salmon on it, and the multigrain with cream cheese was LOADED with cream cheese (a little overloaded to be honest). The vanilla latte was good, and the iced coffee had a sort of unique nutty flavor. \n\nThe place was loaded with college kids (near Harvard and MIT) and I'm sure it's a good place to study. \n\nNothing overly special, but it was good.",
#   'review_topics': [(16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.29308558520286632),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.14918787517954421),
#    (10,
#     'Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)',
#     0.12502047892595025),
#    (0,
#     'Atmosphere (place, staff, love, selection, music, fun)',
#     0.10482345322966811),
#    (4,
#     'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#     0.075486830659142787),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.059947546964063354),
#    (23, 'Room (cafe, wall, room, door, floor)', 0.034840551035112848),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.032992030754873225),
#    (11,
#     'Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
#     0.032434033775628437),
#    (18, 'Tea (tea, selection, store, cup)', 0.030593333293242674),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.026852796376968389),
#    (17, 'Juice (juice, roll, orange, cinnamon)', 0.022052557771951933)],
#   'sentiment_score': 2.2000000000000002},
#  3: {'review_stars': 4.0,
#   'review_text': "Larger than the Pavement in Allston, smaller than the one near Symphony, but every Pavement is pretty consistent with their offerings, and I usually go for a nice chai latte.\n\nMiddle of the afternoon, it was completely packed with mostly students, but we were able to swipe a table of two and stayed for about 2 hours. Free wifi and tons of outlets, but space is a little tighter than other locations and our table was a little wobbly that wasn't a huge still but definitely noticeable.",
#   'review_topics': [(7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.17279127478609785),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.1277454660533725),
#    (16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.096855115589012677),
#    (24, 'Misc.', 0.094587739087398717),
#    (1,
#     'Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#     0.076864261265515044),
#    (4,
#     'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#     0.063356432814587096),
#    (2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.060883653314714924),
#    (0,
#     'Atmosphere (place, staff, love, selection, music, fun)',
#     0.058625309256205745),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.051137101408263844),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.048389963877453424),
#    (19,
#     'Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)',
#     0.048133050964292157),
#    (12,
#     'Alcoholic Beverages (beer, wine, bottle, club)',
#     0.043101603358378704),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.039751250445942597)],
#   'sentiment_score': 1.3333333333333333},
#  4: {'review_stars': 3.0,
#   'review_text': 'It is a ok experience in this coffee house---to be honest, I do think it is a bit overrated. I had a espresso and a sandwich as brunch there. I ordered the sandwich just because of its name---Hamlet---I am a Shakespeare fan.',
#   'review_topics': [(16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.24442177076588417),
#    (14, 'Unknown (die, der, da, le, ist, man)', 0.1772333768365921),
#    (22,
#     'Young People (kid, place, class, year, hip, student, college)',
#     0.15139805045168667),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.13297488158501072),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.096074631939687613),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.089361322087693568),
#    (6,
#     'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#     0.074250252042966577)],
#   'sentiment_score': 2.0},
#  5: {'review_stars': 5.0,
#   'review_text': 'Great spot! I was at a conference at Copley place and wanted to not eat so corporate and also escape the crazy lines of the conference center. This was a very close walk, about ten minutes. \n\nI also wanted to be sure I got a good vegan meal, and was happy this place had a few options. They let me get a breakfast sandwich for lunch which i was stoked for. Coffee is great, Counter a culture brewed so felt like a slice of home. Do beware it may be tough to find a seat (so if you see and open one, grab it)- Many students there studying. \n\nGreat cheap-ish option very close to the Copley Place!',
#   'review_topics': [(7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.17579384247548696),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.14619410585231901),
#    (2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.13800617682576535),
#    (24, 'Misc.', 0.093205499051105145),
#    (12,
#     'Alcoholic Beverages (beer, wine, bottle, club)',
#     0.085316872671238733),
#    (4,
#     'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#     0.073619363879673105),
#    (18, 'Tea (tea, selection, store, cup)', 0.065631418879404962),
#    (22,
#     'Young People (kid, place, class, year, hip, student, college)',
#     0.062875376822937923),
#    (14, 'Unknown (die, der, da, le, ist, man)', 0.060138697543386493),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.035288752183216407),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.028229296894636369),
#    (1,
#     'Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#     0.025300596918854553)],
#   'sentiment_score': 2.2857142857142856},
#  6: {'review_stars': 4.0,
#   'review_text': "Coffee is good, though is a little acidic for my taste. I like writing/studying here because it's cozy but it can get pretty crowded and loud! So if you want to be productive, come early :) I also like the food they offer, particularly the lox bagel. It's 9 bucks though, so I don't get it quite often. But it's worth it!",
#   'review_topics': [(7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.2167081964800551),
#    (16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.21286047975218719),
#    (24, 'Misc.', 0.20036198536439964),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.17542255333542522),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.10114174551347453),
#    (17, 'Juice (juice, roll, orange, cinnamon)', 0.064274270319611776)],
#   'sentiment_score': 2.0},
#  7: {'review_stars': 3.0,
#   'review_text': "This place is so close to Northeastern but I didn't get a chance to go until last semester! It's a very hipster place and gets pretty crowded in the afternoons with everyone using it as a study place so I usually tend to avoid it. \n\nI came in one morning because I was really craving a breakfast bagel and ordered the Sunrise with bacon and red onions on an everything bagel. It was okay. Definitely not the best breakfast bagel in the world but not the worst. I may come back to use this place as a study space as it is pretty cute and cozy but I wouldn't go here to satisfy my breakfast bagel cravings.",
#   'review_topics': [(7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.31828909950205386),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.1120715419891835),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.096375475552327367),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.082165092642888696),
#    (24, 'Misc.', 0.076066846474377101),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.070287993935448434),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.051654450406009599),
#    (0,
#     'Atmosphere (place, staff, love, selection, music, fun)',
#     0.046854847186264474),
#    (23, 'Room (cafe, wall, room, door, floor)', 0.045452298053730099),
#    (4,
#     'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#     0.045420003984729153),
#    (15,
#     'Chocolates (bar, raspberry, fountain, dark, truffle)',
#     0.025013356250585823),
#    (18, 'Tea (tea, selection, store, cup)', 0.021682327354567991)],
#   'sentiment_score': 1.2},
#  8: {'review_stars': 4.0,
#   'review_text': 'I came here because its one of the few places opens at 7am and near Anime Boston buildings, I ordered sunrise breakfast bagel and latte, total about 10 bucks. the latte is smooth and the sandwich has fresh ingredients. 10 bucks for breakfast combo sounds a little high but they made it lives up with it.',
#   'review_topics': [(8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.17090570571887176),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.13917584438104427),
#    (4,
#     'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#     0.12974665485310127),
#    (0,
#     'Atmosphere (place, staff, love, selection, music, fun)',
#     0.095754477805570615),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.091431458884764991),
#    (16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.080102517242111426),
#    (11,
#     'Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
#     0.066565122640207003),
#    (24, 'Misc.', 0.055771798912330896),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.05239194568552466),
#    (7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.047903736670634259),
#    (1,
#     'Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#     0.045902911116537715)],
#   'sentiment_score': 2.3333333333333335},
#  9: {'review_stars': 3.0,
#   'review_text': "Great place for a vanilla latte! It wasn't too sweet but I'm sure you can adjust the level to your liking with the barista. Staff are nice and friendly!\n\nI wasn't blown away by breakfast sandwich I got though. It was very greasy and the bagel wasn't toasted enough- it just tasted really bready and dense to me and was lacking some sauce since it was so dry.\n\nSpace is also very limited- seems like a student hangout, even on weekends so it may be hard to find seating!",
#   'review_topics': [(7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.17888687967784342),
#    (18, 'Tea (tea, selection, store, cup)', 0.16246775566067848),
#    (12, 'Alcoholic Beverages (beer, wine, bottle, club)', 0.1430677783961975),
#    (24, 'Misc.', 0.096433530211144647),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.09602887062870441),
#    (6,
#     'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#     0.09424324766328597),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.073640216270412173),
#    (1,
#     'Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#     0.038670558235673787),
#    (4,
#     'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#     0.037268521362382741),
#    (19,
#     'Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)',
#     0.03356577326945042),
#    (14, 'Unknown (die, der, da, le, ist, man)', 0.031367894262191061)],
#   'sentiment_score': 1.5},
#  10: {'review_stars': 5.0,
#   'review_text': "Fabulous cortado. Rich. Smooth. Delicious.  \n\nCute place.  But I'm just grading the coffee and it doesn't get much better than this. \n\nA wee bit pricey. Worth it.",
#   'review_topics': [(0,
#     'Atmosphere (place, staff, love, selection, music, fun)',
#     0.18297846373240129),
#    (16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.17915916407252153),
#    (7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.1306642292490125),
#    (24, 'Misc.', 0.10401479186388279),
#    (18, 'Tea (tea, selection, store, cup)', 0.097150024790090231),
#    (21,
#     'Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)',
#     0.092931827785598373),
#    (11,
#     'Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
#     0.087643510138691233),
#    (22,
#     'Young People (kid, place, class, year, hip, student, college)',
#     0.082957988362652488)],
#   'sentiment_score': 2.125},
#  11: {'review_stars': 5.0,
#   'review_text': 'This is the best place to study or work with coffee!\n\nThe reason why I said, there were many outlet you which you can charge and were enough seats. The mood was calm even there were a lot of people. And also furniture was so pretty. \n\nI ordered chocolate croissants and iced coffee latte. These were awesome. \n\nI saw many people ordered bagel sandwiches. I would like to get it next time!',
#   'review_topics': [(7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.33013063868868558),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.19848828446974567),
#    (2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.13141959206402551),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.087603275283283225),
#    (24, 'Misc.', 0.068782504433039196),
#    (16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.067851406117280313),
#    (15,
#     'Chocolates (bar, raspberry, fountain, dark, truffle)',
#     0.047899568886505803),
#    (12,
#     'Alcoholic Beverages (beer, wine, bottle, club)',
#     0.047824730055084405)],
#   'sentiment_score': 2.1428571428571428},
#  12: {'review_stars': 5.0,
#   'review_text': "For me this was definitely my kind of coffeehouse!  Well I don't drink actual coffee, so I love it when they have other options, especially tea options.  \n\nMy husband and I were looking for a place to sit down, rest, re-energize and get on the internet for awhile.  Pavement was the perfect place for that!  They had a handful of teas to choose from.  I got the the blueberry rooibus and the husband got the mint green tea.  Both were so refreshing!  I loved the blueberry tea so much I went back to get more!  I also had a toffee cookie for a snack and to satisfy my sweet tooth and it was oh so good too! \n\nThey had a ton of other options if you are looking for a bite to eat or a special drink.  The internet was working great even though there were people all throughout with their noses buried in their machines. \n\nPavement was awesome and if I lived in the area I could see myself becoming a regular here!",
#   'review_topics': [(7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.23071823622154264),
#    (24, 'Misc.', 0.16153304685853639),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.14972631587854374),
#    (4,
#     'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#     0.083060160916003586),
#    (18, 'Tea (tea, selection, store, cup)', 0.069391875177295864),
#    (19,
#     'Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)',
#     0.062468293608006285),
#    (12, 'Alcoholic Beverages (beer, wine, bottle, club)', 0.06185121297489854),
#    (21,
#     'Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)',
#     0.037797342316712862),
#    (2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.034445073622222037),
#    (6,
#     'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#     0.031650406326122503),
#    (14, 'Unknown (die, der, da, le, ist, man)', 0.020450485476134091),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.019885571133333359),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.016721897609473388),
#    (23, 'Room (cafe, wall, room, door, floor)', 0.01443341521379074)],
#   'sentiment_score': 2.1428571428571428},
#  13: {'review_stars': 4.0,
#   'review_text': "The Spanish latte that I ordered was without a doubt sweet but it wasn't obnoxiously sweet, which was great. I think I may have come in during a lull in the afternoon as when I arrived but when I looked around a few hours later it was packed. I'm guilty of being the type of person to sit down in a coffeeshop for hours to work but if it's any compliment Pavement is definitely a place I'd do it again. Lots of outlets, and if you're not in need of any wifi, definitely very productive for studying.\n\nA warning: free wifi for two hours so plan your productivity accordingly!",
#   'review_topics': [(24, 'Misc.', 0.13698705813277509),
#    (7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.13681847034023445),
#    (18, 'Tea (tea, selection, store, cup)', 0.13640330205459358),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.13329002720323552),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.13105337241350634),
#    (6,
#     'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#     0.061463306123011256),
#    (12,
#     'Alcoholic Beverages (beer, wine, bottle, club)',
#     0.057384517738736575),
#    (22,
#     'Young People (kid, place, class, year, hip, student, college)',
#     0.053764842290745268),
#    (1,
#     'Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#     0.034511848639876427),
#    (14, 'Unknown (die, der, da, le, ist, man)', 0.033604981279001689),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.026858601510632955),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.02528062715218627),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.022366279163038804)],
#   'sentiment_score': 1.0},
#  14: {'review_stars': 3.0,
#   'review_text': "I came here for the Spanish latte, I wanted to love it and live for it, but I unfortunately didn't. Sure, I didn't think it was horrible, but I just didn't fall in love with the flavors the way that others had fell in love with the latte. Very crowded, hard to find seating for two people had to stand around awkwardly in the hopes that two spaces would open up. Friendly staff, just would not go out of my way to study here.",
#   'review_topics': [(7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.2871803920302391),
#    (5,
#     'Visited on Vacation (vacation, kale, parfait, frappe, paradise)',
#     0.150075332433074),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.12966446838753246),
#    (0,
#     'Atmosphere (place, staff, love, selection, music, fun)',
#     0.094998687854185304),
#    (12,
#     'Alcoholic Beverages (beer, wine, bottle, club)',
#     0.080519081698920969),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.057282206764623027),
#    (18, 'Tea (tea, selection, store, cup)', 0.055695283669415063),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.045480067594363002),
#    (6,
#     'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#     0.045248731220246426),
#    (24, 'Misc.', 0.036208689521885183)],
#   'sentiment_score': 1.0},
#  15: {'review_stars': 4.0,
#   'review_text': "I am a regular here. In general the staff are great- friendly and pleasant. It's a place for middle aged hipsters to extend their range by hanging with Berkeley School of Music students. Everybody wins!\n\nJust one odd thing. Some of the staff refuse to serve the oatmeal that I have been eating there for years. Why they do this, I do not know. But it's a bit annoying and I would think that management would be more than a little annoyed at this weird habit.",
#   'review_topics': [(22,
#     'Young People (kid, place, class, year, hip, student, college)',
#     0.15376052480758184),
#    (7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.11158713243890138),
#    (16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.11004998421446897),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.097718405624075411),
#    (2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.09599315669838196),
#    (14, 'Unknown (die, der, da, le, ist, man)', 0.080025866963547382),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.076801075607633246),
#    (0,
#     'Atmosphere (place, staff, love, selection, music, fun)',
#     0.062066028032007142),
#    (12, 'Alcoholic Beverages (beer, wine, bottle, club)', 0.03486189792499314),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.034733663929314734),
#    (19,
#     'Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)',
#     0.034407524426736863),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.034040915050435445),
#    (17, 'Juice (juice, roll, orange, cinnamon)', 0.033142893937664425),
#    (15,
#     'Chocolates (bar, raspberry, fountain, dark, truffle)',
#     0.030578372203511887)],
#   'sentiment_score': 1.7142857142857142},
#  16: {'review_stars': 1.0,
#   'review_text': "First time trying Pavement. Drip coffee had a sour, lemony taste which was either intentional or the cream was sour. I don't know which scenario is worse.",
#   'review_topics': [(16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.26401816914763593),
#    (23, 'Room (cafe, wall, room, door, floor)', 0.24803902508708145),
#    (10,
#     'Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)',
#     0.12151672597201475),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.11002004634980686),
#    (6,
#     'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#     0.10277663998042759),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.099343679169410309)],
#   'sentiment_score': 1.3333333333333333},
#  17: {'review_stars': 3.0,
#   'review_text': "Came around 6 with a friend and we both ordered  a spanish latte. I was looking at the menu and debating what I should get and there was nobody in front of me but the person at the register didn't bother to greet me or ask me if I was ready to order. Even when I decided, I had to wait for him because he kept fumbling around and even left for a few minutes. There were 2 other employees who I assumed were in charge of making the drinks but they didn't greet either. After a few minutes standing there, the employee finally took my order. I'm not super picky about service but I was a bit ticked off. \n\nWhen me and my friends both got our drinks at the front, they didn't have the lids on so I saw that one had a nice ish latte design on it and the other was a poorly made design. I don't know if the barista was inconsistent or if two different people made it but either way I was not too happy. I didn't even bother taking a photo of mine. \n\nService aside, the spanish latte was pretty good but it was a bit too sweet, especially when it cooled down you can really taste how sweet it was. The place was pretty and I like the interior as well as the atmosphere of the place. It has a very hipstery-feel to it and a lot of college students seem to chill here. Seems like a  nice place to chill and drink coffee. I wouldn't mind trying other drinks and chilling here but service is just average.",
#   'review_topics': [(2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.17442802036207372),
#    (7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.10903232942297922),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.096409831891725764),
#    (12,
#     'Alcoholic Beverages (beer, wine, bottle, club)',
#     0.075199559861244478),
#    (14, 'Unknown (die, der, da, le, ist, man)', 0.065194255945954169),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.055518227014560641),
#    (23, 'Room (cafe, wall, room, door, floor)', 0.052711560524485626),
#    (24, 'Misc.', 0.05165100362289974),
#    (22,
#     'Young People (kid, place, class, year, hip, student, college)',
#     0.049489344180846349),
#    (11,
#     'Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
#     0.049415742787112318),
#    (1,
#     'Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#     0.045731226538209248),
#    (6,
#     'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#     0.045581426966641428),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.03773098780766436),
#    (18, 'Tea (tea, selection, store, cup)', 0.028333138668927685),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.022890928465245219),
#    (10,
#     'Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)',
#     0.021126943494264007),
#    (21,
#     'Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)',
#     0.016820429709764384)],
#   'sentiment_score': 1.4285714285714286},
#  18: {'review_stars': 1.0,
#   'review_text': "I remember when this place used to be good....so disappointed that it no longer is. \n\nI've never really liked the coffee, it has a kinda of burnt spit flavor, like something that's been left to rot, but at least they had bagels with an assortment of vegan cream cheeses! Well, now you get one option for vegan cream cheese, and it's usually just a small dollop on an under-toasted bagel. But I kept coming back, despite being underwhelmed and even upset with my food every time. \n\nNow it's the last straw, when I ordered on my last visit I was treated as if I were demanding a sesame bagel with the sesames pulled off. All I got was a latte!!\n\nI know working in a coffee shop is hard, I was a barista for 6 years, and I'm still a waitress, but you cannot treat all customers like jerks. You will lose business and the negativity will eat away at you too. I just can't support a business that so clearly just wants a profit and I'm guessing pays their workers minimum wage based on the attitudes. I will not miss this place.",
#   'review_topics': [(20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.11517289562141675),
#    (16,
#     'Coffee – General (coffee, shop, place, cup, bean, espresso)',
#     0.10799396000025686),
#    (2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.071379807477211427),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.070794488801853059),
#    (22,
#     'Young People (kid, place, class, year, hip, student, college)',
#     0.065453734367622626),
#    (23, 'Room (cafe, wall, room, door, floor)', 0.063693235495593775),
#    (10,
#     'Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)',
#     0.062304463737486361),
#    (4,
#     'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#     0.053001876069950715),
#    (12,
#     'Alcoholic Beverages (beer, wine, bottle, club)',
#     0.049685941171686336),
#    (18, 'Tea (tea, selection, store, cup)', 0.045699416499458925),
#    (3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.042669780522177223),
#    (9,
#     'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#     0.039981048785043362),
#    (15,
#     'Chocolates (bar, raspberry, fountain, dark, truffle)',
#     0.037801472634481414),
#    (17, 'Juice (juice, roll, orange, cinnamon)', 0.035273778455065928),
#    (6,
#     'Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#     0.034958966700091437),
#    (11,
#     'Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
#     0.030215866252922108),
#    (24, 'Misc.', 0.020629525963050416),
#    (14, 'Unknown (die, der, da, le, ist, man)', 0.019793488215016787),
#    (8,
#     'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#     0.015718192505619517),
#    (21,
#     'Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)',
#     0.015425119547132785)],
#   'sentiment_score': 1.2222222222222223},
#  19: {'review_stars': 4.0,
#   'review_text': "Lattes are tasty. Green tea ones even more so. It's a pretty small place, but we were able to get seats. Would definitely go back for more.",
#   'review_topics': [(3,
#     'Staff (guy, smile, lady, girl, thank you, counter)',
#     0.24794353049956583),
#    (18, 'Tea (tea, selection, store, cup)', 0.20076657140937826),
#    (2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.18055951208284091),
#    (7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.12431952651273999),
#    (12, 'Alcoholic Beverages (beer, wine, bottle, club)', 0.10089773773234394),
#    (23, 'Room (cafe, wall, room, door, floor)', 0.082179788425520525)],
#   'sentiment_score': 2.5},
#  20: {'review_stars': 4.0,
#   'review_text': "Pavement is an awesome place to go study or meet up with friends. Its super convenient that one is located around every campus in Boston. It's a bit pricey, but definitely worth it considering it tastes ten time better than a regular coffee from Starbucks",
#   'review_topics': [(7,
#     'Physical Space (place, table, area, spot, staff, parking lot, space)',
#     0.43728528901297947),
#    (13,
#     'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#     0.15264554413946871),
#    (20,
#     'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#     0.11055669222079162),
#    (24, 'Misc.', 0.1086289190074155),
#    (2,
#     'Wait Time / Service (time, place, food, order, service, wait)',
#     0.09933905227137417),
#    (22,
#     'Young People (kid, place, class, year, hip, student, college)',
#     0.05850102508416459)],
#   'sentiment_score': 3.0}}

# %%
# pavementDataRefined = {}
# for count, items in pavementData.items():
#     weightMedian = np.median([tup[2] for tup in items['review_topics']])
#     refinedTopics = [(num,name,w) for (num,name,w) in items['review_topics'] if w > weightMedian]
    
#     pavementDataRefined[count] = {'review_stars' : items['review_stars'],
#                                    'review_text' : items['review_text'],
#                                    'review_topics' : sorted(refinedTopics, key=lambda x: x[2], reverse=True),
#                                     'sentiment_score' : items['sentiment_score']}
# pavementData = pavementDataRefined

# %%
pavementTopicWeights = {}
topicStarsSentiments = {topic_name: {'sentiments':[], 'stars':[]} for n, topic_name in TOPIC_LABELS.items()}

# topicSentiments = {topic_name: [] for n, topic_name in TOPIC_LABELS.items()}
# topicStars = {topic_name: [] for n, topic_name in TOPIC_LABELS.items()}

for count, items in pavementData.items():
    for topic in items['review_topics']:
        if topic[1] not in pavementTopicWeights:
            pavementTopicWeights[topic[1]] = topic[2]            
        else:
            pavementTopicWeights[topic[1]] += topic[2]
        
        topicStarsSentiments[topic[1]]['sentiments'].append(items['sentiment_score'])
        topicStarsSentiments[topic[1]]['stars'].append(items['review_stars'])

pavementRankedTopics = sorted(list(pavementTopicWeights.items()), key=lambda x: x[1], reverse=True)

# calculate average sentiment scores and star ratings for each topic
for k in topicStarsSentiments:
    topicStarsSentiments[k]['sentiments'] = np.mean(topicStarsSentiments[k]['sentiments'])
    topicStarsSentiments[k]['stars'] = np.mean(topicStarsSentiments[k]['stars'])
    
# topicSentimentsRanked = sorted([item for item in topicSentiments.items()], key=lambda x: x[1], reverse=True)
# topicStarsRanked = sorted([item for item in topicStars.items()], key=lambda x: x[1], reverse=True)

topicStarsSentiments = {topicItems[0]:topicItems[1] for topicItems in list(topicStarsSentiments.items()) \
                        if not np.isnan(topicItems[1]['sentiments'])}
topicStarsSentiments
# Out:
# {'Alcoholic Beverages (beer, wine, bottle, club)': {'sentiments': 1.7099867724867723,
#   'stars': 3.75},
#  'Atmosphere (place, staff, love, selection, music, fun)': {'sentiments': 1.7694940476190477,
#   'stars': 3.875},
#  'Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)': {'sentiments': 1.6918470418470419,
#   'stars': 3.2727272727272729},
#  'Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)': {'sentiments': 1.9265211640211639,
#   'stars': 3.5},
#  'Chocolates (bar, raspberry, foundtain, dark, truffle)': {'sentiments': 1.5698412698412698,
#   'stars': 3.25},
#  'Coffee – General (coffee, shop, place, cup, bean, espresso)': {'sentiments': 1.8404365079365079,
#   'stars': 3.5},
#  'Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)': {'sentiments': 1.6726190476190477,
#   'stars': 4.0},
#  'Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)': {'sentiments': 1.8187169312169311,
#   'stars': 3.5833333333333335},
#  'Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)': {'sentiments': 1.8297178130511464,
#   'stars': 3.6666666666666665},
#  'Food / Meals / Restaurant (food, place, restaurant, service, meal)': {'sentiments': 1.5418871252204585,
#   'stars': 3.0},
#  'Juice (juice, roll, orange, cinnamon)': {'sentiments': 1.7841269841269842,
#   'stars': 3.25},
#  'Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)': {'sentiments': 1.7329931972789117,
#   'stars': 3.8571428571428572},
#  'Misc.': {'sentiments': 1.7975925925925924, 'stars': 3.7999999999999998},
#  'Physical Space (place, table, area, spot, staff, parking lot, space)': {'sentiments': 1.8722470238095239,
#   'stars': 4.0},
#  'Room (cafe, wall, room, door, floor)': {'sentiments': 1.7181405895691608,
#   'stars': 3.0},
#  'Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)': {'sentiments': 1.5887566137566136,
#   'stars': 3.3333333333333335},
#  'Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)': {'sentiments': 1.6868253968253968,
#   'stars': 2.6000000000000001},
#  'Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)': {'sentiments': 1.7296626984126984,
#   'stars': 3.5},
#  'Staff (guy, smile, lady, girl, thank you, counter)': {'sentiments': 1.7578798185941042,
#   'stars': 3.7142857142857144},
#  'Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)': {'sentiments': 1.7520757020757018,
#   'stars': 3.6153846153846154},
#  'Tea (tea, selection, store, cup)': {'sentiments': 1.7378637566137565,
#   'stars': 3.6666666666666665},
#  'Unknown (die, der, da, le, ist, man)': {'sentiments': 1.7270723104056434,
#   'stars': 3.5555555555555554},
#  'Visited on Vacation (vacation, kale, parfait, frappe, paradise)': {'sentiments': 1.0,
#   'stars': 3.0},
#  'Wait Time / Service (time, place, food, order, service, wait)': {'sentiments': 2.0019841269841274,
#   'stars': 3.8999999999999999},
#  'Young People (kid, place, class, year, hip, student, college)': {'sentiments': 1.8917548500881836,
#   'stars': 3.6666666666666665}}

# %%
# rank topic by star rating
topicSentimentsRanked = sorted([(i[0],i[1]['sentiments']) for i in list(topicStarsSentiments.items())], key=lambda x:x[1], reverse=True)
topicSentimentsRanked
# Out:
# [('Wait Time / Service (time, place, food, order, service, wait)',
#   2.0019841269841274),
#  ('Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
#   1.9265211640211639),
#  ('Young People (kid, place, class, year, hip, student, college)',
#   1.8917548500881836),
#  ('Physical Space (place, table, area, spot, staff, parking lot, space)',
#   1.8722470238095239),
#  ('Coffee – General (coffee, shop, place, cup, bean, espresso)',
#   1.8404365079365079),
#  ('Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#   1.8297178130511464),
#  ('Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#   1.8187169312169311),
#  ('Misc.', 1.7975925925925924),
#  ('Juice (juice, roll, orange, cinnamon)', 1.7841269841269842),
#  ('Atmosphere (place, staff, love, selection, music, fun)',
#   1.7694940476190477),
#  ('Staff (guy, smile, lady, girl, thank you, counter)', 1.7578798185941042),
#  ('Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#   1.7520757020757018),
#  ('Tea (tea, selection, store, cup)', 1.7378637566137565),
#  ('Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#   1.7329931972789117),
#  ('Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)',
#   1.7296626984126984),
#  ('Unknown (die, der, da, le, ist, man)', 1.7270723104056434),
#  ('Room (cafe, wall, room, door, floor)', 1.7181405895691608),
#  ('Alcoholic Beverages (beer, wine, bottle, club)', 1.7099867724867723),
#  ('Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#   1.6918470418470419),
#  ('Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)',
#   1.6868253968253968),
#  ('Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)',
#   1.6726190476190477),
#  ('Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#   1.5887566137566136),
#  ('Chocolates (bar, raspberry, foundtain, dark, truffle)', 1.5698412698412698),
#  ('Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#   1.5418871252204585),
#  ('Visited on Vacation (vacation, kale, parfait, frappe, paradise)', 1.0)]

# %%
# rank topic by sentiment score
topicStarsRanked = sorted([(i[0],i[1]['stars']) for i in list(topicStarsSentiments.items())], key=lambda x:x[1], reverse=True)
topicStarsRanked
# Out:
# [('Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)',
#   4.0),
#  ('Physical Space (place, table, area, spot, staff, parking lot, space)', 4.0),
#  ('Wait Time / Service (time, place, food, order, service, wait)',
#   3.8999999999999999),
#  ('Atmosphere (place, staff, love, selection, music, fun)', 3.875),
#  ('Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#   3.8571428571428572),
#  ('Misc.', 3.7999999999999998),
#  ('Alcoholic Beverages (beer, wine, bottle, club)', 3.75),
#  ('Staff (guy, smile, lady, girl, thank you, counter)', 3.7142857142857144),
#  ('Tea (tea, selection, store, cup)', 3.6666666666666665),
#  ('Young People (kid, place, class, year, hip, student, college)',
#   3.6666666666666665),
#  ('Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#   3.6666666666666665),
#  ('Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#   3.6153846153846154),
#  ('Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#   3.5833333333333335),
#  ('Unknown (die, der, da, le, ist, man)', 3.5555555555555554),
#  ('Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)', 3.5),
#  ('Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
#   3.5),
#  ('Coffee – General (coffee, shop, place, cup, bean, espresso)', 3.5),
#  ('Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#   3.3333333333333335),
#  ('Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#   3.2727272727272729),
#  ('Chocolates (bar, raspberry, foundtain, dark, truffle)', 3.25),
#  ('Juice (juice, roll, orange, cinnamon)', 3.25),
#  ('Visited on Vacation (vacation, kale, parfait, frappe, paradise)', 3.0),
#  ('Room (cafe, wall, room, door, floor)', 3.0),
#  ('Food / Meals / Restaurant (food, place, restaurant, service, meal)', 3.0),
#  ('Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)',
#   2.6000000000000001)]

# %%
pavementRankedTopics
# Out:
# [('Physical Space (place, table, area, spot, staff, parking lot, space)',
#   3.0646081532775447),
#  ('Coffee – General (coffee, shop, place, cup, bean, espresso)',
#   1.6563981521042255),
#  ('Misc.', 1.3291116351179728),
#  ('Customer Service (starbucks, location, time, service,customer, order, line, employee, staff)',
#   1.2014814948660022),
#  ('Sweet Flavors (gelato, butter, taste, caramel, flavor, peanut, pistachio)',
#   1.1037590732041715),
#  ('Wait Time / Service (time, place, food, order, service, wait)',
#   1.0612981297077675),
#  ('Tea (tea, selection, store, cup)', 0.98049048828643781),
#  ('Sandwiches, Lunch, and Breakfast Food (sandwich, breakfast, food, lunch, egg)',
#   0.96760331271572786),
#  ('Staff (guy, smile, lady, girl, thank you, counter)', 0.94292171053844243),
#  ('Baked Bread Items (bagels, pastry, bakery, bread, tart, cheese)',
#   0.87849533368452548),
#  ('Atmosphere (place, staff, love, selection, music, fun)',
#   0.80879407470996711),
#  ('Alcoholic Beverages (beer, wine, bottle, club)', 0.80366237528890305),
#  ('Young People (kid, place, class, year, hip, student, college)',
#   0.76916636044081876),
#  ('Doughnuts (donut, doughnut, dozen, apple, dunkin, shop, creme)',
#   0.59083347576413447),
#  ('Room (cafe, wall, room, door, floor)', 0.54134987383531508),
#  ('Food / Meals / Restaurant (food, place, restaurant, service, meal)',
#   0.51592887546545241),
#  ('Unknown (die, der, da, le, ist, man)', 0.51550011920613459),
#  ('Small Dessserts (cream, ice, waffle, strawberry, dessert, macaroon, banana)',
#   0.38264891854938898),
#  ('Latte/Chai/Milk Drinks (latte, chai, vanilla, mocha, milk)',
#   0.35281611254899176),
#  ('Bakery Style Cakes (cake, dessert, cupcake, brownie, cheesecake, birthday, bakery)',
#   0.32511115150427394),
#  ('Cookies and Pastries (cookie, muffin, chip, scone, macarons, blueberry, salt, cheddar)',
#   0.17857464226848574),
#  ('Specialty Tea/Milk Drinks (tea, milk, drink, boba, place)',
#   0.16297471935920838),
#  ('Juice (juice, roll, orange, cinnamon)', 0.15474350048429406),
#  ('Visited on Vacation (vacation, kale, parfait, frappe, paradise)',
#   0.150075332433074),
#  ('Chocolates (bar, raspberry, foundtain, dark, truffle)',
#   0.14129276997508494)]

# %%
# Linear regression of sentiment score on star rating

topicSentiments = [i['sentiments'] for i in list(topicStarsSentiments.values())]
topicStars = [i['stars'] for i in list(topicStarsSentiments.values())]
slope, intercept, r_value, p_value, std_err = stats.linregress(topicSentiments, topicStars)

print('slope : ', slope)
print('intercept : ', intercept)
print('r_squared : ', r_value**2)
print('p_value : ', p_value)
print('std_err : ', std_err)
# Out:
# slope :  0.984101641368
# intercept :  1.81570936658
# r_squared :  0.265380536332
# p_value :  0.00840667872427
# std_err :  0.341407234592
