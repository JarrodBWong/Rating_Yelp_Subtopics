# %%
from bs4 import BeautifulSoup
import sys
import time
import logging
import argparse
import requests
import codecs
import urllib
import os
import requests
import json
import nltk
from nltk.corpus import stopwords

import gensim
from gensim.corpora import BleiCorpus
from gensim import corpora
from gensim.models import LdaModel

# %%
# YELP DATASET: train on business reviews for businesses within the "Coffee & Tea" category

coffee_places = set()

with open('yelp_academic_dataset_business.json') as businesses:
    for item in businesses:
        biz = json.loads(item)
        if biz['categories'] is not None:
            if "Coffee & Tea" in biz['categories']:
                coffee_places.add(biz['business_id'])
        
reviewData = {}

with open('yelp_academic_dataset_review.json') as reviews:
    for item in reviews:
        rev = json.loads(item)
        if rev['business_id'] in coffee_places:
            reviewData[rev['review_id']] = {'text':rev['text'], 'stars':rev['stars']}

# %%
list(reviewData.items())[:100]
# Out:
# [('z--dbq4Qegp23GdECZYI9A',
#   {'stars': 3,
#    'text': "I love the location since its so close to home and work. I WISH they had a drive thru! With that being said, the service has recently gone down. I go about everyday and no matter what time I go there is always a wait. It seems like only one person is making the drinks. I'm assuming they are just short of staff. The staff that is working there seems very stressed out and not happy. Just doesn't feel very relaxing. Hopefully things get back to normal soon as I do love my coffee!"}),
#  ('fMQUroqu5LzPfIGiwdvmwA',
#   {'stars': 3,
#    'text': 'Beau petit café "3e vague" près de McGill, 4,50 $ le latté ! Il était bon. Ça fait changement des autres Second Cup ou Starbucks au centre-ville. Wi-fi gratuit. Par contre, le service était correct, même pas un sourire et un merci du jeune proprio, mon latté déposé sur le comptoir sans rien dire et continue sa conversation avec son associé.... bof, j\'aime un peu moins.'}),
#  ('v6qi_7mTgPIu0tiqnlSNDw',
#   {'stars': 5,
#    'text': "This place has the best empanada's I have ever had hands down. I definitely recommend this place and staff are very friendly. I will be returning here again."}),
#  ('DJVYvizn6H6vDkLGgkjT9w',
#   {'stars': 4,
#    'text': "Coffee was good. She topped it off for me because I was so tired I didn't want mill. More coffee!! ^-^  Haven't eaten my bagel yet, but veggie cream cheese was same price as regular. Yay free veggies!  Oh yea, and the bagels are huuuuujuh. ;-)"}),
#  ('vxe8EVPctkpXO1NnXoMX1A',
#   {'stars': 4,
#    'text': "Good gelato, awesome cannoli's. You just can't beat 'em."}),
#  ('PnjqwzBg0QWDRpzAAZSHVw',
#   {'stars': 5,
#    'text': 'Amazing ! \nI love their pistachio gelato during summer time ! \nTheir service is great and the place is always clean! \nI love all their locations but this one is my fav!'}),
#  ('IFSUispv-wZIGi_GtZXupg',
#   {'stars': 4,
#    'text': "If there are any bad reviews, then they have limited themselves. This is the only cute little asian bakery around the area. Asia town itself is quite unimpressive and severely limiting. As a CWRU student there are hardly any Asian restaurants close by to start out with and this little bakery is cheap and delicious. \n\nIt takes about 25 mins to get to Koko's by RTA and may 10-15 minutes by car. I wish we had closer asian restaurants and such. \n\nI love their bread selection, they is always a wide variety and they always seem fresh. Their bubble tea is good, better than the ones I've had in Coventry. Their sweets also look adorable, so it's fun eating those."}),
#  ('nMccamehHFJMX05DZqoPfg',
#   {'stars': 5,
#    'text': "Coffee is so good! I'm not much of a coffee drinker but there are items on the menu that can cater to anyone. The food is really good and delicious. At the counter was a girl named May, she is awesome and super friendly and will help you order properly."}),
#  ('kD4LMZM94TF60CN8xNmA2g',
#   {'stars': 4,
#    'text': 'I love the warm, relaxed atmosphere at Phoenix.  Compared to the one on Lee, it\'s more spacious and not as busy.  It\'s usually nice and quiet, so I love going there to study.  I love trying their seasonal creations, even the non-coffee ones.  I love how the decor is repurposed and recycled too, which makes for an eclectic and funky decor. \n\nThe thing that brings me to Phoenix over Starbucks is my desire to support a quality local business that is invested in the community and environment, both local and global.  They now have compostable cups, but charge 10 cents for them, so bring your own if you\'re getting your drink to go!   \n\nSpeaking of "to go", this location is the only one with a drive-thru, if you\'re really on the run.  Either way, be sure to stop on by!'}),
#  ('ruXalyTBOTqh6QAtC6kavA',
#   {'stars': 3,
#    'text': "Pros: Great service, sweet people. I highly recommend their crepes.\n\nCons: Gelato isn't Italian gelato, more like just regular ice cream. I was disappointed."}),
#  ('3xIVNGCBi9UNbRpPi_jp7g',
#   {'stars': 5,
#    'text': 'Went for a late Saturday brunch and got seated right away.  The service was a bit hands off but not a huge issue.  I had the stuffed french toast which was delightful.'}),
#  ('drobVS9vfa8Dz-qpnzcIsA',
#   {'stars': 4,
#    'text': "Pricey but good.\nWhen it comes to coffee I'll take expensive over cheap.  They use illy espresso not cheap Starbucks crap.\nI love their white chocolate iced latte. Perfect stop for hangovers or a pick-me-up before hitting the craps tables.\n\nThe staff is very nice and understands how I like my coffee."}),
#  ('VyOE--7RNRAf2L5tCKywrQ',
#   {'stars': 4,
#    'text': 'Had an event Saturday evening and errands wanted get a coffee or tea. It was only 10pm and every place was closed so looked up the newest Starbucks and open til midnight. This was nice to find out as cinemark theatre is across from them. I had a green tea and dave had Carmel Macchiato. Plenty of tables and sitting areas and was nice to see so many people just hanging out enjoying their coffee. I look forward to sitting on patio when weather warms up.im just thrilled to find out the hours!!'}),
#  ('nkDnI2_4GOIDZrlDX9hjuA',
#   {'stars': 4,
#    'text': 'As the name implies and as everyone points out, the cupcakes are indeed jumbo! Not your typical trendy smallish cupcakes I have been used to in the northeast a la Magnolia.\nI got the simple Vanilla cupcake and thoroughly enjoyed it. The frosting was delicious and full of flavor and the cake itself was moist and tasty. Thank you Colossal Cupcakes!'}),
#  ('d3UCFd_8PTFdL2D7_xu7vA',
#   {'stars': 5,
#    'text': 'omg! delicious! jerk sausage is amazing. chocolate cake is solid sin.'}),
#  ('eTHEvGiJeM3REsIfsFcYDA',
#   {'stars': 5,
#    'text': 'Love the staff and service! I live close and visit offten. They all remember my order! So genuinely happy and interested in their clients. Thankful.'}),
#  ('-oIXdKSuFo3NptY4rDLUVQ',
#   {'stars': 4,
#    'text': "This place is a solid cafe with solid food. I've had the lox omelet and the toasted veggie sandwich here and they were both delicious and large portions. I also appreciate a place that has a selection of hot sauce. It's a no frills kind of place and they focus on the food. I'll definitely be going back."}),
#  ('FmmJtKy7XLdF5ONKNY3yqQ',
#   {'stars': 4,
#    'text': 'Yummy desserts friendly staff. Issue: no coffee espresso drinks available today; did not take Benjamin either. I did like the rise green tea, very refreshing. My faves are green tea crepe cake, tiramisu, creme brûlée.'}),
#  ('MOyPOuJhDvJoqO0mToBToA',
#   {'stars': 5,
#    'text': "This place is AMAZING! They are always friendly and have a great variety of drinks! I'd rather come here than go to Starbucks. Thank you Crossroads Books & Coffee for providing delicious coffee! I highly recommend this place."}),
#  ('Iu2BV2rmopzuM-FzJgsjtQ',
#   {'stars': 5,
#    'text': "Very nice to have a drive thru here.  And there's a lot of parking and seating if you walk in, too. The meeting room is cool. Very nice use of the old building with a patio added for the cool weather.  The park nearby makes this a great stop with the dogs. Puppicino!"}),
#  ('TjLarNl6oTvG74MNQAKMvw',
#   {'stars': 2,
#    'text': "Good for Instagram, not as amazing as it looks. I'm sad to say, it does not live up to its hype.  It wasn't bad ice cream, it was certainly good, but they got rid of the cool flavoured soft serves like burnt marshmallow! And it's not worth the lines if it's over a 10-15 min wait.  \n\nA chocolate or vanilla soft serve or a chocolate vanilla twist with some toppings that's what you're looking at. The rush and hype makes for mediocre tasting ice cream cones that are so not worth the $7.35 price tag.\n\nI came here initially on a rainy December night, and had the campfire smores that was made with a toasted marshmallow soft serve- and that was fabulous. Now, in June, it's just a basic chocolate vanilla jazzed up with toppings. \n\nHmm, not really worth it.  If they go back to having cool flavours of soft serve like they used to, then maybe they deserve more stars."}),
#  ('vSuw2_d6wls4gWfDVwoP7g',
#   {'stars': 2,
#    'text': 'Love how friendly they are and the unique ome like design of the restaurant but the food and the coffee is not at all good tasting..also if you go through the drive through it takes them so LNG that they might ask you to just pul forward and wait till one of the employees brings out you  food - just not impressed at all mediocrity'}),
#  ('v_pM8vKxfQCxYO9ai8nGVQ',
#   {'stars': 5,
#    'text': "I really wanted a treat this rainy Saturday morning and decided to try Troubadour coffee shop. It had only 2 reviews, so I didn't expect much, thought I'd get a regular overly sweet cup of cappuccino and that's fine.\nI ordered a cup of mocha. That was the best mocha I ever had. Not too sweet. And the top layer of frosted milk was not your regular foam. It was gooey, almost like melted marshmallow, very yummy. \nThey have some treats to go with coffee, not many though: banana and pumpkin bread, Italian cake and some cookies. \nThey really take time to prepare for you an awesome cup of coffee, so don't come here if in a rush."}),
#  ('fm15qutmXnRiQRvE2r-iPA',
#   {'stars': 3,
#    'text': "It had been my first Starbucks in a while, but I've been to this location numerous times since it's right by work.  This Starbucks has a lot of seating areas, including high tops, couches, and long tables for larger groups.  Everytime I've walked in, the seating area is full, luckily for me, I usually grab my coffee and head to work.  For the most part, this location is quite busy all the time considering it's right outside the King subway station and in the downtown area.  I love that the staff here are always very enthusiastic and friendly when taking orders.  They always put your name on the cup which makes you feel special and adds a nice touch.  The only downside I'd say is that the line-up here is massive all day long!  I guess everyone needs their coffee.. I know I do anyways.  Depending on whom is working at the bar and how many staff they have on duty, there is usually a wait time to receive your coffee, which is why I can't give this location a four star.  They are usually always very consistent in the taste and temperature of the coffee compared to other locations I've been to.  I think I've only had one order so far that was incorrect.  All in all, I would recommend this Starbucks location if you have the time to line up before your shift for work and aren't in a rush to get anywhere."}),
#  ('4Tovh7FQGdrJS3FyeNIkqg',
#   {'stars': 2,
#    'text': 'I was thinking this place would be fairly good, given the previous reviews. I got a regular cup of the Colombia, because that was the only kind of coffee they were brewing (which is fine) but it tasted horrible. There was no sugar in sight, to even add to it. I usually only add sugar if I have to, in this case it was needed. After two sips of it, I had enough, so I threw away the $2.50 worth of a cup of coffee. By the way, $2.50 to fill up a 14oz. Sustainable cup that I brought in?... A little pricey.'}),
#  ('-ujnyZjbIYQ2I3r4iFmyhw',
#   {'stars': 4,
#    'text': "Ice Cream and Candy Delicious-ness galore!  After dining at Windsor, simply take a few steps on over to Churn for some homemade out of this world super creamy ice cream.  It's like a mini candy store filled with cookies and ice cream.  The staff happily offered a few tastings.  I thought I was going to get the Strawberry but then I tasted the blueberry ice-cream.  It was so good and different.  \n\nWe got out cool treats and then enjoyed eating it on the patio and having a little chat and people watching.    What an adorable place with good ice cream to boot!  See you soon."}),
#  ('9vk9sEX3FHbsFJBLNxoqgA',
#   {'stars': 5,
#    'text': "Amelies...Amelies...how I love thee! There are so many good reviews on here. There isn't much left to say! Awesome decor, delicious desserts, eclectic environment. Their macaroons are TOO LIVE FOR! Everything I tasted were authentic French pastries. Nothing tasted American made! The staff is really friendly. They even have their own delicious smelling coffee! Nowhere in Charlotte will you find a place like this! Oh, but wait there's more! They are open 24 hrs! Awesome! Awesome! Awesome! Says the pregnant woman! Lovely place for you to do school work or to meet people. As a Charlotte native, I never thought the day would come where places like this would exist here. Love it! If you haven't been, go now! They're open! Lol"}),
#  ('3xbgX9rAgS6rEViPR4Rchg',
#   {'stars': 4,
#    'text': 'Taste is awesome, the space is small but cute. They play Chinese music, which takes me back to my summer abroad. Just a little pricier than I would like, 3.50 for the smallest size which is labeled medium but is more like a small. Original Milk Tea is so tasty :)'}),
#  ('T_H6w7mfg61LVxlSaQuhYw',
#   {'stars': 5,
#    'text': "Favorite coffee shop in the Southside, great for people-watching, getting some work done (if you're so inclined), and/or catching up with the day's news. \n\nThe coffee is fine... look, I'm a coffee snob, okay? And when I lived in Boston, I lived within walking distance of George Howell's ONLY cafe in the entire U.S. of A., needless to say, I am spoiled and used to excellent coffee. Overall, Beehive makes the cut, the coffee is decent and the space is more than interesting. All in all, a fine coffee shop."}),
#  ('-OeepEmYKJ-xjYaM0kZMjQ',
#   {'stars': 4,
#    'text': "Hmm, I've been back a few times in 2016 and have to say, I'm having better luck with the quantity of boba. The tea is still a bit weaker than I like but overall, it's good for the limited options in the East Phoenix valley. 3 stars\n\nSo why the 4 star upgrade? Because I have a 5-year old and he and his BFF absolutely love the rainbow slush with green apple jelly and strawberry popping bubbles. LoL They have talked me into coming back the last three weeks for their fix. Best thing is that the team at Boba Tea House team will split a large size into two cups for them, just like Jamba Juice does! No kid needs a full sized cup of sugar water (with sugar popping balls and jellies). Haha\n\nProbably see ya there!"}),
#  ('L3s4bX0KUbvP60lVwBeXBQ',
#   {'stars': 5,
#    'text': 'Wow\n\nI was so impressed with this place!\n\nFrom the authenticity of the food to the personality of the owner.\n\nWe ordered an assortment of veggie dishes.\nEvery dish was better than the other.\n\nThe food is light and seems really healthy.\n\nTo top it all, the owner spoiled us with a ginger tea that she made in-house. One word- Wow!!!\n\nA different experience that will pleasantly surprise you.'}),
#  ('OWsBpdRkau-hySc7wDu8rQ',
#   {'stars': 5,
#    'text': "I stumbled across this cafe on a hot summer's day and am so happy I went in. This adorable little shop in conveniently located between King and Queen off of Portland. Although there are a ton of coffee and cafe options in the area, Forget Me Not is simple and relaxing.\n\nThis quaint cafe is run by an extremely friendly and adorable man and is filled with cute gems for purchase. Definitely check this cafe out if you're looking to escape the typical madness in the entertainment district.\n\nDid I mention there's a ton of space to sit down and set up for the day?"}),
#  ('i-WQm3WzuOmZCHmq4lSTnQ',
#   {'stars': 4,
#    'text': 'Stopped here for lunch after touring around the area and stopping to take pictures of the Forth bridge. This place is pretty small and cramped, but cozy. They also had free wi-fi, which was great for us overseas tourists looking to check some email and post some messages.\n\nI ordered a ham and cheese pannini along with some lentil soup. Our food came out at separate times, because we could see that the person behind the counter was making them one at a time. No big deal. My sandwich was very good. Toasted just the right amount. Nice and crisp, and warm with gooey cheese, but not overdone. \n\nThe soup was also quite nice. Very flavorful and piping hot, which was much appreciated on the rainy morning. The service was also very quick and the staff was friendly and personable, especially for us Americans who were clumsy with all the foreign coinage as we were trying to pay at the end.\n\nGreat little place to stop in with great food and great character!'}),
#  ('g6i3_435sruv_BD8m6cspQ',
#   {'stars': 4,
#    'text': 'Hard to describe its just super delicious is all i have to say. Deffinetly highly recommend will be going here again soon!'}),
#  ('2X1igu0ITw8zYMnsdRzgzQ',
#   {'stars': 1,
#    'text': "Worst breakfast I've had in recent memory. Basted eggs hard and cold, roasted potatoes cold and hard -I think I got the leftovers. I'm super disappointed. The coffee; however, is on point."}),
#  ('8JVLk3rdPSPztGPIlWBHqA',
#   {'stars': 4,
#    'text': 'We were recommended by the waitress at District One and were very pleased. Had the Thai tea the first time which was standard. The second visit we had the jasmine milk tea and the matcha green tea smoothie with green tea ice cream. Both were very good. I took off one star bc the first time we visited, the waitress was a bit rude. They have a huge menu of drinks, food and desserts!'}),
#  ('rkqzdQhbiKuwNGxEVyGkCw',
#   {'stars': 5,
#    'text': 'Very nice snack place a sort of electic style decor. Good for casual hangouts with friends\nTheir club sandwiches are very awesome. Also tried fried chicken burger which was yummy and very spicy. Chicken samosa was just ok. Puffs were good tasting and fresh.\nChai was very refreshing. We went in the middle of driving from Niagra to whitby, and the chai took the tiredness away. Perfect authentic desi chai.'}),
#  ('Rbdl2O8i5MgoVK-p-OljpQ',
#   {'stars': 5,
#    'text': 'Best coffee shop in the valley hands down. The roasts are better than Lux and the vibe is more welcoming. They will know your name the second time you come in and know your drink shortly after. \n\nThe espresso is fantastic and the prices are cheaper than your local Starbucks. The baked goods are consistently good and the food is great as well. Try the herbed chicken sandwich! \n\nAll in all a fantastic welcoming place with outstanding coffee, great prices, and very friendly staff!'}),
#  ('eYJXqEaT0eoS0G0GvUHPfg',
#   {'stars': 5,
#    'text': "I love this place too. A range of drinks. Free wifi (to customers!). A cosy little cafe with a collection of wooden chairs and tables that wouldn't look out of place in your granny's living room. And the bagels. Well. I got there at 4pm today and there were 3 left. But first thing, you can choose from sesame seed, poppy seed, onion, multi-seed, tomato, cinnamon and raisin, plain (why would you?) and the list goes on. Fillings galore also.\n\n\n I would recommend roasted peppers, cream cheese and pine nuts. But I'm a terrible creature of habit."}),
#  ('c51GcZBkToiEYtK4ZbB2uw',
#   {'stars': 2,
#    'text': "Don't come in the middle of the day feels like everyone wants a break and the lines are forever and the drinks are not made correctly I saw 4 people return their drinks because they were made wrong I got skipped twice and my drink was made wrong -get it together"}),
#  ('1h9KZ8JHu0hPObCVCzCCgQ',
#   {'stars': 2,
#    'text': "I was greeted with a yawn by an employee named Net.  She seemed like this was the last place she'd like to be at the time, which also made me not want to be there. Quite unpleasant.  At least all the other employees were smiling and working merrily."}),
#  ('wZrKs9OGg7YXdkG6hy86Sw',
#   {'stars': 1,
#    'text': 'Have you ever opened a Christmas present to find socks or deodorant? Panera.\nFrom the moment i saw my panini that I spent like $90 on I was immediately depressed and began to ponder my existence and what the meaning of my life was. I shortly after began to contemplate suicide, I will not be eating here again.'}),
#  ('pYU4CLlpJs-bfCbTJn5f_Q',
#   {'stars': 5,
#    'text': 'Great no nonsense Italian coffee. Laundromat. \n\nGo wash your clothes you filthy animal.\n\n10/10 would launder again'}),
#  ('WXhAHtQ2e9jOUbWr-sSnwg',
#   {'stars': 4,
#    'text': "After dinner on the Main, we figured we should try some desserts here. People waited in line even in the rain to get in. Fortunately, we didn't have to wait more than a few minutes to be seated.\n\nMy wife enjoyed her café au lait and I opted for the Pot au Chocolat. Very rich and delicious - I recommend.\n\nThe place can be quite busy, but the waitstaff is friendly and accommodating. Our waitress patiently waited for these two Americans to bumble through our order in French, even complimenting our efforts and encouraging us to continue practicing. Awww... merci beaucoup.\n\nDefinitely drop in here if you're on the Main!"}),
#  ('5gxnqKo0pVGitQUWY8PKlw',
#   {'stars': 4,
#    'text': 'I was very pleased with this location.  I ordered a hazelnut iced coffee with cream and a shot of espresso.  The coffee was fresh and the service was awesome!'}),
#  ('Ilrt6rKhXUnqlqMsK-quGA',
#   {'stars': 3,
#    'text': 'This Starbucks is in the convention center in Vegas. And they have you all to themselves as there is no one else that you can go to. So, they have a very limited menu of drinks, because the wait times during a conference can take 15-20 minutes just to get to the front of the line to place your order. I understand why they have a limited menu, it allows them to push the coffee out the door as quickly as possible. However when you were born in the coffee capital and have experience a great coffee shop before, you will see the glaring miss in a full compliment establishment.\n\nThe staff was very efficient, again due to the smaller menu size, however the baked goods left something to be desired. They were mostly out of everything by the time I got to the front of the line and that was at 9AM. The line was 30 deep past me and growing. Better planning should have taken place knowing a huge conference was going to be in the building.'}),
#  ('XUTjAsv9S-nTHILOslxSqw',
#   {'stars': 1,
#    'text': 'Will never do business with Dunkin Donuts again, they refused to accept my Groupon and would not even attempt to scan it.   On top of that, menu items listed on their website were not available and I was told they\'re "seasonal".   No mention of that online which was a huge inconvenience as I was ordering for people who weren\'t present.   To "compensate" for my inconvenience, the clerk gave me an iced hazelnut coffee which was already sitting on the counter - it was disgusting and probably a drink that was botched or rejected by someone else.'}),
#  ('pmOTqx0CbAlhHECc9slrcA',
#   {'stars': 5,
#    'text': 'delicious coffee  i had the iced caramel mocha and it was awesome !!!! I will definitely be coming back .. the environment inside is super cool and fun .. and they even have board games to play while enjoying your coffee !!! Definitely recommending this place to all my fellow coffee lovers !!!!!'}),
#  ('yiVqhyWxXfFsMwC-8Zs0rg',
#   {'stars': 4,
#    'text': "Another great Starbucks! Man, I'm beginning to think that Starbucks might be a successful company. Weird.\n\nMy favorite part about this one is it's located in one of those great southwestern-style strip malls that you see all over Arizona. And with that comes those wispy little trees, cactus, sand and sandstone. \n\nTo sum up, order your favorite coffee, enjoy the lovely mid-October through mid-March beautiful Arizona weather, and relax!"}),
#  ('T486twaisX-MK0MsWoF48w',
#   {'stars': 4,
#    'text': "Ambiente gradevole, all'Alte Kanzlei si parte dall' aperitivo ai piatti tipici, molto gustosi e curati per finire con un cocktail .\nOttime birre e una buona carta dei vini. I camerieri meritano una mancia per la gentilezza e la professionalità ."}),
#  ('s6GICY3-dpGBXGCO5xNBYQ',
#   {'stars': 5,
#    'text': "So I just order apple fritters and a cinnamon roll. WOW. They taste heavenly.\n\nFor a price of $3 , for both donuts and a medium coffee, you'll be crazy not to go there lol. I found my new coffee place.\n\nI'm actually in the car as I'm typing this out, eating the donuts."}),
#  ('2DVgcDoxHaZz0YhwBmC3zg',
#   {'stars': 5,
#    'text': 'Surprisingly the brioche ham and cheese does taste like brioche !!! The coco mocha was to die for. A very nice and laid back atmosphere all around. A great local coffee shop!'}),
#  ('BIGTGRigpMLKwtEwu-qc1A',
#   {'stars': 5,
#    'text': 'Best Starbucks around... The baristas know how to make there drinks... Other Starbucks employees barely look you in the eyes and here they are friendly and chipper... Highly recommend for a great cup of coffee and great service :-)'}),
#  ('asSIJyPISc3onflPK0WP0Q',
#   {'stars': 5,
#    'text': 'Fresh cup is a refreshing new boba place right in central Las Vegas! I stepped in and already loved the atmosphere. The place was clean, cute, and I was immediately greeted by the friendly staff! \n\nI got the Thai Tea blended with egg pudding and boba. Their boba was cooked PERFECTLY! It was up to par with Half and Half, which I frequently visit in SoCal! The drink was overall a refreshing way to cool down from the hot Vegas heat!'}),
#  ('BrfYKa8nfq7103acCcPK0w',
#   {'stars': 4,
#    'text': "My sister went back after I was contacted by someone from the bakery due to my original review. Apparently I'm not the only one who had complaints about this particular employee (who is no longer working there). My sister's second experience was completely different and so much better! She is so happy to be getting exactly what she wants and I can't wait to taste the final product."}),
#  ('sY-iHGWlFU6Ek449fwk73A',
#   {'stars': 4,
#    'text': "My new local Starbucks! The service is great, baristas are nice and friendly. Drinks are made well, when asked for extra hot it actually is extra hot unlike the Starbucks in Chapters at Kennedy Commons! It's always clean, tables, sugar station and washrooms. The only downside is the place has some serious heating issues. There is either no insulation or the ac is always on. Even in the winter!"}),
#  ('boNCYPx_b2Xo8OWU5yO-FQ',
#   {'stars': 5,
#    'text': 'Just spent the whole day studying here. Great beverages, great service, great food, great Internet, and a great environment. I had the chicken wrap that came with a side salad and the ingredients tasted fresh.'}),
#  ('d5fTfInu9KGMiRVzn2sV-g',
#   {'stars': 5,
#    'text': 'great value, filling, perfect to warm you up on a chilly day.  a medium potato is enough for two meals.\n\nstaff incredibly nice.  good solid food with fresh ingredients.  \n\ntry the onion, pineapple and cheese filling.  sounds disgusting, but sweet and savory.  \n\nthe line can get stupid long during festival, but as long as the people ahead of you are ordering instead of performing or mugging, it moves fast.'}),
#  ('xw22w3vP1utRAwUiOVgH0Q',
#   {'stars': 5,
#    'text': "Vision Office's hidden gem. Grab a chicken salad sandwich, or one of their breakfast burritos. Great food, well made with quality ingredients"}),
#  ('E6gyONUVbWbRdgpQ1Md__A',
#   {'stars': 1,
#    'text': 'I will never go to NEXT COFFEE again.  I stopped there on the way to a 10:00 Little League game.  They were not busy at all.  The staff of young "college students" (what it says on their TIP jar)  was very rude.  They slowly made my 2 hot chocolates (which were terrible) and put them on the counter without letting me know they were ready.  When I asked if they were mine they said "ya probably," then walked away to continue chatting.  My coffee was terrible and the kids wouldn\'t even drink the warm milk they tried to pass off as a $3.50 cup of hot chocolate.  It was my first time there and I will not go back.  There are too many other places to go.'}),
#  ('LRMPvahr7tYqIErM-uwDAw',
#   {'stars': 5,
#    'text': 'Een heerlijke kleine winkel voor een goed belegde Jacket Potato! De Aardappels zijn echt groot, dus wanneer je weinig honger hebt, is 1 Jacket Potato echt meer dan voldoende.\n\nEr is voor vegetarischers en mensen met een koemelk-, en gluten allergie ook volop keus, laat het de medewerker(s) weten en ze kunnen je prima verder helpen.\n\nDe winkel zelf heeft wel een tafeltje waaraan je kan zitten, maar echt luxe is het niet. Beter neem je je voedsel mee naar buiten en eet je het op terwijl je van de stad geniet.'}),
#  ('40WlFrJ7tJzvlVh6B0xnxQ',
#   {'stars': 4,
#    'text': 'Ambiance is perfect!  Service was under 10 minutes on a Saturday morning!  Management was personable and took care of us! Thank you Stephen!'}),
#  ('3-Vkr4_ITkAo4Y7YULO_dQ',
#   {'stars': 2,
#    'text': 'Coffee was sub standard and nowhere close to Crema which i was looking for.\nThe space is nice.'}),
#  ('gU5pYVUHexyuP-eoHrkjrw',
#   {'stars': 2,
#    'text': "I'm a regular Starbucks customer at different locations and this is one place that needs improvement towards their customer service. The individual helping me was not attentive to what I was saying and I thought she was joking when she was providing the incorrect order back to me, however, that's what she heard. I believe she is a new employee, therefore, I was hoping someone was helping her than looking at their phone. I would like to update my review because there's opportunity to improve and bring me back since I love coffee."}),
#  ('HArCNXd9d4hSmSrK371woQ',
#   {'stars': 4,
#    'text': 'Not a great place to study, but has good coffee and pretty good mochas.'}),
#  ('PN0O47sQsUSTt6ItAkMVHA',
#   {'stars': 1,
#    'text': "What a Disappointment! I came in after the morning rush, at about 9:30, and on a Wednesday. Brittany is by far the worst cashier I've ever witnessed. It would have been like pulling teeth to get a good morning greeting or even a smile. Every question was an inconvenience to answer. She moved at a snails pace and yet made it seem as though you taking a minute to glance at the menu was keeping her standing next to her register too long. Another women had made a big order to go and as she waited she must have had the same experience. As she waited she called the manager and gave some advice on customer service and examples of her unsatisfactory service she just received.  The same girl Brittany had given the lady her to-go order and the women asked if the bread was in the bag. Brittany didn't answer nor did she look or assist to find out. The lady said nevermind I'll grab it myself. As soon as the woman left all the staff including the manager were laughing at the phone call. All of the staff look too young to take the job seriously, including the manager. They need to fire everyone and hire new people who understand the value of a job. I'll never come back. Save yourself the bad customer service and go to Paradise Bakery across the street."}),
#  ('70o6h9DJgVFE9xpNx-kHuw',
#   {'stars': 4,
#    'text': 'Bring  cash if you just want a cup of coffee. \n$5 minimum order for credit cards . \nNice atmosphere though.'}),
#  ('-7Tjm4oSi_lsF3HCkVxlwg',
#   {'stars': 5,
#    'text': "This place is an awesome addition to Cleveland. I work downtown and this is just what we were looking for. A fast friendly healthy spot that we can get in and out quickly. Everything is organic or non-GMO including the coffee bar. My favorite is the steak Bowl. I've had it 4 times so far and it's been better each time. And they have a ping pong table on the patio which I think is really cool. This is what Public Square really needs. Good job rebol."}),
#  ('Zg47RhhOffmrS3cjOMaH4A',
#   {'stars': 5,
#    'text': "Once I saw Aroma, it immediately reminded me of my time spent in Italy. A welcoming bar, espresso, and iced water with lemon as a complimentary drink for patrons!\n\nWhile I haven't taken Aroma up on a coffee or breakfast, I have enjoyed two awesome steak sandwiches for lunch here. Aroma offers the choice of a half sandwich and a soup or salad which ends up running you a little less then ten dollars, and will certainly leave you satisfied. If you choose to go with the soup option I suggest the pasta fagioli! As for the steak sandwich, it was superb. Nice shaved steak, some peppers, and a to die for (but unable to determine) sauce between two fresh slices of bread. If you're really hungry take a run at the full sandwich, but I'll warn you it's pretty filling! I had a hard time getting through all of it. My only complaint about the sandwich is that the bread isn't toasted and I found that on both occasions the bread became a little soggy because of the warm steak. If you're taking it to go to eat at your office, it could get even soggier when it's wrapped up in a bag, so I would suggest eating it there! \n\nThe complimentary iced lemon water is a great touch!"}),
#  ('znm1zaTUKRzkjgkhmtLSqw',
#   {'stars': 4,
#    'text': "LGO is a great, feel good place to spend an afternoon.  I've never brought someone who didn't find something to like about this place!  \n\nA tip: Pull into the Postino's parking lot & valet your car!  It is free (with gratuity, of course) and much easier than trying to find parking in the front.  Then, you can walk around to the front of the store or cut through the back entrance.  There are some small tables in the grocery store portion as well as plenty of tables in the restaurant portion.  During the day, you order in the grocery store, find a table, and wait for your food to be served.  In the evenings, you are seated in the restaurant portion and have a server to help with the ordering.\n\nThere isn't much I don't like about this place.  There are cute trinkets to look at while you are waiting for your food (or if you want to hang around after).  There is a dog-friendly patio out back.  All of the food is pretty much stellar - this is NOT going to be the MOST amazing meal of your life, but its pretty darn good for brunch.  Their pizzas are some of my favorite in the valley!  I highly recommend!  You can also pick out beer or bottles of wine from the grocery store to accompany your meal.  \n\nNote: There is an LGO at the airport as well - this is my MOST frequented airport meal because it is AWESOME for airport food.  As a vegetarian with many meat-eating family/friends, this place has a great selection for all types of eaters!"}),
#  ('UvH7Wmz9qCI8_VPgVyL6IQ',
#   {'stars': 4,
#    'text': 'Some posh Francophile friends hyped up LGO for me that I suppose it would be impossible for them to live up to my expectations.\n\nThe food: very good, if not particularly French. The commuter sandwich is excellent, the combination of smoked salmon and avocado is hard to beat. The French pancakes are basically crepes without any fillings topped with chopped strawberries. Also delicious.\n\nThe coffee: Excellent. If I come back to LGO it will be for this, and to try the gelato.\n\nThe ambience: Unique. Lots of useless kitsch on the shelves along with overpriced "artisan" foodstuff for people who correlate better taste with increased spending.\n\nThe price: Too much. this is why only four stars. The price won\'t make you walk out, but for what they offer I was underwhelmed. You\'re really paying a steep upcharge just to raise your pinky in a posh "European" atmosphere.\n\nGood for: wealthy Arcadia housewives\nNot good for: poor young deal-seekers'}),
#  ('Eqo5khX8NFsQiEq6udgWEA',
#   {'stars': 5,
#    'text': 'Best quiche in town. Chocolate twist very good as well. Nice outside patio area. Will have to try out lunch here some time everything here looks good.'}),
#  ('Z8L2i334NijGTgI_9LQMNg',
#   {'stars': 3,
#    'text': "cozy atmosphere, service was ok, my burger and fries were pretty good.  my mom's breakfast was not what we expected. she ordered bacon and over easy eggs...the pancakes were a bit over cooked and the bacon was very, very crispy and eggs were very runny.  the woman who waited on us said that's how the bacon is always cooked.  it seems like a nice place, but if you go there for breakfast and don't want extra crispy bacon, you must be sure to let them know.  and if you don't like runny eggs, order them over medium and not over easy."}),
#  ('bWFAlV2E5_IJAXs6Uu5kDw',
#   {'stars': 2,
#    'text': "Overpriced, cheap coffee, and new look (not sure when it was done) is kind of ugly.  Not a big fan of Starbucks in general.  Only thing that does give them a second star is the green tea is OK if I'm in a bind."}),
#  ('coREoV7udaSlxHVxH9jIeg',
#   {'stars': 5,
#    'text': 'absolutely love the food.  This is new restaurant and they are already making a name for themselves.   the location isnt the best for the upscale food and environment they create but a safe location and that is all that matters. \n\nPro- the food is fresh with all fesh ingredients.   Everything is made from scratch so you can def taste the difference.  They are very clean and serve liquor.   my fav- the Chili Relleno. \n\nCon- the parking lot is too small and awkward.   Also, they do catering but the price for catering service doesnt seem to match the price of the plates so it is more than you would expect.  once you try their food you may think it is worth it.  Sooo yummy!'}),
#  ('2ZEhqsEP6BabNwfS82g4NQ',
#   {'stars': 1,
#    'text': "Worst donuts!!! I came 26 minutes before it was supposed to be closed. And as I walked to the door. The workers turned off the lights. Apparently they don't want business. Will never come to this place again.  As a result of them closing early I have called corporation. If this is a franchise I hope it gets taken over."}),
#  ('CzYkOUb2hTepGezwKjN7vw',
#   {'stars': 5,
#    'text': "The place is clean cool and awesome different flavors that I like very nice to come to a place where your welcome and not talking to robots I recommend everyone try endless swirls locally owned not a franchise. I asked an employee I'm always curious come and try."}),
#  ('AaJ4_IwsyjAsGt2XR4SuEQ',
#   {'stars': 4,
#    'text': 'I took my nieces in for a sweet treat and they loved it! The place is truly charming and clean. The pastries and our coffee were delicious. The staff was very attentive and patient. We were surprised, by the owner I believe, with complimentary samples of the gelato and it was truly amazing! Nice touch and very thankful for the sweet treat. Looking forward to going again!'}),
#  ('-LZJuUOWum3dKz7SqLo7vA',
#   {'stars': 5,
#    'text': 'Tasty, fast, healthy food in the metro\n\nToo many times, I have been feeling peckish as I rush from destination to destination, or else seduced by the sweet siren smell of pizza, and found myself spending money on "metro food" followed by instant regret. For this reason, I cast a wary eye at "Yummy Express" every time I passed it while hopping on the green line at Atwater. And I was missing out!\n\nMy partner and I decided to grab a sandwich there one day as we headed to a museum. He ordered the vegetarian banh mi, but I\'m not a big fan of banh mi, so I went with chicken ceasar instead. Both were delicious! Several days later, I satisfied a hotdog jones: $3.50 for a 12-inch all-beef hotdog with all the trimmings (onion, mustard, relish, and ketchup if you want it), plus a drink. Mmmm, even Lafleur\'s while I\'m drunk would be hard-pressed to beat that.\n\nThe owner and his wife told us all about how they avoid excess salt, fat, and sugar, and try to keep it pretty healthy in general, which is rare in a resto so close to turnstyles. It has a pretty home-cooked vibe when you look past the sandwich display and popcorn machine. There\'s a number of delicious menu items I\'m looking forward to trying, including traditional Vietnamese fare as well as the hotdogs and popcorn to satisfy junk food cravings. Finally, food I can feel good about grabbing as I rush to my next destination!'}),
#  ('sgiajSQ-2ah-1M-c_QRKhw',
#   {'stars': 5,
#    'text': "This is the best Starbucks I've ever been to. They don't question or correct me; they just get my drink made, and if I haven't had my coffee yet that day, that's exactly what I want and need. I've been to Starbucks all over California and Nevada, across the west coast up to Canada where I've been told along the way that my Venti Iced half decaf Caramel Drizzle Latte is a Venti Iced Halfcaf Latte with caramel sauce. I don't care! Give me my coffee! I've been told the vanilla bean powder I want in my Cold Brew Venti Iced Double Soy Latte is supposed to be for a hot drink. I don't care (and $7, seriously NV/CA Stateline Starbucks?!)! If I wanted you to order for me, do you think I would waste time in line? Stephanie/Horizon Ridge do it right!"}),
#  ('wG19Unm8462ABerQC3xhYA',
#   {'stars': 4,
#    'text': "Amazing place to feel like a community. The coffees great, they offer almond milk and gluten free cookies (THE BUCKWHEAT DOUBLE CHOCOLATE COOKIES ARE TO DIE FOR), the staff  could be a little more inviting but in the end who wants that!\n\nBring your lap top on over and get coffee. they change the table positions almost' every week so they are obviously in the process of greatness. Don't go on a weekend morning if you want to sit down, totally packed. oh! and get a paninied sandwich, it'll make your week!"}),
#  ('o_NHFvTunCzEiWwdsQU-tw',
#   {'stars': 5,
#    'text': 'What a great treat! My best friend really wanted to try to place out so on our spontaneous food adventure, we stopped by. \n\nWhat a great treat it was. We shared the red bean icecream waffle with black sesame and green tea icecream. It was so yummy! We also got two boxes of the original red bean waffle to bring home to our family. They loved it! \n\nWhat makes the experience that much better is knowing this little place is run by a lovely family. \n\nWill be back! Thanks again for the great experience :)'}),
#  ('BhsJ6jhgZll4MwhFnxYAHA',
#   {'stars': 4,
#    'text': "This is my family's favorite place for Japanese style pasta. But for a period of time, their standards slipped a bit. For a while, their food had been hit or miss, service slacked. We stopped going until last week. \n\nThey have a brand new lunch menu, which is quite exciting. There's a whole page of new items on top of the familiar pastas they've got. We tried some of the new items. 2 of them were outstanding! The Unagi Tamago Dashi Rice was absolutely delicious! The egg with the dashi sauce on top of the rice goes nicely with the unagi. The Yaki Udon is the best I've had so far. I never liked yaki udon. Most of the time the noodles are tasteless. Not the ones here. It has a nice sauce, in which the udon full absorbed the taste, and the dish was serve covered with bonito flakes, seaweed and green onion. Not to mention lots of pork slices fried with the noodles. \n\nWe had a large group, so we also ordered other dishes. The pastas were as good as before and the Banana Crepes was what I remembered. \n\nService is good. Maybe still not back to their old standard. But improved from their low time. \n\nWe can see that they made a great effort to come back, and they did a good job. \n\nWill keep an eye to see if they can keep it up."}),
#  ('_-ELLMIYHNqfxIe2XReS5A',
#   {'stars': 4,
#    'text': "Solid boba option- bonus points for being open late, which really is the only reason I stopped in. I had never heard of the boba babes concept before, and was a little intimidated to visit solo.  But ever since that first visit, I've been back several times for UYEs and late-night boba cravings after hitting the gym.\n\nService is attentive and friendly, owner CD is a great guy and a fellow Yelper, the boba babes have sweet personalities to match their stellar appearances- thigh-tattoo girl is probably my favorite, she's there most frequently when I go.\n\nPricing is reasonable, boba is never mushy, menu is simple but has a lot of options: rose milk tea, taro milk tea, and iced green tea are frequent picks, but they also have a good Vietnamese coffee. Love their heart-shaped straws and glass jars for dining-in. Menu also has a few snacks: heads up that the hot wings are actually hot."}),
#  ('AOfk4Al3aAi-HtoeLtIgkg',
#   {'stars': 4,
#    'text': "I read a lot of positive reviews about this place so when I was in this part of town I stopped by Sambalatte and ordered a caramel latte and veggie quiche. My hot drink is rather delicious, with a faint hint of caramel and espresso while the veggie quiche was very good. I frequent Sunrise Coffee quite a lot and if I were to compare this drink here with my usual caramel macchiato at Sunrise, I think Sambalatte's caramel latte tasted like it may have more caloric content. So if you are health conscious like me and only like one particular drink, maybe it's better to opt for the one at Sunrise.\n\nIf I ever find myself in the NW area of Vegas, I am definitely stopping by here again and try the salmon quiche plus a caramel hot espresso drink!"}),
#  ('agGD9eYP-yjVPxrMtR9kcA',
#   {'stars': 3,
#    'text': 'Sorry Tea Station but you aite. \n\nWith the influx of new and improved boba shops in the greater Las Vegas area, you are no longer on my tea radar. \n\nBut nonetheless a viable option in the general Spring Mountain vicinity.'}),
#  ('gQ9tnGgGPezB71A1oVVw0g',
#   {'stars': 3,
#    'text': 'When a coworker and I were in Cleveland earlier last week, we wanted a place to grab a cup of coffee and chat before our meeting. Downtown Cleveland, which sports some impressive architecture but appears to be largely under construction, isn\'t a hot spot of coffee shops. We were hard pressed to find anywhere to go.\n\nA man stopped on the sidewalk and asked if he could help us. "Where does a fella go for a cup of coffee?" I asked. "I don\'t drink coffee," he replied. "Tea? Something like that?" "People seem to like the Cork & Bean. It\'s downstairs around the corner a couple of entrances in."\n\nBelieve it or not, we found it. Basically, one of the downtown bank buildings seems to have a warren of shops and eateries in its basement, and one of those was a tidy little coffee shop with a tiny counter -- and lots of wine- and coffee-related knick knacks and tools on display. We got a chai and a coffee to go. Prices were quite reasonable, and the countervolk were quite nice.\n\nThere was nowhere to sit, though. So we went and sat in the bank lobby between the loan advisors and safety deposit boxes.'}),
#  ('ZCItFhn91LUlo4EKc5PWZA',
#   {'stars': 3,
#    'text': "After some walking around, we stopped by for some drinks and munchies.\n\nThe restaurant is big and clean; the service was good. We were seated at a table by the window on St. Laurent so we got to people watch.\n\nThey serve everything chocolate - hot chocolates, alcoholic drinks, desserts, crepes & ice cream. \n\nThere were 3 of us and we each wanted to order a drink and split 2 crepes. But we were told that you have to order a crepe with each alcoholic drink. I don't believe the same rule applies to non-alcoholic chocolate drinks. So we ended up splitting 2 drinks and 2 crepes amongst the 3 of us.\n\nThe choco-mojito and Irish chocolate drinks were good. The choco-mojito was kinda thick though. The Irish chocolate is chocolate milk with whiskey (served warm).\n\nTheir crepes are made from buckwheat; they were thin and light. We ordered a turkey pesto crepe which was delicious. We also ordered a dark chocolate/banana/strawberry crepe. They were out of strawberry so they substituted blackberries instead. The dark chocolate was really good, not too sweet. \n\nAs others noted, this place is on the pricier side. Most drinks (even non-alcoholic) are above $6 dollars. You also cannot buy a drink at the counter and sit down, you must get waiter service."}),
#  ('M1yfoxxbE2KrAujo4nXAOA',
#   {'stars': 1,
#    'text': "AVOID AT ALL COSTS... \nI understand, you're hungry, it's early or late.  $10 for a croissant and coffee is ridiculous, stay away from anything inside the MGM, rip off! Especially the mini variety stores, shame."}),
#  ('0D6SFLJbyaquU4QcpxKC6w',
#   {'stars': 1,
#    'text': "The bubble tea was way better when it was Steepery, even better than Kungfu. I dont know if they changed the recipes when it became Sencha but the royal tea latte now tastes artificial sweetened.Also, I ordered the lavender lush, and it honestly tastes like medicine. I guess I'll stick with Kungfu Tea for now."}),
#  ('ZwDi-rq_auB4i_GNVk5Xrw',
#   {'stars': 5,
#    'text': 'Just saying.. Everyone is always so nice as usual. Traffic seems to have let up before 9. Enjoy a nice iced coffee on a warm day!'}),
#  ('gfENEuKbaVBTyamok2pZyQ',
#   {'stars': 5,
#    'text': "I'm sure you've read all the other comments in here about how great this place is so I'll add a new thing they have done.  And I'm talking about the expanded and more regular kitchen.  Before you could only order cooked food for a few hours a day.  Now, it's basically always going.  and the food is as good as ever!"}),
#  ('xHFLiM50PP2JuvbKUwBq_g',
#   {'stars': 1,
#    'text': 'The barista was verbally abusive and openly disrespectful and you could tell that it was an uncomfortable experience for all the other staff and customers that were involved. I was really disappointed to see the way the barista was treating the rest of staff. The coffee and the snacks are passable - what is expected from an aroma location, but the customer experience will never exceed the employee experience.'}),
#  ('_teUuim_g_ITiaoYHSIJXw',
#   {'stars': 5,
#    'text': 'Really nice place, great food and service! Looks and feels like a traditional diner... All the breakfasts are good!!'}),
#  ('MJTwCpMXvpeAF7w_MrV40g',
#   {'stars': 5,
#    'text': "I was in Phoenix for just 2 days and managed to hit this spot up twice!!!! I really wish they had one in LA.\n\nAll vegan blizzards, tons of baked goods=my paradise!\n\nMy favorites were the Monsoon special (choc cake, choc chips, and choc syrup) which I added PB too and another one with pretzels, PB and chocolate chips.\n\nCan't wait to come back on my next trip to Phoenix. They have a sister veg restaurant next door that I can't wait to try too (yes I may have just eaten Tsoynamis for dinner)."}),
#  ('iVAepvCRYS5ErI-a-ilXpA',
#   {'stars': 5,
#    'text': "Ok, I pretty much love this place! The dudes that work here and/or own it are very cool and friendly.  They aren't bad to look at either, I'm just saying. I just like to hang out here.\n\nThey are doing some remodeling and in general making this place even better. They are adding some sort of juice bar component soon, which is great. \n\nOne dude knew who I was by my Yelp review, which was cool & a little scary.  He had a great take on Yelp though, and has the right attitude that a lot of the feedback can be constructive.\n\nOne guy working there wasn't a Yelp fan, which was fine with me, he gave perfect service and made me feel totally welcome.  I respect his point of view. We all don't have to like the same things...right.\n\nThey know my stance on pillows there, and I would love it if they would stay open longer on weekends. I will bring my own Baileys....Please!!!!!\n\nSeriously great place."}),
#  ('fCq4JrFmlt21Rg3GRmgNZg',
#   {'stars': 1,
#    'text': 'Went to dunkin this morning. The people that work there are rude. They look at you funny. No smiles. Slammed my coffee on the counter. It was and older man and woman. Looked of Indian descent. Possible owners. I only go to this  one sometimes because it is the closest to my house. But it the worst one around. Coffees are never right. Terrible customer service !!'}),
#  ('HKE8C7AYVcw9ZeQUQxbvwQ',
#   {'stars': 5,
#    'text': "Found on renowned Roosevelt Row, Songbird possesses a quaint yet modern feel. They have a tasty selection of both hot and iced teas (I'm not a coffee drinker.) Also, they make a matcha green tea latte with almond milk. As someone with both dairy and soy allergies I'm often dismayed by the availability of only cow's milk or soy milk at most coffee shops. I'm very happy to have found a place in my neighborhood that can make this tasty treat just the way I like."}),
#  ('mg9cpBaQLeDvQGHIcYTG-Q',
#   {'stars': 5,
#    'text': "This is a great little coffee house and awesome bakery it's is not called madhouse though...its called wake up coffee cafe."}),
#  ('lAJhl5ZtRzFcz7LqHcRpGA',
#   {'stars': 5,
#    'text': 'One of the best spot to eat if you are Vegan. I really enjoyed their Vegan rolls and salads with tofu. The service is speedy and the prices are reasonable. Their sweets are good and with very low calories count.'})]

# %%
# Split review into sentences, remove stopwords, extract parts-of-speech tags
# (opt. if lots of reviews) store each review into MongoDB db called 'Reviews'

stopWords = set(stopwords.words('english'))

for revId in reviewData:
    reviewWords = []
    sentences = nltk.sent_tokenize(reviewData[revId]['text'].lower())
    
    for sentence in sentences:
        tokens = nltk.word_tokenize(sentence)
        text = [w for w in tokens if w not in stopWords]
        tagged_text = nltk.pos_tag(text)
        
        for word, tag in tagged_text:
            reviewWords.append({'word': word, 'pos': tag})
    
    reviewData[revId]['review_words'] = reviewWords

list(reviewData.items())[:100]
# Out:
# [('z--dbq4Qegp23GdECZYI9A',
#   {'review_words': [{'pos': 'NN', 'word': 'love'},
#     {'pos': 'NN', 'word': 'location'},
#     {'pos': 'IN', 'word': 'since'},
#     {'pos': 'JJ', 'word': 'close'},
#     {'pos': 'NN', 'word': 'home'},
#     {'pos': 'NN', 'word': 'work'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'wish'},
#     {'pos': 'NN', 'word': 'drive'},
#     {'pos': 'NN', 'word': 'thru'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'VBD', 'word': 'said'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'RB', 'word': 'recently'},
#     {'pos': 'VBN', 'word': 'gone'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'go'},
#     {'pos': 'JJ', 'word': 'everyday'},
#     {'pos': 'NN', 'word': 'matter'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': 'VBP', 'word': 'go'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'RB', 'word': 'wait'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBZ', 'word': 'seems'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'person'},
#     {'pos': 'VBG', 'word': 'making'},
#     {'pos': 'NNS', 'word': 'drinks'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBP', 'word': "'m"},
#     {'pos': 'VBG', 'word': 'assuming'},
#     {'pos': 'JJ', 'word': 'short'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'VBG', 'word': 'working'},
#     {'pos': 'VBZ', 'word': 'seems'},
#     {'pos': 'VBN', 'word': 'stressed'},
#     {'pos': 'JJ', 'word': 'happy'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'feel'},
#     {'pos': 'VBG', 'word': 'relaxing'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'hopefully'},
#     {'pos': 'NNS', 'word': 'things'},
#     {'pos': 'VBP', 'word': 'get'},
#     {'pos': 'RB', 'word': 'back'},
#     {'pos': 'JJ', 'word': 'normal'},
#     {'pos': 'RB', 'word': 'soon'},
#     {'pos': 'VBP', 'word': 'love'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 3,
#    'text': "I love the location since its so close to home and work. I WISH they had a drive thru! With that being said, the service has recently gone down. I go about everyday and no matter what time I go there is always a wait. It seems like only one person is making the drinks. I'm assuming they are just short of staff. The staff that is working there seems very stressed out and not happy. Just doesn't feel very relaxing. Hopefully things get back to normal soon as I do love my coffee!"}),
#  ('fMQUroqu5LzPfIGiwdvmwA',
#   {'review_words': [{'pos': 'NN', 'word': 'beau'},
#     {'pos': 'NN', 'word': 'petit'},
#     {'pos': 'NN', 'word': 'café'},
#     {'pos': '``', 'word': '``'},
#     {'pos': 'CD', 'word': '3e'},
#     {'pos': 'NN', 'word': 'vague'},
#     {'pos': "''", 'word': "''"},
#     {'pos': 'NN', 'word': 'près'},
#     {'pos': 'FW', 'word': 'de'},
#     {'pos': 'NN', 'word': 'mcgill'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'CD', 'word': '4,50'},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'JJ', 'word': 'le'},
#     {'pos': 'NN', 'word': 'latté'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'JJ', 'word': 'il'},
#     {'pos': 'NNP', 'word': 'était'},
#     {'pos': 'NN', 'word': 'bon'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'ça'},
#     {'pos': 'NN', 'word': 'fait'},
#     {'pos': 'NN', 'word': 'changement'},
#     {'pos': 'VBZ', 'word': 'des'},
#     {'pos': 'NNS', 'word': 'autres'},
#     {'pos': 'JJ', 'word': 'second'},
#     {'pos': 'NN', 'word': 'cup'},
#     {'pos': 'NN', 'word': 'ou'},
#     {'pos': 'NNS', 'word': 'starbucks'},
#     {'pos': 'VBP', 'word': 'au'},
#     {'pos': 'NN', 'word': 'centre-ville'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'wi-fi'},
#     {'pos': 'NN', 'word': 'gratuit'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'par'},
#     {'pos': 'NN', 'word': 'contre'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'le'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'NN', 'word': 'était'},
#     {'pos': 'NN', 'word': 'correct'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'même'},
#     {'pos': 'NN', 'word': 'pas'},
#     {'pos': 'JJ', 'word': 'un'},
#     {'pos': 'NN', 'word': 'sourire'},
#     {'pos': 'NN', 'word': 'et'},
#     {'pos': 'JJ', 'word': 'un'},
#     {'pos': 'NN', 'word': 'merci'},
#     {'pos': 'NN', 'word': 'du'},
#     {'pos': 'NN', 'word': 'jeune'},
#     {'pos': 'NN', 'word': 'proprio'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'mon'},
#     {'pos': 'NN', 'word': 'latté'},
#     {'pos': 'NN', 'word': 'déposé'},
#     {'pos': 'NN', 'word': 'sur'},
#     {'pos': 'NN', 'word': 'le'},
#     {'pos': 'NN', 'word': 'comptoir'},
#     {'pos': 'NNS', 'word': 'sans'},
#     {'pos': 'VBP', 'word': 'rien'},
#     {'pos': 'JJ', 'word': 'dire'},
#     {'pos': 'NN', 'word': 'et'},
#     {'pos': 'VBP', 'word': 'continue'},
#     {'pos': 'JJ', 'word': 'sa'},
#     {'pos': 'NN', 'word': 'conversation'},
#     {'pos': 'IN', 'word': 'avec'},
#     {'pos': 'NN', 'word': 'son'},
#     {'pos': 'NN', 'word': 'associé'},
#     {'pos': ':', 'word': '...'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'bof'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': "j'aime"},
#     {'pos': 'JJ', 'word': 'un'},
#     {'pos': 'NN', 'word': 'peu'},
#     {'pos': 'NNS', 'word': 'moins'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 3,
#    'text': 'Beau petit café "3e vague" près de McGill, 4,50 $ le latté ! Il était bon. Ça fait changement des autres Second Cup ou Starbucks au centre-ville. Wi-fi gratuit. Par contre, le service était correct, même pas un sourire et un merci du jeune proprio, mon latté déposé sur le comptoir sans rien dire et continue sa conversation avec son associé.... bof, j\'aime un peu moins.'}),
#  ('v6qi_7mTgPIu0tiqnlSNDw',
#   {'review_words': [{'pos': 'NN', 'word': 'place'},
#     {'pos': 'RBS', 'word': 'best'},
#     {'pos': 'NN', 'word': 'empanada'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'RB', 'word': 'ever'},
#     {'pos': 'VBZ', 'word': 'hands'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'definitely'},
#     {'pos': 'JJ', 'word': 'recommend'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'RB', 'word': 'friendly'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBG', 'word': 'returning'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': "This place has the best empanada's I have ever had hands down. I definitely recommend this place and staff are very friendly. I will be returning here again."}),
#  ('DJVYvizn6H6vDkLGgkjT9w',
#   {'review_words': [{'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'good'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'topped'},
#     {'pos': 'VBD', 'word': 'tired'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'want'},
#     {'pos': 'NN', 'word': 'mill'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'JJ', 'word': '^-^'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'eaten'},
#     {'pos': 'JJ', 'word': 'bagel'},
#     {'pos': 'RB', 'word': 'yet'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'veggie'},
#     {'pos': 'NN', 'word': 'cream'},
#     {'pos': 'JJ', 'word': 'cheese'},
#     {'pos': 'NN', 'word': 'price'},
#     {'pos': 'NN', 'word': 'regular'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'yay'},
#     {'pos': 'JJ', 'word': 'free'},
#     {'pos': 'NNS', 'word': 'veggies'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'UH', 'word': 'oh'},
#     {'pos': 'NN', 'word': 'yea'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NNS', 'word': 'bagels'},
#     {'pos': 'VBP', 'word': 'huuuuujuh'},
#     {'pos': '.', 'word': '.'},
#     {'pos': ':', 'word': ';'},
#     {'pos': ':', 'word': '-'},
#     {'pos': ')', 'word': ')'}],
#    'stars': 4,
#    'text': "Coffee was good. She topped it off for me because I was so tired I didn't want mill. More coffee!! ^-^  Haven't eaten my bagel yet, but veggie cream cheese was same price as regular. Yay free veggies!  Oh yea, and the bagels are huuuuujuh. ;-)"}),
#  ('vxe8EVPctkpXO1NnXoMX1A',
#   {'review_words': [{'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NN', 'word': 'gelato'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'awesome'},
#     {'pos': 'NN', 'word': 'cannoli'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'MD', 'word': 'ca'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'beat'},
#     {'pos': 'PRP', 'word': "'em"},
#     {'pos': '.', 'word': '.'}],
#    'stars': 4,
#    'text': "Good gelato, awesome cannoli's. You just can't beat 'em."}),
#  ('PnjqwzBg0QWDRpzAAZSHVw',
#   {'review_words': [{'pos': 'NN', 'word': 'amazing'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'NN', 'word': 'pistachio'},
#     {'pos': 'NN', 'word': 'gelato'},
#     {'pos': 'NN', 'word': 'summer'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'JJ', 'word': 'clean'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'NN', 'word': 'love'},
#     {'pos': 'NNS', 'word': 'locations'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'fav'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 5,
#    'text': 'Amazing ! \nI love their pistachio gelato during summer time ! \nTheir service is great and the place is always clean! \nI love all their locations but this one is my fav!'}),
#  ('IFSUispv-wZIGi_GtZXupg',
#   {'review_words': [{'pos': 'JJ', 'word': 'bad'},
#     {'pos': 'NNS', 'word': 'reviews'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBN', 'word': 'limited'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'cute'},
#     {'pos': 'JJ', 'word': 'little'},
#     {'pos': 'JJ', 'word': 'asian'},
#     {'pos': 'NN', 'word': 'bakery'},
#     {'pos': 'IN', 'word': 'around'},
#     {'pos': 'NN', 'word': 'area'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'asia'},
#     {'pos': 'NN', 'word': 'town'},
#     {'pos': 'RB', 'word': 'quite'},
#     {'pos': 'JJ', 'word': 'unimpressive'},
#     {'pos': 'RB', 'word': 'severely'},
#     {'pos': 'VBG', 'word': 'limiting'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'cwru'},
#     {'pos': 'NN', 'word': 'student'},
#     {'pos': 'RB', 'word': 'hardly'},
#     {'pos': 'JJ', 'word': 'asian'},
#     {'pos': 'NNS', 'word': 'restaurants'},
#     {'pos': 'RB', 'word': 'close'},
#     {'pos': 'VBP', 'word': 'start'},
#     {'pos': 'JJ', 'word': 'little'},
#     {'pos': 'NN', 'word': 'bakery'},
#     {'pos': 'RB', 'word': 'cheap'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBZ', 'word': 'takes'},
#     {'pos': 'CD', 'word': '25'},
#     {'pos': 'NNS', 'word': 'mins'},
#     {'pos': 'VBP', 'word': 'get'},
#     {'pos': 'NN', 'word': 'koko'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'rta'},
#     {'pos': 'MD', 'word': 'may'},
#     {'pos': 'VB', 'word': '10-15'},
#     {'pos': 'NNS', 'word': 'minutes'},
#     {'pos': 'NN', 'word': 'car'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'wish'},
#     {'pos': 'JJR', 'word': 'closer'},
#     {'pos': 'JJ', 'word': 'asian'},
#     {'pos': 'NNS', 'word': 'restaurants'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'NN', 'word': 'bread'},
#     {'pos': 'NN', 'word': 'selection'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'JJ', 'word': 'wide'},
#     {'pos': 'NN', 'word': 'variety'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'VBP', 'word': 'seem'},
#     {'pos': 'JJ', 'word': 'fresh'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'bubble'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJR', 'word': 'better'},
#     {'pos': 'NNS', 'word': 'ones'},
#     {'pos': 'VBP', 'word': "'ve"},
#     {'pos': 'NN', 'word': 'coventry'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'sweets'},
#     {'pos': 'RB', 'word': 'also'},
#     {'pos': 'VBP', 'word': 'look'},
#     {'pos': 'JJ', 'word': 'adorable'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'fun'},
#     {'pos': 'NN', 'word': 'eating'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 4,
#    'text': "If there are any bad reviews, then they have limited themselves. This is the only cute little asian bakery around the area. Asia town itself is quite unimpressive and severely limiting. As a CWRU student there are hardly any Asian restaurants close by to start out with and this little bakery is cheap and delicious. \n\nIt takes about 25 mins to get to Koko's by RTA and may 10-15 minutes by car. I wish we had closer asian restaurants and such. \n\nI love their bread selection, they is always a wide variety and they always seem fresh. Their bubble tea is good, better than the ones I've had in Coventry. Their sweets also look adorable, so it's fun eating those."}),
#  ('nMccamehHFJMX05DZqoPfg',
#   {'review_words': [{'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'good'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'VBP', 'word': "'m"},
#     {'pos': 'JJ', 'word': 'much'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'drinker'},
#     {'pos': 'NNS', 'word': 'items'},
#     {'pos': 'VBP', 'word': 'menu'},
#     {'pos': 'JJR', 'word': 'cater'},
#     {'pos': 'NN', 'word': 'anyone'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'food'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NN', 'word': 'delicious'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'counter'},
#     {'pos': 'NN', 'word': 'girl'},
#     {'pos': 'VBN', 'word': 'named'},
#     {'pos': 'MD', 'word': 'may'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VB', 'word': 'awesome'},
#     {'pos': 'JJR', 'word': 'super'},
#     {'pos': 'RB', 'word': 'friendly'},
#     {'pos': 'VB', 'word': 'help'},
#     {'pos': 'NN', 'word': 'order'},
#     {'pos': 'RB', 'word': 'properly'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': "Coffee is so good! I'm not much of a coffee drinker but there are items on the menu that can cater to anyone. The food is really good and delicious. At the counter was a girl named May, she is awesome and super friendly and will help you order properly."}),
#  ('kD4LMZM94TF60CN8xNmA2g',
#   {'review_words': [{'pos': 'NN', 'word': 'love'},
#     {'pos': 'NN', 'word': 'warm'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBN', 'word': 'relaxed'},
#     {'pos': 'RB', 'word': 'atmosphere'},
#     {'pos': 'NN', 'word': 'phoenix'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'compared'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'lee'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'spacious'},
#     {'pos': 'NN', 'word': 'busy'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'RB', 'word': 'usually'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'JJ', 'word': 'quiet'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'VBG', 'word': 'going'},
#     {'pos': 'NN', 'word': 'study'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'VBG', 'word': 'trying'},
#     {'pos': 'JJ', 'word': 'seasonal'},
#     {'pos': 'NNS', 'word': 'creations'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'even'},
#     {'pos': 'JJ', 'word': 'non-coffee'},
#     {'pos': 'NNS', 'word': 'ones'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'NN', 'word': 'decor'},
#     {'pos': 'VBN', 'word': 'repurposed'},
#     {'pos': 'JJ', 'word': 'recycled'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBZ', 'word': 'makes'},
#     {'pos': 'JJ', 'word': 'eclectic'},
#     {'pos': 'NNS', 'word': 'funky'},
#     {'pos': 'NN', 'word': 'decor'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'thing'},
#     {'pos': 'VBZ', 'word': 'brings'},
#     {'pos': 'NN', 'word': 'phoenix'},
#     {'pos': 'NNS', 'word': 'starbucks'},
#     {'pos': 'VBP', 'word': 'desire'},
#     {'pos': 'NN', 'word': 'support'},
#     {'pos': 'NN', 'word': 'quality'},
#     {'pos': 'JJ', 'word': 'local'},
#     {'pos': 'NN', 'word': 'business'},
#     {'pos': 'VBD', 'word': 'invested'},
#     {'pos': 'NN', 'word': 'community'},
#     {'pos': 'NN', 'word': 'environment'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'local'},
#     {'pos': 'JJ', 'word': 'global'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'compostable'},
#     {'pos': 'NNS', 'word': 'cups'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'charge'},
#     {'pos': 'CD', 'word': '10'},
#     {'pos': 'NNS', 'word': 'cents'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBG', 'word': 'bring'},
#     {'pos': 'VBP', 'word': "'re"},
#     {'pos': 'VBG', 'word': 'getting'},
#     {'pos': 'NN', 'word': 'drink'},
#     {'pos': 'VBP', 'word': 'go'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'VBG', 'word': 'speaking'},
#     {'pos': '``', 'word': '``'},
#     {'pos': 'VB', 'word': 'go'},
#     {'pos': "''", 'word': "''"},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'location'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'drive-thru'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBP', 'word': "'re"},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'VB', 'word': 'run'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'DT', 'word': 'either'},
#     {'pos': 'NN', 'word': 'way'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'sure'},
#     {'pos': 'NN', 'word': 'stop'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 4,
#    'text': 'I love the warm, relaxed atmosphere at Phoenix.  Compared to the one on Lee, it\'s more spacious and not as busy.  It\'s usually nice and quiet, so I love going there to study.  I love trying their seasonal creations, even the non-coffee ones.  I love how the decor is repurposed and recycled too, which makes for an eclectic and funky decor. \n\nThe thing that brings me to Phoenix over Starbucks is my desire to support a quality local business that is invested in the community and environment, both local and global.  They now have compostable cups, but charge 10 cents for them, so bring your own if you\'re getting your drink to go!   \n\nSpeaking of "to go", this location is the only one with a drive-thru, if you\'re really on the run.  Either way, be sure to stop on by!'}),
#  ('ruXalyTBOTqh6QAtC6kavA',
#   {'review_words': [{'pos': 'NNS', 'word': 'pros'},
#     {'pos': ':', 'word': ':'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'sweet'},
#     {'pos': 'NNS', 'word': 'people'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'highly'},
#     {'pos': 'JJ', 'word': 'recommend'},
#     {'pos': 'NNS', 'word': 'crepes'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'cons'},
#     {'pos': ':', 'word': ':'},
#     {'pos': 'NN', 'word': 'gelato'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'JJ', 'word': 'italian'},
#     {'pos': 'NN', 'word': 'gelato'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'JJ', 'word': 'regular'},
#     {'pos': 'NN', 'word': 'ice'},
#     {'pos': 'NN', 'word': 'cream'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'disappointed'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 3,
#    'text': "Pros: Great service, sweet people. I highly recommend their crepes.\n\nCons: Gelato isn't Italian gelato, more like just regular ice cream. I was disappointed."}),
#  ('3xIVNGCBi9UNbRpPi_jp7g',
#   {'review_words': [{'pos': 'VBD', 'word': 'went'},
#     {'pos': 'JJ', 'word': 'late'},
#     {'pos': 'NN', 'word': 'saturday'},
#     {'pos': 'NN', 'word': 'brunch'},
#     {'pos': 'VBD', 'word': 'got'},
#     {'pos': 'VBN', 'word': 'seated'},
#     {'pos': 'RB', 'word': 'right'},
#     {'pos': 'RB', 'word': 'away'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'NN', 'word': 'bit'},
#     {'pos': 'VBZ', 'word': 'hands'},
#     {'pos': 'JJ', 'word': 'huge'},
#     {'pos': 'NN', 'word': 'issue'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'stuffed'},
#     {'pos': 'JJ', 'word': 'french'},
#     {'pos': 'NN', 'word': 'toast'},
#     {'pos': 'NN', 'word': 'delightful'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': 'Went for a late Saturday brunch and got seated right away.  The service was a bit hands off but not a huge issue.  I had the stuffed french toast which was delightful.'}),
#  ('drobVS9vfa8Dz-qpnzcIsA',
#   {'review_words': [{'pos': 'RB', 'word': 'pricey'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBZ', 'word': 'comes'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'MD', 'word': "'ll"},
#     {'pos': 'VB', 'word': 'take'},
#     {'pos': 'JJ', 'word': 'expensive'},
#     {'pos': 'NNS', 'word': 'cheap'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'use'},
#     {'pos': 'RB', 'word': 'illy'},
#     {'pos': 'JJ', 'word': 'espresso'},
#     {'pos': 'JJ', 'word': 'cheap'},
#     {'pos': 'NNS', 'word': 'starbucks'},
#     {'pos': 'NN', 'word': 'crap'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'JJ', 'word': 'white'},
#     {'pos': 'NN', 'word': 'chocolate'},
#     {'pos': 'VBD', 'word': 'iced'},
#     {'pos': 'NN', 'word': 'latte'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'perfect'},
#     {'pos': 'JJ', 'word': 'stop'},
#     {'pos': 'NNS', 'word': 'hangovers'},
#     {'pos': 'JJ', 'word': 'pick-me-up'},
#     {'pos': 'VBG', 'word': 'hitting'},
#     {'pos': 'JJ', 'word': 'craps'},
#     {'pos': 'NNS', 'word': 'tables'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'NNS', 'word': 'understands'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 4,
#    'text': "Pricey but good.\nWhen it comes to coffee I'll take expensive over cheap.  They use illy espresso not cheap Starbucks crap.\nI love their white chocolate iced latte. Perfect stop for hangovers or a pick-me-up before hitting the craps tables.\n\nThe staff is very nice and understands how I like my coffee."}),
#  ('VyOE--7RNRAf2L5tCKywrQ',
#   {'review_words': [{'pos': 'NN', 'word': 'event'},
#     {'pos': 'NN', 'word': 'saturday'},
#     {'pos': 'VBG', 'word': 'evening'},
#     {'pos': 'NNS', 'word': 'errands'},
#     {'pos': 'VBD', 'word': 'wanted'},
#     {'pos': 'NN', 'word': 'get'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': '10pm'},
#     {'pos': 'DT', 'word': 'every'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'VBD', 'word': 'closed'},
#     {'pos': 'VBD', 'word': 'looked'},
#     {'pos': 'JJS', 'word': 'newest'},
#     {'pos': 'NNS', 'word': 'starbucks'},
#     {'pos': 'JJ', 'word': 'open'},
#     {'pos': 'NN', 'word': 'til'},
#     {'pos': 'NN', 'word': 'midnight'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'VBP', 'word': 'find'},
#     {'pos': 'JJ', 'word': 'cinemark'},
#     {'pos': 'NN', 'word': 'theatre'},
#     {'pos': 'IN', 'word': 'across'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'green'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': 'VBP', 'word': 'dave'},
#     {'pos': 'VBN', 'word': 'carmel'},
#     {'pos': 'NN', 'word': 'macchiato'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'plenty'},
#     {'pos': 'NNS', 'word': 'tables'},
#     {'pos': 'VBG', 'word': 'sitting'},
#     {'pos': 'NNS', 'word': 'areas'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'VBP', 'word': 'see'},
#     {'pos': 'JJ', 'word': 'many'},
#     {'pos': 'NNS', 'word': 'people'},
#     {'pos': 'VBG', 'word': 'hanging'},
#     {'pos': 'VBG', 'word': 'enjoying'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'look'},
#     {'pos': 'RB', 'word': 'forward'},
#     {'pos': 'VBG', 'word': 'sitting'},
#     {'pos': 'NN', 'word': 'patio'},
#     {'pos': 'NN', 'word': 'weather'},
#     {'pos': 'NNS', 'word': 'warms'},
#     {'pos': 'VBP', 'word': 'up.im'},
#     {'pos': 'VBN', 'word': 'thrilled'},
#     {'pos': 'VBP', 'word': 'find'},
#     {'pos': 'NNS', 'word': 'hours'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 4,
#    'text': 'Had an event Saturday evening and errands wanted get a coffee or tea. It was only 10pm and every place was closed so looked up the newest Starbucks and open til midnight. This was nice to find out as cinemark theatre is across from them. I had a green tea and dave had Carmel Macchiato. Plenty of tables and sitting areas and was nice to see so many people just hanging out enjoying their coffee. I look forward to sitting on patio when weather warms up.im just thrilled to find out the hours!!'}),
#  ('nkDnI2_4GOIDZrlDX9hjuA',
#   {'review_words': [{'pos': 'NN', 'word': 'name'},
#     {'pos': 'VBZ', 'word': 'implies'},
#     {'pos': 'NN', 'word': 'everyone'},
#     {'pos': 'NNS', 'word': 'points'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NNS', 'word': 'cupcakes'},
#     {'pos': 'RB', 'word': 'indeed'},
#     {'pos': 'VBP', 'word': 'jumbo'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'JJ', 'word': 'typical'},
#     {'pos': 'JJ', 'word': 'trendy'},
#     {'pos': 'JJ', 'word': 'smallish'},
#     {'pos': 'NNS', 'word': 'cupcakes'},
#     {'pos': 'VBN', 'word': 'used'},
#     {'pos': 'RB', 'word': 'northeast'},
#     {'pos': 'JJ', 'word': 'la'},
#     {'pos': 'NNS', 'word': 'magnolia'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBD', 'word': 'got'},
#     {'pos': 'JJ', 'word': 'simple'},
#     {'pos': 'NN', 'word': 'vanilla'},
#     {'pos': 'VB', 'word': 'cupcake'},
#     {'pos': 'JJ', 'word': 'thoroughly'},
#     {'pos': 'VBN', 'word': 'enjoyed'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBG', 'word': 'frosting'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': 'JJ', 'word': 'full'},
#     {'pos': 'NN', 'word': 'flavor'},
#     {'pos': 'VBP', 'word': 'cake'},
#     {'pos': 'NN', 'word': 'moist'},
#     {'pos': 'NN', 'word': 'tasty'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'thank'},
#     {'pos': 'NN', 'word': 'colossal'},
#     {'pos': 'NNS', 'word': 'cupcakes'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 4,
#    'text': 'As the name implies and as everyone points out, the cupcakes are indeed jumbo! Not your typical trendy smallish cupcakes I have been used to in the northeast a la Magnolia.\nI got the simple Vanilla cupcake and thoroughly enjoyed it. The frosting was delicious and full of flavor and the cake itself was moist and tasty. Thank you Colossal Cupcakes!'}),
#  ('d3UCFd_8PTFdL2D7_xu7vA',
#   {'review_words': [{'pos': 'NN', 'word': 'omg'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'NN', 'word': 'jerk'},
#     {'pos': 'NN', 'word': 'sausage'},
#     {'pos': 'NN', 'word': 'amazing'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'chocolate'},
#     {'pos': 'NN', 'word': 'cake'},
#     {'pos': 'JJ', 'word': 'solid'},
#     {'pos': 'NN', 'word': 'sin'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': 'omg! delicious! jerk sausage is amazing. chocolate cake is solid sin.'}),
#  ('eTHEvGiJeM3REsIfsFcYDA',
#   {'review_words': [{'pos': 'VB', 'word': 'love'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'JJ', 'word': 'live'},
#     {'pos': 'RB', 'word': 'close'},
#     {'pos': 'NN', 'word': 'visit'},
#     {'pos': 'NN', 'word': 'offten'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'remember'},
#     {'pos': 'NN', 'word': 'order'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'RB', 'word': 'genuinely'},
#     {'pos': 'JJ', 'word': 'happy'},
#     {'pos': 'JJ', 'word': 'interested'},
#     {'pos': 'NNS', 'word': 'clients'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'thankful'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': 'Love the staff and service! I live close and visit offten. They all remember my order! So genuinely happy and interested in their clients. Thankful.'}),
#  ('-oIXdKSuFo3NptY4rDLUVQ',
#   {'review_words': [{'pos': 'NN', 'word': 'place'},
#     {'pos': 'JJ', 'word': 'solid'},
#     {'pos': 'NN', 'word': 'cafe'},
#     {'pos': 'JJ', 'word': 'solid'},
#     {'pos': 'NN', 'word': 'food'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBP', 'word': "'ve"},
#     {'pos': 'VBN', 'word': 'lox'},
#     {'pos': 'NN', 'word': 'omelet'},
#     {'pos': 'VBD', 'word': 'toasted'},
#     {'pos': 'NN', 'word': 'veggie'},
#     {'pos': 'NN', 'word': 'sandwich'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': 'JJ', 'word': 'large'},
#     {'pos': 'NNS', 'word': 'portions'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'also'},
#     {'pos': 'JJ', 'word': 'appreciate'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'NN', 'word': 'selection'},
#     {'pos': 'JJ', 'word': 'hot'},
#     {'pos': 'NN', 'word': 'sauce'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NNS', 'word': 'frills'},
#     {'pos': 'NN', 'word': 'kind'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'NN', 'word': 'focus'},
#     {'pos': 'NN', 'word': 'food'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'MD', 'word': "'ll"},
#     {'pos': 'RB', 'word': 'definitely'},
#     {'pos': 'VBG', 'word': 'going'},
#     {'pos': 'RB', 'word': 'back'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 4,
#    'text': "This place is a solid cafe with solid food. I've had the lox omelet and the toasted veggie sandwich here and they were both delicious and large portions. I also appreciate a place that has a selection of hot sauce. It's a no frills kind of place and they focus on the food. I'll definitely be going back."}),
#  ('FmmJtKy7XLdF5ONKNY3yqQ',
#   {'review_words': [{'pos': 'NN', 'word': 'yummy'},
#     {'pos': 'NNS', 'word': 'desserts'},
#     {'pos': 'JJ', 'word': 'friendly'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'issue'},
#     {'pos': ':', 'word': ':'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'espresso'},
#     {'pos': 'NNS', 'word': 'drinks'},
#     {'pos': 'JJ', 'word': 'available'},
#     {'pos': 'NN', 'word': 'today'},
#     {'pos': ':', 'word': ';'},
#     {'pos': 'VB', 'word': 'take'},
#     {'pos': 'NN', 'word': 'benjamin'},
#     {'pos': 'DT', 'word': 'either'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'NN', 'word': 'rise'},
#     {'pos': 'JJ', 'word': 'green'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'refreshing'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'faves'},
#     {'pos': 'JJ', 'word': 'green'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': 'NN', 'word': 'crepe'},
#     {'pos': 'NN', 'word': 'cake'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'tiramisu'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'creme'},
#     {'pos': 'NN', 'word': 'brûlée'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 4,
#    'text': 'Yummy desserts friendly staff. Issue: no coffee espresso drinks available today; did not take Benjamin either. I did like the rise green tea, very refreshing. My faves are green tea crepe cake, tiramisu, creme brûlée.'}),
#  ('MOyPOuJhDvJoqO0mToBToA',
#   {'review_words': [{'pos': 'NN', 'word': 'place'},
#     {'pos': 'NN', 'word': 'amazing'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'RB', 'word': 'friendly'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NN', 'word': 'variety'},
#     {'pos': 'NNS', 'word': 'drinks'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'MD', 'word': "'d"},
#     {'pos': 'RB', 'word': 'rather'},
#     {'pos': 'VB', 'word': 'come'},
#     {'pos': 'VB', 'word': 'go'},
#     {'pos': 'NNS', 'word': 'starbucks'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'thank'},
#     {'pos': 'NNS', 'word': 'crossroads'},
#     {'pos': 'NNS', 'word': 'books'},
#     {'pos': 'CC', 'word': '&'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'providing'},
#     {'pos': 'JJ', 'word': 'delicious'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'RB', 'word': 'highly'},
#     {'pos': 'JJ', 'word': 'recommend'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': "This place is AMAZING! They are always friendly and have a great variety of drinks! I'd rather come here than go to Starbucks. Thank you Crossroads Books & Coffee for providing delicious coffee! I highly recommend this place."}),
#  ('Iu2BV2rmopzuM-FzJgsjtQ',
#   {'review_words': [{'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'NN', 'word': 'drive'},
#     {'pos': 'NN', 'word': 'thru'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'lot'},
#     {'pos': 'VBG', 'word': 'parking'},
#     {'pos': 'VBG', 'word': 'seating'},
#     {'pos': 'NN', 'word': 'walk'},
#     {'pos': ',', 'word': ','},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'meeting'},
#     {'pos': 'NN', 'word': 'room'},
#     {'pos': 'NN', 'word': 'cool'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'NN', 'word': 'use'},
#     {'pos': 'JJ', 'word': 'old'},
#     {'pos': 'NN', 'word': 'building'},
#     {'pos': 'NN', 'word': 'patio'},
#     {'pos': 'VBD', 'word': 'added'},
#     {'pos': 'JJ', 'word': 'cool'},
#     {'pos': 'NN', 'word': 'weather'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'park'},
#     {'pos': 'JJ', 'word': 'nearby'},
#     {'pos': 'VBZ', 'word': 'makes'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'JJ', 'word': 'stop'},
#     {'pos': 'NNS', 'word': 'dogs'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'puppicino'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 5,
#    'text': "Very nice to have a drive thru here.  And there's a lot of parking and seating if you walk in, too. The meeting room is cool. Very nice use of the old building with a patio added for the cool weather.  The park nearby makes this a great stop with the dogs. Puppicino!"}),
#  ('TjLarNl6oTvG74MNQAKMvw',
#   {'review_words': [{'pos': 'JJ', 'word': 'good'},
#     {'pos': 'NN', 'word': 'instagram'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'amazing'},
#     {'pos': 'NNS', 'word': 'looks'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBP', 'word': "'m"},
#     {'pos': 'JJ', 'word': 'sad'},
#     {'pos': 'VBP', 'word': 'say'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'live'},
#     {'pos': 'NN', 'word': 'hype'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'JJ', 'word': 'bad'},
#     {'pos': 'NN', 'word': 'ice'},
#     {'pos': 'NN', 'word': 'cream'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'certainly'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBD', 'word': 'got'},
#     {'pos': 'JJ', 'word': 'rid'},
#     {'pos': 'NN', 'word': 'cool'},
#     {'pos': 'VBD', 'word': 'flavoured'},
#     {'pos': 'JJ', 'word': 'soft'},
#     {'pos': 'NNS', 'word': 'serves'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'JJ', 'word': 'burnt'},
#     {'pos': 'NN', 'word': 'marshmallow'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'worth'},
#     {'pos': 'NNS', 'word': 'lines'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': '10-15'},
#     {'pos': 'NN', 'word': 'min'},
#     {'pos': 'NN', 'word': 'wait'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'chocolate'},
#     {'pos': 'NN', 'word': 'vanilla'},
#     {'pos': 'JJ', 'word': 'soft'},
#     {'pos': 'NN', 'word': 'serve'},
#     {'pos': 'NN', 'word': 'chocolate'},
#     {'pos': 'NN', 'word': 'vanilla'},
#     {'pos': 'NN', 'word': 'twist'},
#     {'pos': 'NNS', 'word': 'toppings'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'VBP', 'word': "'re"},
#     {'pos': 'VBG', 'word': 'looking'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'rush'},
#     {'pos': 'NN', 'word': 'hype'},
#     {'pos': 'VBZ', 'word': 'makes'},
#     {'pos': 'JJ', 'word': 'mediocre'},
#     {'pos': 'VBG', 'word': 'tasting'},
#     {'pos': 'NN', 'word': 'ice'},
#     {'pos': 'NN', 'word': 'cream'},
#     {'pos': 'NNS', 'word': 'cones'},
#     {'pos': 'JJ', 'word': 'worth'},
#     {'pos': '$', 'word': '$'},
#     {'pos': 'CD', 'word': '7.35'},
#     {'pos': 'NN', 'word': 'price'},
#     {'pos': 'NN', 'word': 'tag'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBD', 'word': 'came'},
#     {'pos': 'RB', 'word': 'initially'},
#     {'pos': 'JJ', 'word': 'rainy'},
#     {'pos': 'NN', 'word': 'december'},
#     {'pos': 'NN', 'word': 'night'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'campfire'},
#     {'pos': 'NNS', 'word': 'smores'},
#     {'pos': 'VBN', 'word': 'made'},
#     {'pos': 'VBD', 'word': 'toasted'},
#     {'pos': 'JJ', 'word': 'marshmallow'},
#     {'pos': 'JJ', 'word': 'soft'},
#     {'pos': 'JJ', 'word': 'serve-'},
#     {'pos': 'JJ', 'word': 'fabulous'},
#     {'pos': '.', 'word': '.'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'june'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'basic'},
#     {'pos': 'NN', 'word': 'chocolate'},
#     {'pos': 'NN', 'word': 'vanilla'},
#     {'pos': 'JJ', 'word': 'jazzed'},
#     {'pos': 'NNS', 'word': 'toppings'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'hmm'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'JJ', 'word': 'worth'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'go'},
#     {'pos': 'RB', 'word': 'back'},
#     {'pos': 'JJ', 'word': 'cool'},
#     {'pos': 'NNS', 'word': 'flavours'},
#     {'pos': 'JJ', 'word': 'soft'},
#     {'pos': 'VBP', 'word': 'serve'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'VBN', 'word': 'used'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'maybe'},
#     {'pos': 'NN', 'word': 'deserve'},
#     {'pos': 'NNS', 'word': 'stars'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 2,
#    'text': "Good for Instagram, not as amazing as it looks. I'm sad to say, it does not live up to its hype.  It wasn't bad ice cream, it was certainly good, but they got rid of the cool flavoured soft serves like burnt marshmallow! And it's not worth the lines if it's over a 10-15 min wait.  \n\nA chocolate or vanilla soft serve or a chocolate vanilla twist with some toppings that's what you're looking at. The rush and hype makes for mediocre tasting ice cream cones that are so not worth the $7.35 price tag.\n\nI came here initially on a rainy December night, and had the campfire smores that was made with a toasted marshmallow soft serve- and that was fabulous. Now, in June, it's just a basic chocolate vanilla jazzed up with toppings. \n\nHmm, not really worth it.  If they go back to having cool flavours of soft serve like they used to, then maybe they deserve more stars."}),
#  ('vSuw2_d6wls4gWfDVwoP7g',
#   {'review_words': [{'pos': 'VB', 'word': 'love'},
#     {'pos': 'JJ', 'word': 'friendly'},
#     {'pos': 'JJ', 'word': 'unique'},
#     {'pos': 'NN', 'word': 'ome'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'NN', 'word': 'design'},
#     {'pos': 'NN', 'word': 'restaurant'},
#     {'pos': 'NN', 'word': 'food'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'good'},
#     {'pos': 'NN', 'word': 'tasting..also'},
#     {'pos': 'VBP', 'word': 'go'},
#     {'pos': 'JJ', 'word': 'drive'},
#     {'pos': 'VBZ', 'word': 'takes'},
#     {'pos': 'NN', 'word': 'lng'},
#     {'pos': 'MD', 'word': 'might'},
#     {'pos': 'VB', 'word': 'ask'},
#     {'pos': 'JJ', 'word': 'pul'},
#     {'pos': 'RB', 'word': 'forward'},
#     {'pos': 'VBP', 'word': 'wait'},
#     {'pos': 'VB', 'word': 'till'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NNS', 'word': 'employees'},
#     {'pos': 'VBZ', 'word': 'brings'},
#     {'pos': 'NN', 'word': 'food'},
#     {'pos': ':', 'word': '-'},
#     {'pos': 'JJ', 'word': 'impressed'},
#     {'pos': 'NN', 'word': 'mediocrity'}],
#    'stars': 2,
#    'text': 'Love how friendly they are and the unique ome like design of the restaurant but the food and the coffee is not at all good tasting..also if you go through the drive through it takes them so LNG that they might ask you to just pul forward and wait till one of the employees brings out you  food - just not impressed at all mediocrity'}),
#  ('v_pM8vKxfQCxYO9ai8nGVQ',
#   {'review_words': [{'pos': 'RB', 'word': 'really'},
#     {'pos': 'JJ', 'word': 'wanted'},
#     {'pos': 'NN', 'word': 'treat'},
#     {'pos': 'JJ', 'word': 'rainy'},
#     {'pos': 'JJ', 'word': 'saturday'},
#     {'pos': 'NN', 'word': 'morning'},
#     {'pos': 'VBD', 'word': 'decided'},
#     {'pos': 'VB', 'word': 'try'},
#     {'pos': 'JJ', 'word': 'troubadour'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'shop'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': '2'},
#     {'pos': 'NNS', 'word': 'reviews'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'expect'},
#     {'pos': 'JJ', 'word': 'much'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBN', 'word': 'thought'},
#     {'pos': 'MD', 'word': "'d"},
#     {'pos': 'VB', 'word': 'get'},
#     {'pos': 'JJ', 'word': 'regular'},
#     {'pos': 'RB', 'word': 'overly'},
#     {'pos': 'JJ', 'word': 'sweet'},
#     {'pos': 'NN', 'word': 'cup'},
#     {'pos': 'NN', 'word': 'cappuccino'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'fine'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'ordered'},
#     {'pos': 'NN', 'word': 'cup'},
#     {'pos': 'NN', 'word': 'mocha'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJS', 'word': 'best'},
#     {'pos': 'NN', 'word': 'mocha'},
#     {'pos': 'RB', 'word': 'ever'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'sweet'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'top'},
#     {'pos': 'NN', 'word': 'layer'},
#     {'pos': 'VBD', 'word': 'frosted'},
#     {'pos': 'NN', 'word': 'milk'},
#     {'pos': 'JJ', 'word': 'regular'},
#     {'pos': 'NN', 'word': 'foam'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'gooey'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'almost'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'VBN', 'word': 'melted'},
#     {'pos': 'NN', 'word': 'marshmallow'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'yummy'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'treats'},
#     {'pos': 'VBP', 'word': 'go'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'many'},
#     {'pos': 'IN', 'word': 'though'},
#     {'pos': ':', 'word': ':'},
#     {'pos': 'NN', 'word': 'banana'},
#     {'pos': 'NN', 'word': 'pumpkin'},
#     {'pos': 'NN', 'word': 'bread'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'italian'},
#     {'pos': 'NN', 'word': 'cake'},
#     {'pos': 'NNS', 'word': 'cookies'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'VB', 'word': 'take'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': 'JJ', 'word': 'prepare'},
#     {'pos': 'JJ', 'word': 'awesome'},
#     {'pos': 'NN', 'word': 'cup'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VBN', 'word': 'come'},
#     {'pos': 'NN', 'word': 'rush'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': "I really wanted a treat this rainy Saturday morning and decided to try Troubadour coffee shop. It had only 2 reviews, so I didn't expect much, thought I'd get a regular overly sweet cup of cappuccino and that's fine.\nI ordered a cup of mocha. That was the best mocha I ever had. Not too sweet. And the top layer of frosted milk was not your regular foam. It was gooey, almost like melted marshmallow, very yummy. \nThey have some treats to go with coffee, not many though: banana and pumpkin bread, Italian cake and some cookies. \nThey really take time to prepare for you an awesome cup of coffee, so don't come here if in a rush."}),
#  ('fm15qutmXnRiQRvE2r-iPA',
#   {'review_words': [{'pos': 'RB', 'word': 'first'},
#     {'pos': 'NNS', 'word': 'starbucks'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBP', 'word': "'ve"},
#     {'pos': 'NN', 'word': 'location'},
#     {'pos': 'JJ', 'word': 'numerous'},
#     {'pos': 'NNS', 'word': 'times'},
#     {'pos': 'IN', 'word': 'since'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'right'},
#     {'pos': 'NN', 'word': 'work'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'starbucks'},
#     {'pos': 'VBP', 'word': 'lot'},
#     {'pos': 'VBG', 'word': 'seating'},
#     {'pos': 'NNS', 'word': 'areas'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBG', 'word': 'including'},
#     {'pos': 'JJ', 'word': 'high'},
#     {'pos': 'NNS', 'word': 'tops'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NNS', 'word': 'couches'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'long'},
#     {'pos': 'NNS', 'word': 'tables'},
#     {'pos': 'JJR', 'word': 'larger'},
#     {'pos': 'NNS', 'word': 'groups'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'everytime'},
#     {'pos': 'VBP', 'word': "'ve"},
#     {'pos': 'VBN', 'word': 'walked'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBG', 'word': 'seating'},
#     {'pos': 'NN', 'word': 'area'},
#     {'pos': 'JJ', 'word': 'full'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'luckily'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'usually'},
#     {'pos': 'VBP', 'word': 'grab'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'head'},
#     {'pos': 'NN', 'word': 'work'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'part'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'location'},
#     {'pos': 'RB', 'word': 'quite'},
#     {'pos': 'JJ', 'word': 'busy'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': 'VBG', 'word': 'considering'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'JJ', 'word': 'right'},
#     {'pos': 'IN', 'word': 'outside'},
#     {'pos': 'VBG', 'word': 'king'},
#     {'pos': 'JJ', 'word': 'subway'},
#     {'pos': 'NN', 'word': 'station'},
#     {'pos': 'JJ', 'word': 'downtown'},
#     {'pos': 'NN', 'word': 'area'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'JJ', 'word': 'enthusiastic'},
#     {'pos': 'JJ', 'word': 'friendly'},
#     {'pos': 'VBG', 'word': 'taking'},
#     {'pos': 'NNS', 'word': 'orders'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'always'},
#     {'pos': 'VBN', 'word': 'put'},
#     {'pos': 'JJ', 'word': 'name'},
#     {'pos': 'NN', 'word': 'cup'},
#     {'pos': 'VBZ', 'word': 'makes'},
#     {'pos': 'VBP', 'word': 'feel'},
#     {'pos': 'JJ', 'word': 'special'},
#     {'pos': 'VBZ', 'word': 'adds'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'NN', 'word': 'touch'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'downside'},
#     {'pos': 'MD', 'word': "'d"},
#     {'pos': 'VB', 'word': 'say'},
#     {'pos': 'JJ', 'word': 'line-up'},
#     {'pos': 'JJ', 'word': 'massive'},
#     {'pos': 'NN', 'word': 'day'},
#     {'pos': 'RB', 'word': 'long'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'NN', 'word': 'guess'},
#     {'pos': 'NN', 'word': 'everyone'},
#     {'pos': 'VBZ', 'word': 'needs'},
#     {'pos': 'NNS', 'word': 'coffee..'},
#     {'pos': 'VBP', 'word': 'know'},
#     {'pos': 'NNS', 'word': 'anyways'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBG', 'word': 'depending'},
#     {'pos': 'VBG', 'word': 'working'},
#     {'pos': 'NN', 'word': 'bar'},
#     {'pos': 'JJ', 'word': 'many'},
#     {'pos': 'NN', 'word': 'staff'},
#     {'pos': 'NN', 'word': 'duty'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'usually'},
#     {'pos': 'JJ', 'word': 'wait'},
#     {'pos': 'NN', 'word': 'time'},
#     {'pos': 'JJ', 'word': 'receive'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': ',', 'word': ','},
# ...
#  ('_teUuim_g_ITiaoYHSIJXw',
#   {'review_words': [{'pos': 'RB', 'word': 'really'},
#     {'pos': 'JJ', 'word': 'nice'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NN', 'word': 'food'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'VBZ', 'word': 'looks'},
#     {'pos': 'NNS', 'word': 'feels'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'JJ', 'word': 'traditional'},
#     {'pos': 'NN', 'word': 'diner'},
#     {'pos': ':', 'word': '...'},
#     {'pos': 'VBZ', 'word': 'breakfasts'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 5,
#    'text': 'Really nice place, great food and service! Looks and feels like a traditional diner... All the breakfasts are good!!'}),
#  ('MJTwCpMXvpeAF7w_MrV40g',
#   {'review_words': [{'pos': 'JJ', 'word': 'phoenix'},
#     {'pos': 'CD', 'word': '2'},
#     {'pos': 'NNS', 'word': 'days'},
#     {'pos': 'VBD', 'word': 'managed'},
#     {'pos': 'JJ', 'word': 'hit'},
#     {'pos': 'NN', 'word': 'spot'},
#     {'pos': 'RB', 'word': 'twice'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'JJ', 'word': 'wish'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'la'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'vegan'},
#     {'pos': 'NNS', 'word': 'blizzards'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NNS', 'word': 'tons'},
#     {'pos': 'VBD', 'word': 'baked'},
#     {'pos': 'JJ', 'word': 'goods=my'},
#     {'pos': 'NN', 'word': 'paradise'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'NNS', 'word': 'favorites'},
#     {'pos': 'VBP', 'word': 'monsoon'},
#     {'pos': 'JJ', 'word': 'special'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'JJ', 'word': 'choc'},
#     {'pos': 'NN', 'word': 'cake'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'choc'},
#     {'pos': 'NNS', 'word': 'chips'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'NN', 'word': 'choc'},
#     {'pos': 'NN', 'word': 'syrup'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'VBD', 'word': 'added'},
#     {'pos': 'NN', 'word': 'pb'},
#     {'pos': 'DT', 'word': 'another'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'pretzels'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'pb'},
#     {'pos': 'NN', 'word': 'chocolate'},
#     {'pos': 'NNS', 'word': 'chips'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'MD', 'word': 'ca'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'wait'},
#     {'pos': 'VB', 'word': 'come'},
#     {'pos': 'RB', 'word': 'back'},
#     {'pos': 'JJ', 'word': 'next'},
#     {'pos': 'NN', 'word': 'trip'},
#     {'pos': 'NN', 'word': 'phoenix'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'sister'},
#     {'pos': 'NN', 'word': 'veg'},
#     {'pos': 'NN', 'word': 'restaurant'},
#     {'pos': 'JJ', 'word': 'next'},
#     {'pos': 'NN', 'word': 'door'},
#     {'pos': 'MD', 'word': 'ca'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'wait'},
#     {'pos': 'VB', 'word': 'try'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'UH', 'word': 'yes'},
#     {'pos': 'MD', 'word': 'may'},
#     {'pos': 'VB', 'word': 'eaten'},
#     {'pos': 'VB', 'word': 'tsoynamis'},
#     {'pos': 'NN', 'word': 'dinner'},
#     {'pos': ')', 'word': ')'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': "I was in Phoenix for just 2 days and managed to hit this spot up twice!!!! I really wish they had one in LA.\n\nAll vegan blizzards, tons of baked goods=my paradise!\n\nMy favorites were the Monsoon special (choc cake, choc chips, and choc syrup) which I added PB too and another one with pretzels, PB and chocolate chips.\n\nCan't wait to come back on my next trip to Phoenix. They have a sister veg restaurant next door that I can't wait to try too (yes I may have just eaten Tsoynamis for dinner)."}),
#  ('iVAepvCRYS5ErI-a-ilXpA',
#   {'review_words': [{'pos': 'NN', 'word': 'ok'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'RB', 'word': 'pretty'},
#     {'pos': 'JJ', 'word': 'much'},
#     {'pos': 'IN', 'word': 'love'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'NNS', 'word': 'dudes'},
#     {'pos': 'VBP', 'word': 'work'},
#     {'pos': 'JJ', 'word': 'and/or'},
#     {'pos': 'JJ', 'word': 'cool'},
#     {'pos': 'RB', 'word': 'friendly'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'JJ', 'word': 'bad'},
#     {'pos': 'VB', 'word': 'look'},
#     {'pos': 'CC', 'word': 'either'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBP', 'word': "'m"},
#     {'pos': 'VBG', 'word': 'saying'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': 'NN', 'word': 'hang'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBG', 'word': 'remodeling'},
#     {'pos': 'JJ', 'word': 'general'},
#     {'pos': 'VBG', 'word': 'making'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'RB', 'word': 'even'},
#     {'pos': 'RBR', 'word': 'better'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBG', 'word': 'adding'},
#     {'pos': 'NN', 'word': 'sort'},
#     {'pos': 'NN', 'word': 'juice'},
#     {'pos': 'NN', 'word': 'bar'},
#     {'pos': 'NN', 'word': 'component'},
#     {'pos': 'RB', 'word': 'soon'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'dude'},
#     {'pos': 'VBD', 'word': 'knew'},
#     {'pos': 'JJR', 'word': 'yelp'},
#     {'pos': 'NN', 'word': 'review'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'cool'},
#     {'pos': 'CC', 'word': '&'},
#     {'pos': 'JJ', 'word': 'little'},
#     {'pos': 'JJ', 'word': 'scary'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'VB', 'word': 'take'},
#     {'pos': 'NN', 'word': 'yelp'},
#     {'pos': 'IN', 'word': 'though'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'right'},
#     {'pos': 'NN', 'word': 'attitude'},
#     {'pos': 'NN', 'word': 'lot'},
#     {'pos': 'RB', 'word': 'feedback'},
#     {'pos': 'JJ', 'word': 'constructive'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'guy'},
#     {'pos': 'VBG', 'word': 'working'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'VB', 'word': 'yelp'},
#     {'pos': 'NN', 'word': 'fan'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'fine'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBD', 'word': 'gave'},
#     {'pos': 'JJ', 'word': 'perfect'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'VBD', 'word': 'made'},
#     {'pos': 'VB', 'word': 'feel'},
#     {'pos': 'RB', 'word': 'totally'},
#     {'pos': 'JJ', 'word': 'welcome'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'respect'},
#     {'pos': 'NN', 'word': 'point'},
#     {'pos': 'NN', 'word': 'view'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': "n't"},
#     {'pos': 'JJ', 'word': 'like'},
#     {'pos': 'NNS', 'word': 'things'},
#     {'pos': ':', 'word': '...'},
#     {'pos': 'RB', 'word': 'right'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'know'},
#     {'pos': 'NN', 'word': 'stance'},
#     {'pos': 'NNS', 'word': 'pillows'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'MD', 'word': 'would'},
#     {'pos': 'VB', 'word': 'love'},
#     {'pos': 'MD', 'word': 'would'},
#     {'pos': 'VB', 'word': 'stay'},
#     {'pos': 'JJ', 'word': 'open'},
#     {'pos': 'JJR', 'word': 'longer'},
#     {'pos': 'NNS', 'word': 'weekends'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'bring'},
#     {'pos': 'NNS', 'word': 'baileys'},
#     {'pos': ':', 'word': '...'},
#     {'pos': 'NN', 'word': '.please'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'},
#     {'pos': 'RB', 'word': 'seriously'},
#     {'pos': 'JJ', 'word': 'great'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': "Ok, I pretty much love this place! The dudes that work here and/or own it are very cool and friendly.  They aren't bad to look at either, I'm just saying. I just like to hang out here.\n\nThey are doing some remodeling and in general making this place even better. They are adding some sort of juice bar component soon, which is great. \n\nOne dude knew who I was by my Yelp review, which was cool & a little scary.  He had a great take on Yelp though, and has the right attitude that a lot of the feedback can be constructive.\n\nOne guy working there wasn't a Yelp fan, which was fine with me, he gave perfect service and made me feel totally welcome.  I respect his point of view. We all don't have to like the same things...right.\n\nThey know my stance on pillows there, and I would love it if they would stay open longer on weekends. I will bring my own Baileys....Please!!!!!\n\nSeriously great place."}),
#  ('fCq4JrFmlt21Rg3GRmgNZg',
#   {'review_words': [{'pos': 'VBD', 'word': 'went'},
#     {'pos': 'JJ', 'word': 'dunkin'},
#     {'pos': 'NN', 'word': 'morning'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'people'},
#     {'pos': 'VBP', 'word': 'work'},
#     {'pos': 'NN', 'word': 'rude'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'look'},
#     {'pos': 'NN', 'word': 'funny'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'smiles'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBN', 'word': 'slammed'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'counter'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJR', 'word': 'older'},
#     {'pos': 'NN', 'word': 'man'},
#     {'pos': 'NN', 'word': 'woman'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'looked'},
#     {'pos': 'JJ', 'word': 'indian'},
#     {'pos': 'NN', 'word': 'descent'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'possible'},
#     {'pos': 'NNS', 'word': 'owners'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VB', 'word': 'go'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'RB', 'word': 'sometimes'},
#     {'pos': 'JJ', 'word': 'closest'},
#     {'pos': 'NN', 'word': 'house'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJS', 'word': 'worst'},
#     {'pos': 'CD', 'word': 'one'},
#     {'pos': 'NN', 'word': 'around'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'coffees'},
#     {'pos': 'RB', 'word': 'never'},
#     {'pos': 'RB', 'word': 'right'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'terrible'},
#     {'pos': 'NN', 'word': 'customer'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': '.', 'word': '!'},
#     {'pos': '.', 'word': '!'}],
#    'stars': 1,
#    'text': 'Went to dunkin this morning. The people that work there are rude. They look at you funny. No smiles. Slammed my coffee on the counter. It was and older man and woman. Looked of Indian descent. Possible owners. I only go to this  one sometimes because it is the closest to my house. But it the worst one around. Coffees are never right. Terrible customer service !!'}),
#  ('HKE8C7AYVcw9ZeQUQxbvwQ',
#   {'review_words': [{'pos': 'VBN', 'word': 'found'},
#     {'pos': 'VBD', 'word': 'renowned'},
#     {'pos': 'JJ', 'word': 'roosevelt'},
#     {'pos': 'NN', 'word': 'row'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'JJ', 'word': 'songbird'},
#     {'pos': 'NNS', 'word': 'possesses'},
#     {'pos': 'VBP', 'word': 'quaint'},
#     {'pos': 'RB', 'word': 'yet'},
#     {'pos': 'JJ', 'word': 'modern'},
#     {'pos': 'NN', 'word': 'feel'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'JJ', 'word': 'tasty'},
#     {'pos': 'NN', 'word': 'selection'},
#     {'pos': 'JJ', 'word': 'hot'},
#     {'pos': 'VBN', 'word': 'iced'},
#     {'pos': 'NNS', 'word': 'teas'},
#     {'pos': '(', 'word': '('},
#     {'pos': 'VBP', 'word': "'m"},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'drinker'},
#     {'pos': '.', 'word': '.'},
#     {'pos': ')', 'word': ')'},
#     {'pos': 'RB', 'word': 'also'},
#     {'pos': ',', 'word': ','},
#     {'pos': 'VBP', 'word': 'make'},
#     {'pos': 'NN', 'word': 'matcha'},
#     {'pos': 'JJ', 'word': 'green'},
#     {'pos': 'NN', 'word': 'tea'},
#     {'pos': 'NN', 'word': 'latte'},
#     {'pos': 'NN', 'word': 'almond'},
#     {'pos': 'NN', 'word': 'milk'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'someone'},
#     {'pos': 'NN', 'word': 'dairy'},
#     {'pos': 'NN', 'word': 'soy'},
#     {'pos': 'NNS', 'word': 'allergies'},
#     {'pos': 'VBP', 'word': "'m"},
#     {'pos': 'RB', 'word': 'often'},
#     {'pos': 'JJ', 'word': 'dismayed'},
#     {'pos': 'NN', 'word': 'availability'},
#     {'pos': 'NN', 'word': 'cow'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'NN', 'word': 'milk'},
#     {'pos': 'NN', 'word': 'soy'},
#     {'pos': 'NN', 'word': 'milk'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NNS', 'word': 'shops'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'VBP', 'word': "'m"},
#     {'pos': 'JJ', 'word': 'happy'},
#     {'pos': 'JJ', 'word': 'found'},
#     {'pos': 'NN', 'word': 'place'},
#     {'pos': 'NN', 'word': 'neighborhood'},
#     {'pos': 'VBP', 'word': 'make'},
#     {'pos': 'JJ', 'word': 'tasty'},
#     {'pos': 'NN', 'word': 'treat'},
#     {'pos': 'NN', 'word': 'way'},
#     {'pos': 'IN', 'word': 'like'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': "Found on renowned Roosevelt Row, Songbird possesses a quaint yet modern feel. They have a tasty selection of both hot and iced teas (I'm not a coffee drinker.) Also, they make a matcha green tea latte with almond milk. As someone with both dairy and soy allergies I'm often dismayed by the availability of only cow's milk or soy milk at most coffee shops. I'm very happy to have found a place in my neighborhood that can make this tasty treat just the way I like."}),
#  ('mg9cpBaQLeDvQGHIcYTG-Q',
#   {'review_words': [{'pos': 'JJ', 'word': 'great'},
#     {'pos': 'JJ', 'word': 'little'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'house'},
#     {'pos': 'JJ', 'word': 'awesome'},
#     {'pos': 'NN', 'word': 'bakery'},
#     {'pos': 'POS', 'word': "'s"},
#     {'pos': 'VBN', 'word': 'called'},
#     {'pos': 'NN', 'word': 'madhouse'},
#     {'pos': 'IN', 'word': 'though'},
#     {'pos': ':', 'word': '...'},
#     {'pos': 'VBN', 'word': 'called'},
#     {'pos': 'VBP', 'word': 'wake'},
#     {'pos': 'NN', 'word': 'coffee'},
#     {'pos': 'NN', 'word': 'cafe'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': "This is a great little coffee house and awesome bakery it's is not called madhouse though...its called wake up coffee cafe."}),
#  ('lAJhl5ZtRzFcz7LqHcRpGA',
#   {'review_words': [{'pos': 'CD', 'word': 'one'},
#     {'pos': 'JJS', 'word': 'best'},
#     {'pos': 'NN', 'word': 'spot'},
#     {'pos': 'NN', 'word': 'eat'},
#     {'pos': 'NN', 'word': 'vegan'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'RB', 'word': 'really'},
#     {'pos': 'VBN', 'word': 'enjoyed'},
#     {'pos': 'NN', 'word': 'vegan'},
#     {'pos': 'NNS', 'word': 'rolls'},
#     {'pos': 'VBZ', 'word': 'salads'},
#     {'pos': 'NN', 'word': 'tofu'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NN', 'word': 'service'},
#     {'pos': 'NN', 'word': 'speedy'},
#     {'pos': 'NNS', 'word': 'prices'},
#     {'pos': 'JJ', 'word': 'reasonable'},
#     {'pos': '.', 'word': '.'},
#     {'pos': 'NNS', 'word': 'sweets'},
#     {'pos': 'JJ', 'word': 'good'},
#     {'pos': 'JJ', 'word': 'low'},
#     {'pos': 'NNS', 'word': 'calories'},
#     {'pos': 'NN', 'word': 'count'},
#     {'pos': '.', 'word': '.'}],
#    'stars': 5,
#    'text': 'One of the best spot to eat if you are Vegan. I really enjoyed their Vegan rolls and salads with tofu. The service is speedy and the prices are reasonable. Their sweets are good and with very low calories count.'})]

# %%
def lemmatize(reviewDict):
    # loop through the reviews
    # get nouns and group them by lemma
    reviewCorpus = {}
    lemmatizer = nltk.WordNetLemmatizer()

    for review_count, review_content in reviewDict.items():
        nouns = []
        words = [w for w in review_content['review_words'] if w['pos'] in ['NN','NNS']]
        
        for w in words:
            nouns.append(lemmatizer.lemmatize(w['word']))
            
        reviewCorpus[review_count] = {'review_stars' : review_content['stars'], \
                                      'review_text' : review_content['text'], \
                                      'review_nouns' : nouns} 
    
    return reviewCorpus

# %%
# feed reviews to LDA model using k topics
def train(reviewDict, k):
    
    '''
    create id2word
    cannot filter extremes when the set is too small (only 1 page of yelp)
    '''
    id2word = corpora.Dictionary(reviewDict[review]["review_nouns"] for review in reviewDict)
#     id2word.filter_extremes(keep_n=10000)
#     id2word.compactify()

    corpora_dict = corpora.Dictionary(reviewDict[review]["review_nouns"] for review in reviewDict)
    corpora_dict.save('lda/dictionary.dict')
    
    corpus = [corpora_dict.doc2bow(reviewDict[review]["review_nouns"]) for review in reviewDict]
    corpora.BleiCorpus.serialize('lda/corpus.lda-c', corpus)
    corpus = corpora.BleiCorpus('lda/corpus.lda-c')
    
    if k == 50:
        # save lda model for 50 topics
        lda = gensim.models.LdaModel(corpus, num_topics=50, id2word=id2word)
        lda.save('lda/lda_50_topics.lda')
    
    else if k == 25:
        # save lda model for 25 topics
        lda = gensim.models.LdaModel(corpus, num_topics=25, id2word=id2word)
        lda.save('lda/lda_25_topics.lda')
    
    return lda

# %%
# Scrape Yelp reviews

import requests
import json

def main():
    global REVIEW_DICT 
    REVIEW_DICT = reviewData 
        
    '''
    Check if the folder for the lda model exists
    If it doesnt create the folder 
    '''
    if not os.path.exists('lda'):
        os.makedirs('lda')
    
    train(lemmatize(REVIEW_DICT, 25))

    
if __name__ == '__main__':
    main()

# %%
WEIGHT_TOPIC = []

dictionary_path = "lda/dictionary.dict"
corpus_path = "lda/corpus.lda-c"
lda_model_path = "lda/lda_50_topics.lda"

dictionary = corpora.Dictionary.load(dictionary_path)
corpus = corpora.BleiCorpus(corpus_path)
lda = LdaModel.load(lda_model_path)

i = 0
for topic in lda.show_topics():
    topic_list = topic[1].replace(' ','').replace('\"', '').split('+')

    weight_topic = [x.split('*') for x in topic_list ]
    global WEIGHT_TOPIC
    WEIGHT_TOPIC.append(weight_topic)
    print((weight_topic) + '\n')
# Out:
# [['0.169', 'cake'], ['0.057', 'cupcake'], ['0.026', 'macaroon'], ['0.021', 'velvet'], ['0.016', 'moist'], ['0.015', 'baby'], ['0.014', 'birthday'], ['0.014', 'salt'], ['0.013', 'sweet'], ['0.013', 'dessert']]
#
# [['0.098', 'line'], ['0.061', 'people'], ['0.031', 'time'], ['0.029', 'order'], ['0.023', 'wait'], ['0.022', 'person'], ['0.021', 'door'], ['0.021', 'way'], ['0.020', 'morning'], ['0.017', 'day']]
#
# [['0.141', 'love'], ['0.077', 'kid'], ['0.040', 'yum'], ['0.032', 'place'], ['0.029', 'family'], ['0.019', 'fresh'], ['0.015', 'city'], ['0.014', 'special'], ['0.013', 'jar'], ['0.012', 'cocoa']]
#
# [['0.058', 'table'], ['0.042', 'space'], ['0.029', 'place'], ['0.023', 'chair'], ['0.022', 'seat'], ['0.020', 'lot'], ['0.020', 'coffee'], ['0.019', 'sit'], ['0.018', 'people'], ['0.018', 'seating']]
#
# [['0.078', 'hour'], ['0.059', 'weekend'], ['0.039', 'place'], ['0.034', 'time'], ['0.024', 'student'], ['0.017', 'food'], ['0.017', 'complaint'], ['0.017', 'evening'], ['0.016', 'system'], ['0.014', 'people']]
#
# [['0.192', 'bar'], ['0.073', 'night'], ['0.037', 'station'], ['0.026', 'mood'], ['0.024', 'cocktail'], ['0.019', 'pm'], ['0.016', 'edinburgh'], ['0.015', 'dream'], ['0.014', 'inviting'], ['0.013', 'background']]
#
# [['0.051', 'le'], ['0.046', 'café'], ['0.020', 'je'], ['0.018', 'pa'], ['0.017', 'de'], ['0.017', 'la'], ['0.016', 'et'], ['0.016', 'que'], ['0.015', 'pour'], ['0.013', 'bon']]
#
# [['0.042', 'macchiato'], ['0.034', 'cause'], ['0.025', 'post'], ['0.024', 'tasting'], ['0.022', 'blend'], ['0.021', 'fruity'], ['0.021', 'matcha'], ['0.021', 'patient'], ['0.020', 'eye'], ['0.018', 'venue']]
#
# [['0.276', 'chocolate'], ['0.058', 'dessert'], ['0.033', 'chip'], ['0.014', 'cheesecake'], ['0.014', 'bun'], ['0.013', 'raspberry'], ['0.013', 'banana'], ['0.012', 'creme'], ['0.012', 'sweet'], ['0.010', 'truffle']]
#
# [['0.040', 'food'], ['0.032', 'chicken'], ['0.027', 'sauce'], ['0.022', 'meat'], ['0.021', 'dish'], ['0.021', 'burger'], ['0.021', 'fry'], ['0.020', 'meal'], ['0.017', 'portion'], ['0.017', 'place']]

# %%
# See topics
TOPIC_DICT = dict(lda.show_topics(num_topics=50))

# %%
topic_text = []
for review in REVIEW_DICT:
    review_text = REVIEW_DICT[review]['text']
    review_stars = REVIEW_DICT[review]['stars']
    counter = 0
    for weight_topic in WEIGHT_TOPIC:
        for topic in weight_topic:
            if topic[1] in review_text: counter +=1
                
        if counter >= 4: topic_text.append((review_stars, review_text, weight_topic))

# %%
# Test on an example – applying LDA model to unseen review
unseenReview = '''I really wanted to like this coffee shop, but after my first visit today I can't say I'm impressed. My biggest issue is with the atmosphere. I believe interior decor plays a big role, and this doesn't seem like it's been renovated since the late 90s/ early 2000s. The flooring, walls, tables, counter, everything contributes to a less-than-pleasing environment and not somewhere I'd like to spend a lot of time. There are spots on the walls where paint is falling off, all tables aren't of same style, the interior temperature was cold, and the music unfitting/ distracting (old hip-hip, rap, and pop).

Secondly it was very dirty when I visited. I had to wipe off my table before I could place my laptop down, there were napkins and paper cups all over the floors, and the service counter was very unappealing. I don't know whether this is a consistent issue or I just happened to visit at a bad time, but it affected my first impression nonetheless. 

As far as the coffee goes, I wasn't impressed. Despite ordering to stay, I was served in a paper cup. It's not a big issue, but I would preferred a regular cup. My caffè mocha was mediocre at best, not the worst I've had, but both Starbucks and Pavement up the street serves better. The prices weren't particularly impressive either, paying over $4.5 (including tax) for a medium (12oz) mocha.

I didn't order any food, but their their display of cookies/ cakes was rather sad. Everything looked dry, unorganized, and very unsanitary. They did have a menu for warm sandwiches, some of which sounded really good, but I didn't have a chance to try any of them. However several of the other customers did order a sandwich, so I can only assume they're worth the price.

The final point I'd like to address is the internet. They do provide free internet which is nice (though expected in this day and age), however it's among the slowest I've experienced. Definitely not somewhere I could get work done, and I don't understand how so many people stay here for an extended period of time on their laptops. A random YouTube video I opened took over 2 minutes to start playing at 240p, and when I adjusted it to 1080p it never continued. It took me over 5 minutes just to open Yelp and navigate to this page.

On the positive side, the cafe is open late until 10pm every night which is a plus. However the nearby Starbucks is open just as late, albeit a little less seating for those late night study sessions.
'''
                                
def predTopics(review_text):
    separated_text = review_text.lower().split()
    
    # apply LDA model
    dictionary_path = "lda/dictionary.dict"
    corpus_path = "lda/corpus.lda-c"
    lda_model_path = "lda/lda_50_topics.lda"

    dictionary = corpora.Dictionary.load(dictionary_path)
    corpus = corpora.BleiCorpus(corpus_path)
    lda = LdaModel.load(lda_model_path)
    
    review_bow = dictionary.doc2bow(separated_text)
    
    return lda[review_bow]

for (topic, weight) in predTopics(unseenReview):
    print('Review has ' + str(weight*100) + '% weight ' + 'for topic \n' + TOPIC_DICT[topic] + '\n')
# Out:
# Review has 7.62426870771% weight for topic
# 0.058*"table" + 0.042*"space" + 0.029*"place" + 0.023*"chair" + 0.022*"seat" + 0.020*"lot" + 0.020*"coffee" + 0.019*"sit" + 0.018*"people" + 0.018*"seating"
#
# Review has 2.05755183731% weight for topic
# 0.101*"game" + 0.055*"board" + 0.042*"boyfriend" + 0.032*"size" + 0.030*"room" + 0.026*"purchase" + 0.021*"girlfriend" + 0.019*"disappointment" + 0.017*"hey" + 0.016*"energy"
#
# Review has 3.03601666243% weight for topic
# 0.067*"check" + 0.047*"excellent" + 0.046*"wow" + 0.033*"neighborhood" + 0.027*"cold" + 0.021*"food" + 0.020*"jam" + 0.018*"range" + 0.016*"bottle" + 0.014*"place"
#
# Review has 1.38018249044% weight for topic
# 0.098*"line" + 0.061*"people" + 0.031*"time" + 0.029*"order" + 0.023*"wait" + 0.022*"person" + 0.021*"door" + 0.021*"way" + 0.020*"morning" + 0.017*"day"
#
# Review has 4.57130235468% weight for topic
# 0.066*"nice" + 0.055*"staff" + 0.039*"strip" + 0.034*"afternoon" + 0.028*"mall" + 0.027*"helpful" + 0.024*"talk" + 0.022*"suggestion" + 0.019*"pleasant" + 0.018*"leaf"
#
# Review has 12.1832761544% weight for topic
# 0.049*"die" + 0.040*"der" + 0.033*"da" + 0.024*"man" + 0.023*"war" + 0.020*"mit" + 0.020*"ist" + 0.015*"zu" + 0.014*"sehr" + 0.014*"ein"
#
# Review has 3.77462980108% weight for topic
# 0.206*"starbucks" + 0.049*"coffee" + 0.033*"location" + 0.028*"drink" + 0.025*"staff" + 0.020*"lot" + 0.018*"time" + 0.017*"baristas" + 0.017*"area" + 0.017*"parking"
#
# Review has 6.24130122962% weight for topic
# 0.161*"place" + 0.047*"coffee" + 0.033*"staff" + 0.032*"music" + 0.026*"vibe" + 0.024*"friend" + 0.023*"spot" + 0.022*"book" + 0.020*"fun" + 0.019*"hang"
#
# Review has 4.24047867243% weight for topic
# 0.126*"order" + 0.124*"drink" + 0.082*"time" + 0.064*"minute" + 0.020*"girl" + 0.018*"service" + 0.015*"wait" + 0.014*"counter" + 0.012*"people" + 0.012*"get"
#
# Review has 1.55001954932% weight for topic
# 0.266*"latte" + 0.065*"chai" + 0.046*"milk" + 0.043*"vanilla" + 0.037*"%" + 0.020*"caramel" + 0.019*"syrup" + 0.016*"foam" + 0.013*"taste" + 0.013*"glad"
#
# Review has 3.99882032697% weight for topic
# 0.099*"business" + 0.041*"atmosphere" + 0.031*"care" + 0.029*"owner" + 0.026*"phoenix" + 0.025*"support" + 0.024*"product" + 0.023*"montreal" + 0.023*"place" + 0.023*"chain"
#
# Review has 5.30866109378% weight for topic
# 0.059*"snack" + 0.046*"spice" + 0.039*"weather" + 0.038*"none" + 0.037*"winter" + 0.026*"outdoor" + 0.023*"hubby" + 0.022*"soda" + 0.020*"lavender" + 0.018*"layout"
#
# Review has 2.41306453494% weight for topic
# 0.140*"food" + 0.103*"breakfast" + 0.078*"place" + 0.045*"service" + 0.028*"time" + 0.021*"menu" + 0.018*"staff" + 0.017*"lunch" + 0.015*"brunch" + 0.015*"spot"
#
# Review has 4.88592853899% weight for topic
# 0.042*"macchiato" + 0.034*"cause" + 0.025*"post" + 0.024*"tasting" + 0.022*"blend" + 0.021*"fruity" + 0.021*"matcha" + 0.021*"patient" + 0.020*"eye" + 0.018*"venue"
#
# Review has 5.71818168984% weight for topic
# 0.078*"hour" + 0.059*"weekend" + 0.039*"place" + 0.034*"time" + 0.024*"student" + 0.017*"food" + 0.017*"complaint" + 0.017*"evening" + 0.016*"system" + 0.014*"people"
#
# Review has 2.03282083498% weight for topic
# 0.141*"sandwich" + 0.057*"salad" + 0.052*"lunch" + 0.036*"bread" + 0.030*"soup" + 0.020*"food" + 0.019*"cheese" + 0.017*"place" + 0.017*"panini" + 0.016*"wrap"
#
# Review has 3.48149063279% weight for topic
# 0.054*"coconut" + 0.047*"tapioca" + 0.039*"slush" + 0.034*"miss" + 0.029*"cleveland" + 0.028*"disappoint" + 0.024*"grass" + 0.024*"craving" + 0.022*"refreshing" + 0.021*"bf"
#
# Review has 10.583241997% weight for topic
# 0.258*"coffee" + 0.053*"shop" + 0.040*"place" + 0.022*"cup" + 0.016*"espresso" + 0.016*"bean" + 0.013*"time" + 0.013*"staff" + 0.010*"drink" + 0.010*"house"
#
# Review has 1.25213028964% weight for topic
# 0.115*"place" + 0.038*"amazing" + 0.029*"friend" + 0.029*"cute" + 0.028*"fruit" + 0.023*"food" + 0.021*"recommend" + 0.019*"yummy" + 0.018*"staff" + 0.018*"quiche"
#
# Review has 1.60024699133% weight for topic
# 0.147*"store" + 0.049*"doughnut" + 0.036*"pick" + 0.025*"center" + 0.024*"shopping" + 0.023*"rude" + 0.023*"hazelnut" + 0.020*"bag" + 0.020*"box" + 0.017*"valley"
#
# Review has 1.37832890089% weight for topic
# 0.051*"le" + 0.046*"café" + 0.020*"je" + 0.018*"pa" + 0.017*"de" + 0.017*"la" + 0.016*"et" + 0.016*"que" + 0.015*"pour" + 0.013*"bon"
#
# Review has 1.1151983541% weight for topic
# 0.106*"customer" + 0.086*"service" + 0.035*"employee" + 0.031*"time" + 0.023*"guy" + 0.020*"manager" + 0.018*"experience" + 0.018*"day" + 0.018*"owner" + 0.015*"lady"
#
# Review has 3.71248342072% weight for topic
# 0.042*"macarons" + 0.035*"ambience" + 0.030*"charlotte" + 0.026*"mediocre" + 0.023*"interior" + 0.018*"garden" + 0.015*"pricing" + 0.015*"add" + 0.014*"mark" + 0.014*"speed"
#
# Review has 2.12452298608% weight for topic
# 0.161*"vega" + 0.064*"la" + 0.051*"hotel" + 0.034*"class" + 0.031*"steak" + 0.029*"omelette" + 0.028*"quick" + 0.023*"gift" + 0.022*"trip" + 0.020*"season"

# %%
# Next steps
# (1) more robust training set 
# (2) topic labeling 
# (3) factor in star-ratings
# (4) sentiment analysis (Stanford NLP / treebank)

# %%
import corenlp
import numpy as np

def sentimentScore(text):
    # Before running corenlp, must start up NLP server using:
    # java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000

    sentences = list(filter(None, text.replace('\n','').split('.')))
    sentimentVals = []
    for sentence in sentences:
        try:
            sentimentVals.append(corenlp.sentiment_analysis_on_sentence(sentence))
        except:
            continue
        
    return np.mean(sentimentVals)

def get_reviews(theurl):
    reviewInfo = {}
    
    stop = set(stopwords.words('english'))
    
    main_page = requests.get(theurl)
    if main_page.status_code == 200:
        soup = BeautifulSoup(main_page.content, "html.parser")
    else:
        print('Non-200 status code. Get request for url failed.')
    
    review_div = soup.findAll('div',{'itemprop':'review'})

    reviewCount = 1
    
    for i in review_div: # iterating through review_div 
        # get review star rating
        reviewStar = float(i.find('meta',{'itemprop':'ratingValue'}).get('content', None))

        # get review body text
        reviewBody = i.find('p',{'itemprop':'description'})
        for txt in reviewBody:
            if type(txt) != '<p>' and not str(txt).startswith('<p>'):
                reviewText = txt
        
        topics = predTopics(reviewText)
        sentiment = sentimentScore(reviewText)
        
        reviewInfo[reviewCount] = {'review_stars' : reviewStar, \
                                   'review_text': reviewText, \
                                   'review_topics' : topics, \
                                   'sentiment_score' : sentiment} 
        reviewCount += 1
        
    return reviewInfo
    
# def getAllReviews(restaurant_url):
#     reviewDict = {}
    
#     stop=0

#     while(stop == 0):
#         reviewDict.update(get_reviews(restaurant_url))
#         this_page = urllib.request.urlopen(restaurant_url)
#         soup = BeautifulSoup(this_page, "html.parser")
#         review_div = soup.findAll('link',{'rel':'next'})
    
#         if len(review_div) != 0:
#             for i in review_div:
#                 restaurant_url = i.get('href', None)
#         else:
#             stop = 1 

#     return reviewDict

# %%
pavementUrl = 'https://www.yelp.com/biz/pavement-coffeehouse-boston'
pavementReviews = get_reviews(pavementUrl)

# %%
import pandas as pd

# Topic labels for K=50 topics
TOPIC_LABELS = {
0 : 'tables/space/seating',
1 : 'price',
2 : 'people/atmosphere/energy',
3 : 'location/convenience/service (cars, line)',
4 : 'savory food',
5 : 'Unknown #1',
6 : 'desserts/sweets',
7 : 'wait/line/order',
8 : 'Unknown #2',
9 : 'food / meat',
10 : 'design',
11 : 'convenient / easy to grab food',
12 : 'helpfulness/friendliness of staff',
13 : 'trendiness / uniqueness',
14 : 'bakery items / pastries',
15 : 'alcoholic beverages',
16 : 'Unknown #3',
17 : 'compared to Starbucks',
18 : 'cake / dessert',
19 : 'atmosphere / fun',
20 : 'order / waittime / service',
21 : 'specialty drinks (e.g. latte)',
22 : 'business / chain',
23 : 'seasonal drinks (WINTER?)',
24 : 'food service / servers',
25 : 'crepes',
26 : 'vegan / gluten-free? (slight)',
27 : 'chocolate desserts',
28 : 'star rating rationale?',
29 : 'breakfast/brunch',
30 : 'blended drinks (e.g. macchiato, matcha, fruit)',
31 : 'good for families/kids',
32 : 'hours / opening',
33 : 'tea beverages (e.g. boba)',
34 : 'lunch foods (sandwich, salad, soup)',
35 : 'ice cream, donut, waffle (sweet things)',
36 : 'refreshing things (coconut, tapioca, slushie)',
37 : 'General coffee shop (cup, bean, place)',
38 : 'nighttime / cocktails and bars',
39 : 'Would recommend the place ',
40 : 'Store / shopping',
41 : 'French cafe?',
42 : 'breakfast foods (eggs/bacon/toast,etc)',
43 : 'juice and smoothies',
44 : 'customer service',
45 : 'ambience / interior',
46 : 'Unknown #4',
47 : 'Unknown #5',
48 : 'Hotel cafe',
49 : 'Unknown #6',
}

# Topic labels for K=25 topics

# %%
pavementData = {}

for count, items in pavementReviews.items():
    pavementData[count] = {'review_stars' : items['review_stars'],
                           'review_text' : items['review_text'],
                           'review_topics' : sorted([(t,TOPIC_LABELS[t],w) for (t,w) in items['review_topics']], key=lambda x: x[2], reverse=True),
                           'sentiment_score' : items['sentiment_score']}

# %%
pavementTopicWeights = {}
topicSentiments = {topic_name: [] for n, topic_name in TOPIC_LABELS.items()}
topicStars = {topic_name: [] for n, topic_name in TOPIC_LABELS.items()}

for count, items in pavementData.items():
    for topic in items['review_topics']:
        if topic[1] not in pavementTopicWeights:
            pavementTopicWeights[topic[1]] = topic[2]            
        else:
            pavementTopicWeights[topic[1]] += topic[2]
            
        topicSentiments[topic[1]].append(items['sentiment_score'])
        topicStars[topic[1]].append(items['review_stars'])

pavementRankedTopics = sorted(list(pavementTopicWeights.items()), key=lambda x: x[1], reverse=True)

# calculate average sentiment scores and star ratings for each topic
for k in topicSentiments:
    topicSentiments[k] = np.mean(topicSentiments[k])
    topicStars[k] = np.mean(topicStars[k])
    
topicSentimentsRanked = sorted(list(topicSentiments.items()), key=lambda x: x[1], reverse=True)
topicStarsRanked = sorted(list(topicStars.items()), key=lambda x: x[1], reverse=True)

# %%
'''
Pros of Pavement (>2 sentiment score)
- Tea 
- Employees 
- Juice 
- Trendiness
- Sandwich offerings

Cons of Pavement (<2 sentiments score)
- Atmosphere 
- Pastries and deserts 
- Wait times 
- Price 

'''
topicSentimentsRanked
# Out:
# [('Unknown #5', 3.0),
#  ('tea beverages (e.g. boba)', 2.3214285714285712),
#  ('food service / servers', 2.304761904761905),
#  ('juice and smoothies', 2.2857142857142856),
#  ('savory food', 2.2857142857142856),
#  ('trendiness / uniqueness', 2.2000000000000002),
#  ('Unknown #1', 2.1190476190476191),
#  ('lunch foods (sandwich, salad, soup)', 2.0297619047619047),
#  ('alcoholic beverages', 2.0076884920634921),
#  ('Would recommend the place ', 2.0029265873015873),
#  ('helpfulness/friendliness of staff', 1.9957671957671959),
#  ('chocolate desserts', 1.9722222222222223),
#  ('convenient / easy to grab food', 1.9676587301587303),
#  ('food / meat', 1.9642857142857142),
#  ('good for families/kids', 1.9402116402116403),
#  ('atmosphere / fun', 1.926851851851852),
#  ('compared to Starbucks', 1.906084656084656),
#  ('location/convenience/service (cars, line)', 1.9058201058201059),
#  ('bakery items / pastries', 1.8980158730158727),
#  ('seasonal drinks (WINTER?)', 1.8956709956709956),
#  ('crepes', 1.892857142857143),
#  ('breakfast foods (eggs/bacon/toast,etc)', 1.8812500000000001),
#  ('nighttime / cocktails and bars', 1.8640211640211639),
#  ('Store / shopping', 1.8550264550264552),
#  ('blended drinks (e.g. macchiato, matcha, fruit)', 1.8529914529914531),
#  ('breakfast/brunch', 1.8355820105820104),
#  ('Hotel cafe', 1.8220804988662131),
#  ('desserts/sweets', 1.812018140589569),
#  ('French cafe?', 1.8104056437389771),
#  ('tables/space/seating', 1.7970779220779221),
#  ('refreshing things (coconut, tapioca, slushie)', 1.7929453262786597),
#  ('hours / opening', 1.7644841269841269),
#  ('Unknown #4', 1.7523015873015872),
#  ('business / chain', 1.7323232323232325),
#  ('wait/line/order', 1.7256235827664399),
#  ('vegan / gluten-free? (slight)', 1.7221560846560848),
#  ('ice cream, donut, waffle (sweet things)', 1.7171957671957674),
#  ('design', 1.7113095238095237),
#  ('customer service', 1.6934744268077604),
#  ('General coffee shop (cup, bean, place)', 1.6911782661782659),
#  ('specialty drinks (e.g. latte)', 1.6682539682539683),
#  ('Unknown #2', 1.6609977324263039),
#  ('Unknown #3', 1.6424338624338624),
#  ('cake / dessert', 1.6019047619047619),
#  ('price', 1.5544973544973544),
#  ('Unknown #6', 1.4682539682539684),
#  ('star rating rationale?', 1.4446712018140586),
#  ('order / waittime / service', 1.4285714285714286),
#  ('ambience / interior', 1.4232804232804233),
#  ('people/atmosphere/energy', 1.1851851851851851)]

# %%
topicStarsRanked
# Out:
# [('juice and smoothies', 5.0),
#  ('savory food', 5.0),
#  ('tea beverages (e.g. boba)', 4.5),
#  ('crepes', 4.25),
#  ('chocolate desserts', 4.166666666666667),
#  ('food service / servers', 4.0),
#  ('trendiness / uniqueness', 4.0),
#  ('helpfulness/friendliness of staff', 4.0),
#  ('Unknown #5', 4.0),
#  ('food / meat', 4.0),
#  ('location/convenience/service (cars, line)', 3.8888888888888888),
#  ('good for families/kids', 3.8888888888888888),
#  ('Unknown #2', 3.8571428571428572),
#  ('specialty drinks (e.g. latte)', 3.8333333333333335),
#  ('hours / opening', 3.8333333333333335),
#  ('tables/space/seating', 3.8181818181818183),
#  ('Unknown #1', 3.75),
#  ('alcoholic beverages', 3.75),
#  ('Would recommend the place ', 3.75),
#  ('breakfast foods (eggs/bacon/toast,etc)', 3.75),
#  ('lunch foods (sandwich, salad, soup)', 3.75),
#  ('business / chain', 3.7272727272727271),
#  ('Hotel cafe', 3.7142857142857144),
#  ('atmosphere / fun', 3.6666666666666665),
#  ('breakfast/brunch', 3.6666666666666665),
#  ('nighttime / cocktails and bars', 3.6666666666666665),
#  ('vegan / gluten-free? (slight)', 3.6666666666666665),
#  ('refreshing things (coconut, tapioca, slushie)', 3.6666666666666665),
#  ('convenient / easy to grab food', 3.625),
#  ('bakery items / pastries', 3.6000000000000001),
#  ('cake / dessert', 3.6000000000000001),
#  ('wait/line/order', 3.5714285714285716),
#  ('French cafe?', 3.5555555555555554),
#  ('seasonal drinks (WINTER?)', 3.5454545454545454),
#  ('blended drinks (e.g. macchiato, matcha, fruit)', 3.5384615384615383),
#  ('design', 3.5),
#  ('Unknown #3', 3.4666666666666668),
#  ('customer service', 3.4444444444444446),
#  ('star rating rationale?', 3.4285714285714284),
#  ('Unknown #4', 3.3999999999999999),
#  ('General coffee shop (cup, bean, place)', 3.3846153846153846),
#  ('Store / shopping', 3.3333333333333335),
#  ('desserts/sweets', 3.2857142857142856),
#  ('compared to Starbucks', 3.1666666666666665),
#  ('ambience / interior', 3.0),
#  ('price', 3.0),
#  ('order / waittime / service', 3.0),
#  ('people/atmosphere/energy', 3.0),
#  ('ice cream, donut, waffle (sweet things)', 2.8333333333333335),
#  ('Unknown #6', 2.5)]

# %%
# Linear regression of sentiment score on star rating
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(list(topicSentiments.values()), list(topicStars.values()))

print('slope : ', slope)
print('intercept : ', intercept)
print('r_squared : ', r_value**2)
print('p_value : ', p_value)
print('std_err : ', std_err)
# Out:
# slope :  1.09542755434
# intercept :  1.63514422113
# r_squared :  0.465771731906
# p_value :  4.79676766587e-08
# std_err :  0.169332340372
